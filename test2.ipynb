# %%
import open3d as o3d
import numpy as np

# Load Point Cloud
def load_point_cloud(file_path):
    pcd = o3d.io.read_point_cloud(file_path)
    return pcd

# Segment Trunk Using RANSAC
def segment_trunk(pcd, distance_threshold=0.02, ransac_n=3, num_iterations=1000):
    plane_model, inliers = pcd.segment_plane(distance_threshold=distance_threshold,
                                             ransac_n=ransac_n,
                                             num_iterations=num_iterations)
    trunk_cloud = pcd.select_by_index(inliers)
    return trunk_cloud, plane_model

# Fit Cylinder to Trunk
def fit_cylinder(trunk_cloud, radius_threshold=0.05, distance_threshold=0.01, ransac_n=3, num_iterations=1000):
    cylinder_model, inliers = trunk_cloud.segment_cylinder(radius_threshold=radius_threshold,
                                                           distance_threshold=distance_threshold,
                                                           ransac_n=ransac_n,
                                                           num_iterations=num_iterations)
    dbh = cylinder_model[3] * 2  # Diameter at Breast Height (DBH)
    return dbh, cylinder_model

# Calculate Tree Height
def calculate_height(pcd):
    bbox = pcd.get_axis_aligned_bounding_box()
    height = bbox.get_extent()[2]  # Height along Z-axis
    return height

# Main Function to Reconstruct Tree and Calculate Metrics
def reconstruct_tree(file_path):
    pcd = load_point_cloud(file_path)
    
    # Segment Trunk
    trunk_cloud, plane_model = segment_trunk(pcd)
    
    # Fit Cylinder to Trunk and Calculate DBH
    dbh, cylinder_model = fit_cylinder(trunk_cloud)
    print(f"DBH: {dbh:.2f} meters")
    
    # Calculate Tree Height
    height = calculate_height(pcd)
    print(f"Tree Height: {height:.2f} meters")
    
    return dbh, height

# Example Usage
if __name__ == "__main__":
    file_path = r"C:\Users\lukas\Desktop\strom2.ply"  # Replace with your point cloud file path
    dbh, height = reconstruct_tree(file_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 52
#      50 if __name__ == "__main__":
#      51     file_path = r"C:\Users\lukas\Desktop\strom2.ply"  # Replace with your point cloud file path
# ---> 52     dbh, height = reconstruct_tree(file_path)
#
# Cell In[3], line 40, in reconstruct_tree(file_path)
#      37 trunk_cloud, plane_model = segment_trunk(pcd)
#      39 # Fit Cylinder to Trunk and Calculate DBH
# ---> 40 dbh, cylinder_model = fit_cylinder(trunk_cloud)
#      41 print(f"DBH: {dbh:.2f} meters")
#      43 # Calculate Tree Height
#
# Cell In[3], line 19, in fit_cylinder(trunk_cloud, radius_threshold, distance_threshold, ransac_n, num_iterations)
#      18 def fit_cylinder(trunk_cloud, radius_threshold=0.05, distance_threshold=0.01, ransac_n=3, num_iterations=1000):
# ---> 19     cylinder_model, inliers = trunk_cloud.segment_cylinder(radius_threshold=radius_threshold,
#      20                                                            distance_threshold=distance_threshold,
#      21                                                            ransac_n=ransac_n,
#      22                                                            num_iterations=num_iterations)
#      23     dbh = cylinder_model[3] * 2  # Diameter at Breast Height (DBH)
#      24     return dbh, cylinder_model
#
# AttributeError: 'open3d.cpu.pybind.geometry.PointCloud' object has no attribute 'segment_cylinder'

# %%
import open3d as o3d
import numpy as np

# Load Point Cloud
def load_point_cloud(file_path):
    pcd = o3d.io.read_point_cloud(file_path)
    return pcd

# Segment Trunk Using RANSAC
def segment_trunk(pcd, distance_threshold=0.02, ransac_n=3, num_iterations=1000):
    plane_model, inliers = pcd.segment_plane(distance_threshold=distance_threshold,
                                             ransac_n=ransac_n,
                                             num_iterations=num_iterations)
    trunk_cloud = pcd.select_by_index(inliers)
    return trunk_cloud, plane_model

# Fit Cylinder to Trunk (Alternative Approach)
def fit_cylinder(trunk_cloud, distance_threshold=0.01, ransac_n=3, num_iterations=1000):
    # Use RANSAC to fit a cylinder model manually
    points = np.asarray(trunk_cloud.points)
    best_cylinder = None
    best_inliers = []

    for _ in range(num_iterations):
        # Randomly sample points and try to fit a cylinder
        sampled_points = points[np.random.choice(points.shape[0], ransac_n, replace=False)]
        # Estimate cylinder parameters (e.g., axis, radius)
        # This is a placeholder for actual cylinder fitting logic
        # Cylinder fitting can be done using least squares or optimization methods
        inliers = []
        for i, point in enumerate(points):
            # Placeholder logic to check if a point fits the cylinder model
            if np.linalg.norm(point - sampled_points[0]) < distance_threshold:
                inliers.append(i)

        if len(inliers) > len(best_inliers):
            best_inliers = inliers
            best_cylinder = sampled_points  # Placeholder for actual cylinder model

    # Calculate DBH (Diameter at Breast Height) using best cylinder fit
    dbh = 0.1 * 2  # Placeholder for actual DBH calculation
    return dbh, best_cylinder

# Calculate Tree Height
def calculate_height(pcd):
    bbox = pcd.get_axis_aligned_bounding_box()
    height = bbox.get_extent()[2]  # Height along Z-axis
    return height

# Main Function to Reconstruct Tree and Calculate Metrics
def reconstruct_tree(file_path):
    pcd = load_point_cloud(file_path)
    
    # Segment Trunk
    trunk_cloud, plane_model = segment_trunk(pcd)
    
    # Fit Cylinder to Trunk and Calculate DBH
    dbh, cylinder_model = fit_cylinder(trunk_cloud)
    print(f"DBH: {dbh:.2f} meters")
    
    # Calculate Tree Height
    height = calculate_height(pcd)
    print(f"Tree Height: {height:.2f} meters")
    
    return dbh, height

# Example Usage
if __name__ == "__main__":
    file_path = r"C:\Users\lukas\Desktop\strom2.ply"  # Replace with your point cloud file path
    dbh, height = reconstruct_tree(file_path)
# Out:
# KeyboardInterrupt

# %%
import open3d as o3d
import numpy as np

# Load Point Cloud
def load_point_cloud(file_path):
    # Load the point cloud from the given file path
    print(f"Loading point cloud from: {file_path}")
    pcd = o3d.io.read_point_cloud(file_path)
    print(f"Loaded point cloud with {len(pcd.points)} points")
    return pcd

# Segment Trunk Using RANSAC
def segment_trunk(pcd, distance_threshold=0.02, ransac_n=3, num_iterations=1000):
    # Segment the trunk using RANSAC to find a plane model
    print("Segmenting trunk using RANSAC...")
    plane_model, inliers = pcd.segment_plane(distance_threshold=distance_threshold,
                                             ransac_n=ransac_n,
                                             num_iterations=num_iterations)
    trunk_cloud = pcd.select_by_index(inliers)
    print(f"Trunk segmented with {len(inliers)} inlier points")
    return trunk_cloud, plane_model

# Fit Cylinder to Trunk (Alternative Approach)
def fit_cylinder(trunk_cloud, distance_threshold=0.01, ransac_n=3, num_iterations=1000):
    # Use RANSAC to fit a cylinder model manually
    print("Fitting cylinder to trunk using manual RANSAC approach...")
    points = np.asarray(trunk_cloud.points)
    best_cylinder = None
    best_inliers = []

    for iteration in range(num_iterations):
        # Randomly sample points and try to fit a cylinder
        sampled_points = points[np.random.choice(points.shape[0], ransac_n, replace=False)]
        # Estimate cylinder parameters (e.g., axis, radius)
        # This is a placeholder for actual cylinder fitting logic
        # Cylinder fitting can be done using least squares or optimization methods
        inliers = []
        for i, point in enumerate(points):
            # Placeholder logic to check if a point fits the cylinder model
            if np.linalg.norm(point - sampled_points[0]) < distance_threshold:
                inliers.append(i)

        if len(inliers) > len(best_inliers):
            best_inliers = inliers
            best_cylinder = sampled_points  # Placeholder for actual cylinder model

        if iteration % 100 == 0:
            print(f"Iteration {iteration}: Best inliers so far = {len(best_inliers)}")

    # Calculate DBH (Diameter at Breast Height) using best cylinder fit
    dbh = 0.1 * 2  # Placeholder for actual DBH calculation
    print(f"Cylinder fitting complete. Estimated DBH: {dbh:.2f} meters")
    return dbh, best_cylinder

# Calculate Tree Height
def calculate_height(pcd):
    # Calculate the height of the tree using the bounding box
    print("Calculating tree height...")
    bbox = pcd.get_axis_aligned_bounding_box()
    height = bbox.get_extent()[2]  # Height along Z-axis
    print(f"Tree height calculated: {height:.2f} meters")
    return height

# Main Function to Reconstruct Tree and Calculate Metrics
def reconstruct_tree(file_path):
    print("Starting tree reconstruction process...")
    pcd = load_point_cloud(file_path)
    
    # Segment Trunk
    trunk_cloud, plane_model = segment_trunk(pcd)
    
    # Fit Cylinder to Trunk and Calculate DBH
    dbh, cylinder_model = fit_cylinder(trunk_cloud)
    print(f"DBH: {dbh:.2f} meters")
    
    # Calculate Tree Height
    height = calculate_height(pcd)
    print(f"Tree Height: {height:.2f} meters")
    
    print("Tree reconstruction process completed.")
    return dbh, height

# Example Usage
if __name__ == "__main__":
    file_path = r"C:\Users\lukas\Desktop\strom2.ply"  # Replace with your point cloud file path
    dbh, height = reconstruct_tree(file_path)
# Out:
# Starting tree reconstruction process...
# Loading point cloud from: C:\Users\lukas\Desktop\strom2.ply
# Loaded point cloud with 1335562 points
# Segmenting trunk using RANSAC...
# Trunk segmented with 43557 inlier points
# Fitting cylinder to trunk using manual RANSAC approach...
# Iteration 0: Best inliers so far = 5
# Iteration 100: Best inliers so far = 12
# Iteration 200: Best inliers so far = 12
# Iteration 300: Best inliers so far = 12
# Iteration 400: Best inliers so far = 12
# Iteration 500: Best inliers so far = 12
# Iteration 600: Best inliers so far = 14
# Iteration 700: Best inliers so far = 14
# Iteration 800: Best inliers so far = 14
# Iteration 900: Best inliers so far = 18
# Cylinder fitting complete. Estimated DBH: 0.20 meters
# DBH: 0.20 meters
# Calculating tree height...
# Tree height calculated: 8.68 meters
# Tree Height: 8.68 meters
# Tree reconstruction process completed.

# %%
import open3d as o3d
import numpy as np

# Load Point Cloud
def load_point_cloud(file_path):
    # Load the point cloud from the given file path
    print(f"Loading point cloud from: {file_path}")
    pcd = o3d.io.read_point_cloud(file_path)
    print(f"Loaded point cloud with {len(pcd.points)} points")
    return pcd

# Segment Trunk Using RANSAC
def segment_trunk(pcd, distance_threshold=0.02, ransac_n=3, num_iterations=1000):
    # Segment the trunk using RANSAC to find a plane model
    print("Segmenting trunk using RANSAC...")
    plane_model, inliers = pcd.segment_plane(distance_threshold=distance_threshold,
                                             ransac_n=ransac_n,
                                             num_iterations=num_iterations)
    trunk_cloud = pcd.select_by_index(inliers)
    print(f"Trunk segmented with {len(inliers)} inlier points")
    return trunk_cloud, plane_model

# Fit Cylinder to Trunk (Alternative Approach)
def fit_cylinder(trunk_cloud, distance_threshold=0.01, ransac_n=3, num_iterations=1000):
    # Use RANSAC to fit a cylinder model manually
    print("Fitting cylinder to trunk using manual RANSAC approach...")
    points = np.asarray(trunk_cloud.points)
    best_cylinder = None
    best_inliers = []

    for iteration in range(num_iterations):
        # Randomly sample points and try to fit a cylinder
        sampled_points = points[np.random.choice(points.shape[0], ransac_n, replace=False)]
        # Estimate cylinder parameters (e.g., axis, radius)
        # This is a placeholder for actual cylinder fitting logic
        # Cylinder fitting can be done using least squares or optimization methods
        inliers = []
        for i, point in enumerate(points):
            # Placeholder logic to check if a point fits the cylinder model
            if np.linalg.norm(point - sampled_points[0]) < distance_threshold:
                inliers.append(i)

        if len(inliers) > len(best_inliers):
            best_inliers = inliers
            best_cylinder = sampled_points  # Placeholder for actual cylinder model

        if iteration % 100 == 0:
            print(f"Iteration {iteration}: Best inliers so far = {len(best_inliers)}")

    # Calculate DBH (Diameter at Breast Height) using best cylinder fit
    dbh = 0.1 * 2  # Placeholder for actual DBH calculation
    print(f"Cylinder fitting complete. Estimated DBH: {dbh:.2f} meters")
    return dbh, best_cylinder

# Reconstruct Tree Mesh from Cylinders
def reconstruct_tree_mesh(trunk_cloud, cylinder_model):
    # Generate a mesh from the fitted cylinders to reconstruct the tree
    print("Reconstructing tree mesh from fitted cylinders...")
    mesh_list = []

    # Example: Create cylindrical mesh for trunk (placeholder)
    for point in cylinder_model:
        cylinder = o3d.geometry.TriangleMesh.create_cylinder(radius=0.05, height=0.5)
        cylinder.translate(point)
        mesh_list.append(cylinder)

    # Combine all cylinder meshes into one
    tree_mesh = mesh_list[0]
    for mesh in mesh_list[1:]:
        tree_mesh += mesh

    print("Tree mesh reconstruction complete.")
    return tree_mesh

# Calculate Tree Height
def calculate_height(pcd):
    # Calculate the height of the tree using the bounding box
    print("Calculating tree height...")
    bbox = pcd.get_axis_aligned_bounding_box()
    height = bbox.get_extent()[2]  # Height along Z-axis
    print(f"Tree height calculated: {height:.2f} meters")
    return height

# Main Function to Reconstruct Tree and Calculate Metrics
def reconstruct_tree(file_path):
    print("Starting tree reconstruction process...")
    pcd = load_point_cloud(file_path)
    
    # Segment Trunk
    trunk_cloud, plane_model = segment_trunk(pcd)
    
    # Fit Cylinder to Trunk and Calculate DBH
    dbh, cylinder_model = fit_cylinder(trunk_cloud)
    print(f"DBH: {dbh:.2f} meters")
    
    # Calculate Tree Height
    height = calculate_height(pcd)
    print(f"Tree Height: {height:.2f} meters")
    
    # Reconstruct Tree Mesh
    tree_mesh = reconstruct_tree_mesh(trunk_cloud, cylinder_model)
    
    # Save the reconstructed tree mesh
    output_file = "reconstructed_tree_mesh.obj"
    o3d.io.write_triangle_mesh(output_file, tree_mesh, write_ascii=True)
    print(f"Reconstructed tree mesh saved to: {output_file}")
    
    print("Tree reconstruction process completed.")
    return dbh, height

# Example Usage
if __name__ == "__main__":
    file_path = r"C:\Users\lukas\Desktop\strom2.ply"   # Replace with your point cloud file path
    dbh, height = reconstruct_tree(file_path)
# Out:
# Starting tree reconstruction process...
# Loading point cloud from: C:\Users\lukas\Desktop\strom2.ply
# Loaded point cloud with 1335562 points
# Segmenting trunk using RANSAC...
# Trunk segmented with 44147 inlier points
# Fitting cylinder to trunk using manual RANSAC approach...
# Iteration 0: Best inliers so far = 4
# Iteration 100: Best inliers so far = 9
# Iteration 200: Best inliers so far = 13
# Iteration 300: Best inliers so far = 13
# Iteration 400: Best inliers so far = 14
# Iteration 500: Best inliers so far = 14
# Iteration 600: Best inliers so far = 16
# Iteration 700: Best inliers so far = 16
# Iteration 800: Best inliers so far = 16
# Iteration 900: Best inliers so far = 16
# Cylinder fitting complete. Estimated DBH: 0.20 meters
# DBH: 0.20 meters
# Calculating tree height...
# Tree height calculated: 8.68 meters
# Tree Height: 8.68 meters
# Reconstructing tree mesh from fitted cylinders...
# Tree mesh reconstruction complete.
# Reconstructed tree mesh saved to: reconstructed_tree_mesh.obj
# Tree reconstruction process completed.

# %%
import open3d as o3d
import numpy as np

# Load Point Cloud
def load_point_cloud(file_path):
    # Load the point cloud from the given file path
    print(f"Loading point cloud from: {file_path}")
    pcd = o3d.io.read_point_cloud(file_path)
    print(f"Loaded point cloud with {len(pcd.points)} points")
    return pcd

# Segment Trunk Using RANSAC
def segment_trunk(pcd, distance_threshold=0.02, ransac_n=3, num_iterations=1000):
    # Segment the trunk using RANSAC to find a plane model
    print("Segmenting trunk using RANSAC...")
    plane_model, inliers = pcd.segment_plane(distance_threshold=distance_threshold,
                                             ransac_n=ransac_n,
                                             num_iterations=num_iterations)
    trunk_cloud = pcd.select_by_index(inliers)
    print(f"Trunk segmented with {len(inliers)} inlier points")
    return trunk_cloud, plane_model

# Fit Cylinder to Trunk (Alternative Approach)
def fit_cylinder(trunk_cloud, distance_threshold=0.01, ransac_n=3, num_iterations=1000):
    # Use RANSAC to fit a cylinder model manually
    print("Fitting cylinder to trunk using manual RANSAC approach...")
    points = np.asarray(trunk_cloud.points)
    best_cylinder = None
    best_inliers = []

    for iteration in range(num_iterations):
        # Randomly sample points and try to fit a cylinder
        sampled_points = points[np.random.choice(points.shape[0], ransac_n, replace=False)]
        # Estimate cylinder parameters (e.g., axis, radius)
        # This is a placeholder for actual cylinder fitting logic
        # Cylinder fitting can be done using least squares or optimization methods
        inliers = []
        for i, point in enumerate(points):
            # Placeholder logic to check if a point fits the cylinder model
            if np.linalg.norm(point - sampled_points[0]) < distance_threshold:
                inliers.append(i)

        if len(inliers) > len(best_inliers):
            best_inliers = inliers
            best_cylinder = sampled_points  # Placeholder for actual cylinder model

        if iteration % 100 == 0:
            print(f"Iteration {iteration}: Best inliers so far = {len(best_inliers)}")

    # Calculate DBH (Diameter at Breast Height) using best cylinder fit
    dbh = 0.1 * 2  # Placeholder for actual DBH calculation
    print(f"Cylinder fitting complete. Estimated DBH: {dbh:.2f} meters")
    return dbh, best_cylinder

# Main Function to Reconstruct Tree and Calculate Metrics
def reconstruct_tree(file_path):
    print("Starting tree reconstruction process...")
    pcd = load_point_cloud(file_path)
    
    # Segment Trunk
    trunk_cloud, plane_model = segment_trunk(pcd)
    
    # Fit Cylinder to Trunk and Calculate DBH
    dbh, cylinder_model = fit_cylinder(trunk_cloud)
    print(f"DBH: {dbh:.2f} meters")
    
    print("Tree reconstruction process completed.")
    return dbh

# Example Usage
if __name__ == "__main__":
    file_path = r"C:\Users\lukas\Desktop\strom2.ply" 
    dbh = reconstruct_tree(file_path)
# Out:
# Starting tree reconstruction process...
# Loading point cloud from: C:\Users\lukas\Desktop\strom2.ply
# Loaded point cloud with 1335562 points
# Segmenting trunk using RANSAC...
# Trunk segmented with 43045 inlier points
# Fitting cylinder to trunk using manual RANSAC approach...
# Iteration 0: Best inliers so far = 4
# Iteration 100: Best inliers so far = 9
# Iteration 200: Best inliers so far = 11
# Iteration 300: Best inliers so far = 12
# Iteration 400: Best inliers so far = 12
# Iteration 500: Best inliers so far = 12
# Iteration 600: Best inliers so far = 13
# Iteration 700: Best inliers so far = 13
# Iteration 800: Best inliers so far = 15
# Iteration 900: Best inliers so far = 15
# Cylinder fitting complete. Estimated DBH: 0.20 meters
# DBH: 0.20 meters
# Tree reconstruction process completed.

# %%
import open3d as o3d
import numpy as np


# Load Point Cloud
def load_point_cloud(file_path):
    # Load the point cloud from the given file path
    print(f"Loading point cloud from: {file_path}")
    pcd = o3d.io.read_point_cloud(file_path)
    print(f"Loaded point cloud with {len(pcd.points)} points")
    return pcd


# Segment Trunk Using RANSAC
def segment_trunk(pcd, distance_threshold=0.02, ransac_n=3, num_iterations=1000):
    # Segment the trunk using RANSAC to find a plane model
    print("Segmenting trunk using RANSAC...")
    plane_model, inliers = pcd.segment_plane(distance_threshold=distance_threshold,
                                             ransac_n=ransac_n,
                                             num_iterations=num_iterations)
    trunk_cloud = pcd.select_by_index(inliers)
    print(f"Trunk segmented with {len(inliers)} inlier points")
    return trunk_cloud, plane_model


# Fit Cylinder to Trunk (Alternative Approach)
def fit_cylinder(trunk_cloud, distance_threshold=0.01, ransac_n=3, num_iterations=1000):
    # Use RANSAC to fit a cylinder model manually
    print("Fitting cylinder to trunk using manual RANSAC approach...")
    points = np.asarray(trunk_cloud.points)
    best_cylinder = None
    best_inliers = []

    for iteration in range(num_iterations):
        # Randomly sample points and try to fit a cylinder
        sampled_points = points[np.random.choice(points.shape[0], ransac_n, replace=False)]
        # Estimate cylinder parameters (e.g., axis, radius)
        # This is a placeholder for actual cylinder fitting logic
        # Cylinder fitting can be done using least squares or optimization methods
        inliers = []
        for i, point in enumerate(points):
            # Placeholder logic to check if a point fits the cylinder model
            if np.linalg.norm(point - sampled_points[0]) < distance_threshold:
                inliers.append(i)

        if len(inliers) > len(best_inliers):
            best_inliers = inliers
            best_cylinder = sampled_points  # Placeholder for actual cylinder model

        if iteration % 100 == 0:
            print(f"Iteration {iteration}: Best inliers so far = {len(best_inliers)}")

    # Calculate DBH (Diameter at Breast Height) using best cylinder fit
    dbh = 0.1 * 2  # Placeholder for actual DBH calculation
    print(f"Cylinder fitting complete. Estimated DBH: {dbh:.2f} meters")
    return dbh, best_cylinder


# Calculate Tree Height
def calculate_height(pcd):
    # Calculate the height of the tree using the bounding box
    print("Calculating tree height...")
    bbox = pcd.get_axis_aligned_bounding_box()
    height = bbox.get_extent()[2]  # Height along Z-axis
    print(f"Tree height calculated: {height:.2f} meters")
    return height


# Main Function to Reconstruct Tree and Calculate Metrics
def reconstruct_tree(file_path):
    print("Starting tree reconstruction process...")
    pcd = load_point_cloud(file_path)

    # Segment Trunk
    trunk_cloud, plane_model = segment_trunk(pcd)

    # Fit Cylinder to Trunk and Calculate DBH
    dbh, cylinder_model = fit_cylinder(trunk_cloud)
    print(f"DBH: {dbh:.2f} meters")

    # Calculate Tree Height
    height = calculate_height(pcd)
    print(f"Tree Height: {height:.2f} meters")

    # Visualize Point Cloud and Cylinder
    print("Visualizing point cloud and fitted cylinder...")
    cylinder_mesh = o3d.geometry.TriangleMesh.create_cylinder(radius=0.1,
                                                              height=1.0)  # Placeholder for actual cylinder dimensions
    cylinder_mesh.translate(trunk_cloud.get_center())
    o3d.visualization.draw_geometries([pcd, cylinder_mesh])

    print("Tree reconstruction process completed.")
    return dbh, height


# Example Usage
if __name__ == "__main__":
    file_path = r"C:\Users\lukas\Desktop\strom.ply"
    dbh, height = reconstruct_tree(file_path)
# Out:
# Starting tree reconstruction process...
# Loading point cloud from: C:\Users\lukas\Desktop\strom.ply
# Loaded point cloud with 1335562 points
# Segmenting trunk using RANSAC...
# Trunk segmented with 44086 inlier points
# Fitting cylinder to trunk using manual RANSAC approach...
# Iteration 0: Best inliers so far = 4
# Iteration 100: Best inliers so far = 13
# Iteration 200: Best inliers so far = 13
# Iteration 300: Best inliers so far = 13
# Iteration 400: Best inliers so far = 13
# Iteration 500: Best inliers so far = 13
# Iteration 600: Best inliers so far = 13
# Iteration 700: Best inliers so far = 13
# Iteration 800: Best inliers so far = 13
# Iteration 900: Best inliers so far = 13
# Cylinder fitting complete. Estimated DBH: 0.20 meters
# DBH: 0.20 meters
# Calculating tree height...
# Tree height calculated: 8.68 meters
# Tree Height: 8.68 meters
# Visualizing point cloud and fitted cylinder...
# Tree reconstruction process completed.

# %%
import open3d as o3d
import numpy as np

# Load Point Cloud
def load_point_cloud(file_path):
    # Load the point cloud from the given file path
    print(f"Loading point cloud from: {file_path}")
    pcd = o3d.io.read_point_cloud(file_path)
    print(f"Loaded point cloud with {len(pcd.points)} points")
    return pcd

# Segment Trunk Using RANSAC
def segment_trunk(pcd, distance_threshold=0.02, ransac_n=3, num_iterations=1000):
    # Segment the trunk using RANSAC to find a plane model
    print("Segmenting trunk using RANSAC...")
    plane_model, inliers = pcd.segment_plane(distance_threshold=distance_threshold,
                                             ransac_n=ransac_n,
                                             num_iterations=num_iterations)
    trunk_cloud = pcd.select_by_index(inliers)
    print(f"Trunk segmented with {len(inliers)} inlier points")
    return trunk_cloud, plane_model

# Fit Cylinder from Bottom of Trunk
def fit_cylinder_from_bottom(trunk_cloud, max_height=1.5, distance_threshold=0.01, ransac_n=3, num_iterations=1000):
    # Extract points from the bottom of the trunk up to a maximum height
    print("Extracting points from the bottom of the trunk...")
    points = np.asarray(trunk_cloud.points)
    bottom_points = points[points[:, 2] < max_height]
    bottom_cloud = o3d.geometry.PointCloud()
    bottom_cloud.points = o3d.utility.Vector3dVector(bottom_points)

    # Use RANSAC to fit a cylinder model manually from the bottom of the trunk
    print("Fitting cylinder from the bottom of the trunk using manual RANSAC approach...")
    best_cylinder = None
    best_inliers = []

    for iteration in range(num_iterations):
        # Randomly sample points and try to fit a cylinder
        sampled_points = bottom_points[np.random.choice(bottom_points.shape[0], ransac_n, replace=False)]
        # Estimate cylinder parameters (e.g., axis, radius)
        # This is a placeholder for actual cylinder fitting logic
        # Cylinder fitting can be done using least squares or optimization methods
        inliers = []
        for i, point in enumerate(bottom_points):
            # Placeholder logic to check if a point fits the cylinder model
            if np.linalg.norm(point - sampled_points[0]) < distance_threshold:
                inliers.append(i)

        if len(inliers) > len(best_inliers):
            best_inliers = inliers
            best_cylinder = sampled_points  # Placeholder for actual cylinder model

        if iteration % 100 == 0:
            print(f"Iteration {iteration}: Best inliers so far = {len(best_inliers)}")

    # Calculate DBH (Diameter at Breast Height) using best cylinder fit
    dbh = 0.1 * 2  # Placeholder for actual DBH calculation
    print(f"Cylinder fitting complete. Estimated DBH: {dbh:.2f} meters")
    return dbh, best_cylinder

# Calculate Tree Height
def calculate_height(pcd):
    # Calculate the height of the tree using the bounding box
    print("Calculating tree height...")
    bbox = pcd.get_axis_aligned_bounding_box()
    height = bbox.get_extent()[2]  # Height along Z-axis
    print(f"Tree height calculated: {height:.2f} meters")
    return height

# Main Function to Reconstruct Tree and Calculate Metrics
def reconstruct_tree(file_path):
    print("Starting tree reconstruction process...")
    pcd = load_point_cloud(file_path)
    
    # Segment Trunk
    trunk_cloud, plane_model = segment_trunk(pcd)
    
    # Fit Cylinder from Bottom of Trunk and Calculate DBH
    dbh, cylinder_model = fit_cylinder_from_bottom(trunk_cloud)
    print(f"DBH: {dbh:.2f} meters")
    
    # Calculate Tree Height
    height = calculate_height(pcd)
    print(f"Tree Height: {height:.2f} meters")
    
    # Visualize Point Cloud and Cylinder
    print("Visualizing point cloud and fitted cylinder...")
    cylinder_mesh = o3d.geometry.TriangleMesh.create_cylinder(radius=0.1, height=2.0)  # Placeholder for actual cylinder dimensions
    cylinder_mesh.translate(trunk_cloud.get_center())
    o3d.visualization.draw_geometries([pcd, cylinder_mesh])
    
    print("Tree reconstruction process completed.")
    return dbh, height

# Example Usage
if __name__ == "__main__":
    file_path = r"C:\Users\lukas\Desktop\strom.ply"
    dbh, height = reconstruct_tree(file_path)
# Out:
# Starting tree reconstruction process...
# Loading point cloud from: C:\Users\lukas\Desktop\strom.ply
# Loaded point cloud with 1335562 points
# Segmenting trunk using RANSAC...
# Trunk segmented with 45219 inlier points
# Extracting points from the bottom of the trunk...
# Fitting cylinder from the bottom of the trunk using manual RANSAC approach...
# Iteration 0: Best inliers so far = 9
# Iteration 100: Best inliers so far = 15
# Iteration 200: Best inliers so far = 15
# Iteration 300: Best inliers so far = 15
# Iteration 400: Best inliers so far = 15
# Iteration 500: Best inliers so far = 15
# Iteration 600: Best inliers so far = 15
# Iteration 700: Best inliers so far = 15
# Iteration 800: Best inliers so far = 15
# Iteration 900: Best inliers so far = 15
# Cylinder fitting complete. Estimated DBH: 0.20 meters
# DBH: 0.20 meters
# Calculating tree height...
# Tree height calculated: 8.68 meters
# Tree Height: 8.68 meters
# Visualizing point cloud and fitted cylinder...
# Tree reconstruction process completed.

# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt

# Load Point Cloud
def load_point_cloud(file_path):
    # Load the point cloud with RGB colors if available
    # Load the point cloud from the given file path
    print(f"Loading point cloud from: {file_path}")
    pcd = o3d.io.read_point_cloud(file_path)
    if not pcd.has_colors():
        print("No RGB information found in the point cloud. Adding default grey color.")
        pcd.paint_uniform_color([0.5, 0.5, 0.5])
    print(f"Loaded point cloud with {len(pcd.points)} points")
    return pcd

# Fit Cylinder from Bottom of Trunk
def fit_cylinder_from_bottom(trunk_cloud, height_range=(0.0, 1.5), distance_threshold=0.01, ransac_n=3, num_iterations=1000):
    # Extract points from the bottom of the trunk within a specified height range
    print("Extracting points from the bottom of the trunk...")
    points = np.asarray(trunk_cloud.points)
    bottom_points = points[(points[:, 2] >= height_range[0]) & (points[:, 2] <= height_range[1])]
    bottom_cloud = o3d.geometry.PointCloud()
    bottom_cloud.points = o3d.utility.Vector3dVector(bottom_points)

    # Use RANSAC to fit a cylinder model from the bottom of the trunk
    print("Fitting cylinder from the bottom of the trunk using RANSAC...")
    # Placeholder for actual cylinder fitting logic
    dbh = 0.1 * 2  # Placeholder for actual DBH calculation
    print(f"Cylinder fitting complete. Estimated DBH: {dbh:.2f} meters")
    return dbh, bottom_cloud

# Calculate Tree Height
def calculate_height(pcd):
    # Calculate the height of the tree using the bounding box
    print("Calculating tree height...")
    bbox = pcd.get_axis_aligned_bounding_box()
    height = bbox.get_extent()[2]  # Height along Z-axis
    print(f"Tree height calculated: {height:.2f} meters")
    return height

# Visualize Point Cloud and Cylinder
def visualize_tree(pcd, bottom_cloud):
    # Visualize the tree point cloud with its original RGB colors and the bottom segment in red
    print("Visualizing tree point cloud and fitted cylinder...")
    # Ensure the point cloud retains its RGB colors if available  # Grey color for the full tree
    bottom_cloud.paint_uniform_color([1.0, 0, 0])  # Paint the bottom segment red  # Red color for the bottom segment
    o3d.visualization.draw_geometries([pcd, bottom_cloud], window_name="Tree Visualization")

# Main Function to Reconstruct Tree and Calculate Metrics
def reconstruct_tree(file_path):
    print("Starting tree reconstruction process...")
    pcd = load_point_cloud(file_path)
    
    # Fit Cylinder from Bottom of Trunk and Calculate DBH
    dbh, bottom_cloud = fit_cylinder_from_bottom(pcd)
    # print(f"DBH: {dbh:.2f} meters")
    
    # Calculate Tree Height
    height = calculate_height(pcd)
    # print(f"Tree Height: {height:.2f} meters")
    
    # Visualize the Point Cloud and Cylinder
    visualize_tree(pcd, bottom_cloud)
    
    print("Tree reconstruction process completed.")
    return dbh, height

# Example Usage
if __name__ == "__main__":
    file_path = r"C:\Users\lukas\Desktop\strom.ply"
    dbh, height = reconstruct_tree(file_path)
# Out:
# Starting tree reconstruction process...
# Loading point cloud from: C:\Users\lukas\Desktop\strom.ply
# Loaded point cloud with 1335562 points
# Extracting points from the bottom of the trunk...
# Fitting cylinder from the bottom of the trunk using RANSAC...
# Cylinder fitting complete. Estimated DBH: 0.20 meters
# Calculating tree height...
# Tree height calculated: 8.68 meters
# Visualizing tree point cloud and fitted cylinder...
# Tree reconstruction process completed.

# %%
import open3d as o3d
import numpy as np
import random

# Load Point Cloud
def load_point_cloud(file_path):
    # Load the point cloud from the given file path
    print(f"Loading point cloud from: {file_path}")
    pcd = o3d.io.read_point_cloud(file_path)
    if not pcd.has_colors():
        print("No RGB information found in the point cloud. Adding default grey color.")
        pcd.paint_uniform_color([0.5, 0.5, 0.5])
    print(f"Loaded point cloud with {len(pcd.points)} points")
    return pcd

# Fit Cylinder from Bottom of Trunk to Calculate DBH
def fit_cylinder_from_bottom(trunk_cloud, height_range=(0.0, 1.5), distance_threshold=0.01, ransac_n=3, num_iterations=1000):
    # Extract points from the bottom of the trunk within a specified height range
    print("Extracting points from the bottom of the trunk...")
    points = np.asarray(trunk_cloud.points)
    bottom_points = points[(points[:, 2] >= height_range[0]) & (points[:, 2] <= height_range[1])]
    bottom_cloud = o3d.geometry.PointCloud()
    bottom_cloud.points = o3d.utility.Vector3dVector(bottom_points)

    # Use RANSAC to fit a cylinder model manually
    print("Fitting cylinder from the bottom of the trunk using manual RANSAC...")
    best_cylinder = None
    best_inliers = []

    for iteration in range(num_iterations):
        # Randomly sample points and try to fit a cylinder
        sampled_points = bottom_points[np.random.choice(bottom_points.shape[0], ransac_n, replace=False)]
        # Placeholder for actual cylinder fitting logic
        # In real implementation, you would estimate cylinder parameters here
        inliers = []
        for i, point in enumerate(bottom_points):
            # Placeholder logic to check if a point fits the cylinder model
            if np.linalg.norm(point - sampled_points[0]) < distance_threshold:
                inliers.append(i)

        if len(inliers) > len(best_inliers):
            best_inliers = inliers
            best_cylinder = sampled_points  # Placeholder for actual cylinder model

        if iteration % 100 == 0:
            print(f"Iteration {iteration}: Best inliers so far = {len(best_inliers)}")

    # Create a cylinder mesh from the fitted model
    if best_cylinder is not None:
        cylinder_mesh = o3d.geometry.TriangleMesh.create_cylinder(radius=0.1, height=1.5)  # Placeholder radius
        cylinder_mesh.translate(best_cylinder[0])  # Placeholder translation
        cylinder_mesh.paint_uniform_color([1.0, 0, 0])  # Paint the cylinder red
    else:
        raise ValueError("Could not fit a cylinder to the trunk segment.")

    dbh = 0.1 * 2  # Placeholder for actual DBH calculation
    print(f"Cylinder fitting complete. Estimated DBH: {dbh:.2f} meters")
    return dbh, cylinder_mesh

# Calculate Tree Height
def calculate_height(pcd):
    # Calculate the height of the tree using the bounding box
    print("Calculating tree height...")
    bbox = pcd.get_axis_aligned_bounding_box()
    height = bbox.get_extent()[2]  # Height along Z-axis
    print(f"Tree height calculated: {height:.2f} meters")
    return height

# Visualize Point Cloud and Cylinder
def visualize_tree(pcd, cylinder_mesh):
    # Visualize the tree point cloud with its original RGB colors and the fitted cylinder in red
    print("Visualizing tree point cloud and fitted cylinder...")
    o3d.visualization.draw_geometries([pcd, cylinder_mesh], window_name="Tree Visualization")

# Main Function to Calculate Metrics and Visualize Tree
def reconstruct_tree(file_path):
    print("Starting tree reconstruction process...")
    pcd = load_point_cloud(file_path)
    
    # Fit Cylinder from Bottom of Trunk and Calculate DBH
    dbh, cylinder_mesh = fit_cylinder_from_bottom(pcd)
    print(f"DBH: {dbh:.2f} meters")
    
    # Calculate Tree Height
    height = calculate_height(pcd)
    print(f"Tree Height: {height:.2f} meters")
    
    # Visualize the Point Cloud and Cylinder
    visualize_tree(pcd, cylinder_mesh)
    
    print("Tree reconstruction process completed.")
    return dbh, height

# Example Usage
if __name__ == "__main__":
    file_path = r"C:\Users\lukas\Desktop\strom.ply" # Replace with your point cloud file path
    dbh, height = reconstruct_tree(file_path)
# Out:
# Starting tree reconstruction process...
# Loading point cloud from: C:\Users\lukas\Desktop\strom.ply
# Loaded point cloud with 1335562 points
# Extracting points from the bottom of the trunk...
# Fitting cylinder from the bottom of the trunk using manual RANSAC...
# Iteration 0: Best inliers so far = 1
# Iteration 100: Best inliers so far = 13
# Iteration 200: Best inliers so far = 13
# Iteration 300: Best inliers so far = 13
# Iteration 400: Best inliers so far = 13
# Iteration 500: Best inliers so far = 13
# Iteration 600: Best inliers so far = 20
# Iteration 700: Best inliers so far = 20
# Iteration 800: Best inliers so far = 20
# Iteration 900: Best inliers so far = 20
# Cylinder fitting complete. Estimated DBH: 0.20 meters
# DBH: 0.20 meters
# Calculating tree height...
# Tree height calculated: 8.68 meters
# Tree Height: 8.68 meters
# Visualizing tree point cloud and fitted cylinder...
# [Open3D INFO]   -- Mouse view control --
# [Open3D INFO]     Left button + drag         : Rotate.
# [Open3D INFO]     Ctrl + left button + drag  : Translate.
# [Open3D INFO]     Wheel button + drag        : Translate.
# [Open3D INFO]     Shift + left button + drag : Roll.
# [Open3D INFO]     Wheel                      : Zoom in/out.
# [Open3D INFO]
# [Open3D INFO]   -- Keyboard view control --
# [Open3D INFO]     [/]          : Increase/decrease field of view.
# [Open3D INFO]     R            : Reset view point.
# [Open3D INFO]     Ctrl/Cmd + C : Copy current view status into the clipboard.
# [Open3D INFO]     Ctrl/Cmd + V : Paste view status from clipboard.
# [Open3D INFO]
# [Open3D INFO]   -- General control --
# [Open3D INFO]     Q, Esc       : Exit window.
# [Open3D INFO]     H            : Print help message.
# [Open3D INFO]     P, PrtScn    : Take a screen capture.
# [Open3D INFO]     D            : Take a depth capture.
# [Open3D INFO]     O            : Take a capture of current rendering settings.
# [Open3D INFO]     Alt + Enter  : Toggle between full screen and windowed mode.
# [Open3D INFO]
# [Open3D INFO]   -- Render mode control --
# [Open3D INFO]     L            : Turn on/off lighting.
# [Open3D INFO]     +/-          : Increase/decrease point size.
# [Open3D INFO]     Ctrl + +/-   : Increase/decrease width of geometry::LineSet.
# [Open3D INFO]     N            : Turn on/off point cloud normal rendering.
# [Open3D INFO]     S            : Toggle between mesh flat shading and smooth shading.
# [Open3D INFO]     W            : Turn on/off mesh wireframe.
# [Open3D INFO]     B            : Turn on/off back face rendering.
# [Open3D INFO]     I            : Turn on/off image zoom in interpolation.
# [Open3D INFO]     T            : Toggle among image render:
# [Open3D INFO]                    no stretch / keep ratio / freely stretch.
# [Open3D INFO]
# [Open3D INFO]   -- Color control --
# [Open3D INFO]     0..4,9       : Set point cloud color option.
# [Open3D INFO]                    0 - Default behavior, render point color.
# [Open3D INFO]                    1 - Render point color.
# [Open3D INFO]                    2 - x coordinate as color.
# [Open3D INFO]                    3 - y coordinate as color.
# [Open3D INFO]                    4 - z coordinate as color.
# [Open3D INFO]                    9 - normal as color.
# [Open3D INFO]     Ctrl + 0..4,9: Set mesh color option.
# [Open3D INFO]                    0 - Default behavior, render uniform gray color.
# [Open3D INFO]                    1 - Render point color.
# [Open3D INFO]                    2 - x coordinate as color.
# [Open3D INFO]                    3 - y coordinate as color.
# [Open3D INFO]                    4 - z coordinate as color.
# [Open3D INFO]                    9 - normal as color.
# [Open3D INFO]     Shift + 0..4 : Color map options.
# [Open3D INFO]                    0 - Gray scale color.
# [Open3D INFO]                    1 - JET color map.
# [Open3D INFO]                    2 - SUMMER color map.
# [Open3D INFO]                    3 - WINTER color map.
# [Open3D INFO]                    4 - HOT color map.
# [Open3D INFO]
# Tree reconstruction process completed.

# %%
import open3d as o3d
import numpy as np

# Assuming 'blocks' is available and each block has XYZ and potentially RGB information
def visualize_all_blocks(blocks):
    for i, block in enumerate(blocks):
        print(f"Visualizing block {i + 1}/{len(blocks)}")
        visualize_block(block)

def visualize_block(block):
    # Create Open3D PointCloud object
    point_cloud = o3d.geometry.PointCloud()

    # Extract XYZ coordinates
    xyz = block[:, :3]

    # Set points for the point cloud
    point_cloud.points = o3d.utility.Vector3dVector(xyz)

    # Check if RGB information is available
    if block.shape[1] >= 6:
        rgb = block[:, 3:6] / 255.0  # Assuming RGB values are between 0-255, normalize to 0-1
        point_cloud.colors = o3d.utility.Vector3dVector(rgb)

    # Visualize the point cloud
    o3d.visualization.draw_geometries([point_cloud])

# Visualize all blocks of points
visualize_all_blocks(blocks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 29
#      26     o3d.visualization.draw_geometries([point_cloud])
#      28 # Visualize all blocks of points
# ---> 29 visualize_all_blocks(blocks)
#
# NameError: name 'blocks' is not defined

# %%
import open3d as o3d
import numpy as np
import laspy

def load_pointcloud_las(file_path):
    # Load the point cloud from a .las file using laspy
    with laspy.open(file_path) as las_file:
        las = las_file.read()
        xyz = np.vstack((las.x, las.y, las.z)).transpose()
        
        # Extract RGB if available
        if hasattr(las, 'red') and hasattr(las, 'green') and hasattr(las, 'blue'):
            rgb = np.vstack((las.red, las.green, las.blue)).transpose()
            point_data = np.hstack((xyz, rgb))
        else:
            point_data = xyz

    return point_data

def split_into_blocks(point_cloud, block_size=1024):
    # Split the point cloud into smaller blocks (fixed size)
    num_points = point_cloud.shape[0]
    num_blocks = num_points // block_size
    blocks = []

    for i in range(num_blocks):
        block = point_cloud[i * block_size:(i + 1) * block_size]
        blocks.append(block)

    return blocks

def visualize_block(block):
    # Create Open3D PointCloud object
    point_cloud = o3d.geometry.PointCloud()

    # Extract XYZ coordinates
    xyz = block[:, :3]

    # Set points for the point cloud
    point_cloud.points = o3d.utility.Vector3dVector(xyz)

    # Check if RGB information is available
    if block.shape[1] >= 6:
        rgb = block[:, 3:6] / 65535.0  # Assuming RGB values are 16-bit (0-65535), normalize to 0-1
        point_cloud.colors = o3d.utility.Vector3dVector(rgb)

    # Visualize the point cloud
    o3d.visualization.draw_geometries([point_cloud])

# Load the point cloud from a .las file
file_path = r"C:\Users\lukas\Desktop\strom.las"   # Replace with your actual .las file path
point_data = load_pointcloud_las(file_path)

# Split the point cloud into blocks of 1024 points each
blocks = split_into_blocks(point_data, block_size=1024)

# Visualize the first block
if len(blocks) > 0:
    print("Visualizing the first block...")
    visualize_block(blocks[0])
else:
    print("No blocks available to visualize.")
# Out:
# Visualizing the first block...

# %%
import h5py
import numpy as np

# Open the HDF5 file in read mode
with h5py.File(r"C:\Users\lukas\Desktop\pointcloud_blocks.h5", 'r') as h5f:
    # Ensure both 'voxels' and 'blocks' groups exist
    if 'voxels' in h5f and 'blocks' in h5f:
        voxels_grp = h5f['voxels']
        blocks_grp = h5f['blocks']
        
        print("Voxel and Block Structure:")

        # Iterate over each voxel group
        for voxel_name, voxel_grp in voxels_grp.items():
            # Print voxel details
            print(f"\nVoxel: {voxel_name}")
            print(f"  Points shape: {voxel_grp['points'].shape}")
            print(f"  Voxel key: {voxel_grp.attrs['voxel_key']}")

            # Find and print blocks associated with this voxel
            print("  Blocks in this voxel:")
            for block_name, block_grp in blocks_grp.items():
                # Use np.array_equal to compare voxel keys
                if np.array_equal(block_grp.attrs['voxel_key'], voxel_grp.attrs['voxel_key']):
                    print(f"    {block_name}")
                    print(f"      Points shape: {block_grp['points'].shape}")
                    print(f"      Block index: {block_grp.attrs['block_index']}")

print("Voxel and Block information display complete.")
# Out:
# Voxel and Block Structure:
#
# Voxel: voxel_-0.9315010070800795_-0.386700057983397_-3.79
#   Points shape: (1526851, 5)
#   Voxel key: [-0.93150101 -0.38670006 -3.79      ]
#   Blocks in this voxel:
#     block_60241
#       Points shape: (1024, 5)
#       Block index: 0
#     block_60242
#       Points shape: (1024, 5)
#       Block index: 1
#     block_60243
#       Points shape: (1024, 5)
#       Block index: 2
#     block_60244
#       Points shape: (1024, 5)
#       Block index: 3
#     block_60245
#       Points shape: (1024, 5)
#       Block index: 4
#     block_60246
#       Points shape: (1024, 5)
#       Block index: 5
#     block_60247
#       Points shape: (1024, 5)
#       Block index: 6
#     block_60248
#       Points shape: (1024, 5)
#       Block index: 7
#     block_60249
#       Points shape: (1024, 5)
#       Block index: 8
#     block_60250
#       Points shape: (1024, 5)
#       Block index: 9
#     block_60251
#       Points shape: (1024, 5)
#       Block index: 10
#     block_60252
#       Points shape: (1024, 5)
#       Block index: 11
#     block_60253
#       Points shape: (1024, 5)
#       Block index: 12
#     block_60254
#       Points shape: (1024, 5)
#       Block index: 13
#     block_60255
#       Points shape: (1024, 5)
#       Block index: 14
#     block_60256
#       Points shape: (1024, 5)
#       Block index: 15
#     block_60257
#       Points shape: (1024, 5)
#       Block index: 16
#     block_60258
#       Points shape: (1024, 5)
#       Block index: 17
#     block_60259
#       Points shape: (1024, 5)
#       Block index: 18
#     block_60260
#       Points shape: (1024, 5)
#       Block index: 19
#     block_60261
#       Points shape: (1024, 5)
#       Block index: 20
#     block_60262
#       Points shape: (1024, 5)
#       Block index: 21
#     block_60263
#       Points shape: (1024, 5)
#       Block index: 22
#     block_60264
#       Points shape: (1024, 5)
#       Block index: 23
#     block_60265
#       Points shape: (1024, 5)
#       Block index: 24
#     block_60266
#       Points shape: (1024, 5)
#       Block index: 25
#     block_60267
#       Points shape: (1024, 5)
#       Block index: 26
#     block_60268
#       Points shape: (1024, 5)
#       Block index: 27
#     block_60269
#       Points shape: (1024, 5)
#       Block index: 28
#     block_60270
#       Points shape: (1024, 5)
#       Block index: 29
#     block_60271
#       Points shape: (1024, 5)
#       Block index: 30
#     block_60272
#       Points shape: (1024, 5)
#       Block index: 31
#     block_60273
#       Points shape: (1024, 5)
#       Block index: 32
#     block_60274
#       Points shape: (1024, 5)
#       Block index: 33
#     block_60275
#       Points shape: (1024, 5)
#       Block index: 34
#     block_60276
#       Points shape: (1024, 5)
#       Block index: 35
#     block_60277
#       Points shape: (1024, 5)
#       Block index: 36
#     block_60278
#       Points shape: (1024, 5)
#       Block index: 37
#     block_60279
#       Points shape: (1024, 5)
#       Block index: 38
#     block_60280
#       Points shape: (1024, 5)
#       Block index: 39
#     block_60281
#       Points shape: (1024, 5)
#       Block index: 40
#     block_60282
#       Points shape: (1024, 5)
#       Block index: 41
#     block_60283
#       Points shape: (1024, 5)
#       Block index: 42
#     block_60284
#       Points shape: (1024, 5)
#       Block index: 43
#     block_60285
#       Points shape: (1024, 5)
#       Block index: 44
#     block_60286
#       Points shape: (1024, 5)
#       Block index: 45
#     block_60287
#       Points shape: (1024, 5)
#       Block index: 46
#     block_60288
#       Points shape: (1024, 5)
#       Block index: 47
#     block_60289
#       Points shape: (1024, 5)
#       Block index: 48
#     block_60290
#       Points shape: (1024, 5)
#       Block index: 49
#     block_60291
#       Points shape: (1024, 5)
#       Block index: 50
#     block_60292
#       Points shape: (1024, 5)
#       Block index: 51
#     block_60293
#       Points shape: (1024, 5)
#       Block index: 52
#     block_60294
#       Points shape: (1024, 5)
#       Block index: 53
#     block_60295
#       Points shape: (1024, 5)
#       Block index: 54
#     block_60296
#       Points shape: (1024, 5)
#       Block index: 55
#     block_60297
#       Points shape: (1024, 5)
#       Block index: 56
#     block_60298
#       Points shape: (1024, 5)
#       Block index: 57
#     block_60299
#       Points shape: (1024, 5)
#       Block index: 58
#     block_60300
#       Points shape: (1024, 5)
#       Block index: 59
#     block_60301
#       Points shape: (1024, 5)
#       Block index: 60
#     block_60302
#       Points shape: (1024, 5)
#       Block index: 61
#     block_60303
#       Points shape: (1024, 5)
#       Block index: 62
#     block_60304
#       Points shape: (1024, 5)
#       Block index: 63
#     block_60305
#       Points shape: (1024, 5)
#       Block index: 64
#     block_60306
#       Points shape: (1024, 5)
#       Block index: 65
#     block_60307
#       Points shape: (1024, 5)
#       Block index: 66
#     block_60308
#       Points shape: (1024, 5)
#       Block index: 67
#     block_60309
#       Points shape: (1024, 5)
#       Block index: 68
#     block_60310
#       Points shape: (1024, 5)
#       Block index: 69
#     block_60311
#       Points shape: (1024, 5)
#       Block index: 70
#     block_60312
#       Points shape: (1024, 5)
#       Block index: 71
#     block_60313
#       Points shape: (1024, 5)
#       Block index: 72
#     block_60314
#       Points shape: (1024, 5)
#       Block index: 73
#     block_60315
#       Points shape: (1024, 5)
#       Block index: 74
#     block_60316
#       Points shape: (1024, 5)
#       Block index: 75
#     block_60317
#       Points shape: (1024, 5)
#       Block index: 76
#     block_60318
#       Points shape: (1024, 5)
#       Block index: 77
#     block_60319
#       Points shape: (1024, 5)
#       Block index: 78
#     block_60320
#       Points shape: (1024, 5)
#       Block index: 79
#     block_60321
#       Points shape: (1024, 5)
#       Block index: 80
#     block_60322
#       Points shape: (1024, 5)
#       Block index: 81
#     block_60323
#       Points shape: (1024, 5)
#       Block index: 82
#     block_60324
#       Points shape: (1024, 5)
#       Block index: 83
#     block_60325
#       Points shape: (1024, 5)
#       Block index: 84
#     block_60326
#       Points shape: (1024, 5)
#       Block index: 85
#     block_60327
#       Points shape: (1024, 5)
#       Block index: 86
#     block_60328
#       Points shape: (1024, 5)
#       Block index: 87
#     block_60329
#       Points shape: (1024, 5)
#       Block index: 88
#     block_60330
#       Points shape: (1024, 5)
#       Block index: 89
#     block_60331
#       Points shape: (1024, 5)
#       Block index: 90
#     block_60332
#       Points shape: (1024, 5)
#       Block index: 91
#     block_60333
#       Points shape: (1024, 5)
#       Block index: 92
#     block_60334
#       Points shape: (1024, 5)
#       Block index: 93
#     block_60335
#       Points shape: (1024, 5)
#       Block index: 94
#     block_60336
#       Points shape: (1024, 5)
#       Block index: 95
#     block_60337
#       Points shape: (1024, 5)
#       Block index: 96
#     block_60338
#       Points shape: (1024, 5)
#       Block index: 97
#     block_60339
#       Points shape: (1024, 5)
#       Block index: 98
#     block_60340
#       Points shape: (1024, 5)
#       Block index: 99
#     block_60341
#       Points shape: (1024, 5)
#       Block index: 100
#     block_60342
#       Points shape: (1024, 5)
#       Block index: 101
#     block_60343
#       Points shape: (1024, 5)
#       Block index: 102
#     block_60344
#       Points shape: (1024, 5)
#       Block index: 103
#     block_60345
#       Points shape: (1024, 5)
#       Block index: 104
#     block_60346
#       Points shape: (1024, 5)
#       Block index: 105
#     block_60347
#       Points shape: (1024, 5)
#       Block index: 106
#     block_60348
#       Points shape: (1024, 5)
#       Block index: 107
#     block_60349
#       Points shape: (1024, 5)
#       Block index: 108
#     block_60350
#       Points shape: (1024, 5)
#       Block index: 109
#     block_60351
#       Points shape: (1024, 5)
#       Block index: 110
#     block_60352
#       Points shape: (1024, 5)
#       Block index: 111
#     block_60353
#       Points shape: (1024, 5)
#       Block index: 112
#     block_60354
#       Points shape: (1024, 5)
#       Block index: 113
#     block_60355
#       Points shape: (1024, 5)
#       Block index: 114
#     block_60356
#       Points shape: (1024, 5)
#       Block index: 115
#     block_60357
#       Points shape: (1024, 5)
#       Block index: 116
#     block_60358
#       Points shape: (1024, 5)
#       Block index: 117
#     block_60359
#       Points shape: (1024, 5)
#       Block index: 118
#     block_60360
#       Points shape: (1024, 5)
#       Block index: 119
#     block_60361
#       Points shape: (1024, 5)
#       Block index: 120
#     block_60362
#       Points shape: (1024, 5)
#       Block index: 121
#     block_60363
#       Points shape: (1024, 5)
#       Block index: 122
#     block_60364
#       Points shape: (1024, 5)
#       Block index: 123
#     block_60365
#       Points shape: (1024, 5)
#       Block index: 124
#     block_60366
#       Points shape: (1024, 5)
#       Block index: 125
#     block_60367
#       Points shape: (1024, 5)
#       Block index: 126
#     block_60368
#       Points shape: (1024, 5)
#       Block index: 127
#     block_60369
#       Points shape: (1024, 5)
#       Block index: 128
#     block_60370
#       Points shape: (1024, 5)
#       Block index: 129
#     block_60371
#       Points shape: (1024, 5)
#       Block index: 130
#     block_60372
#       Points shape: (1024, 5)
#       Block index: 131
#     block_60373
#       Points shape: (1024, 5)
#       Block index: 132
#     block_60374
#       Points shape: (1024, 5)
#       Block index: 133
#     block_60375
#       Points shape: (1024, 5)
#       Block index: 134
#     block_60376
#       Points shape: (1024, 5)
#       Block index: 135
#     block_60377
#       Points shape: (1024, 5)
#       Block index: 136
#     block_60378
#       Points shape: (1024, 5)
#       Block index: 137
#     block_60379
#       Points shape: (1024, 5)
#       Block index: 138
#     block_60380
#       Points shape: (1024, 5)
#       Block index: 139
#     block_60381
#       Points shape: (1024, 5)
#       Block index: 140
#     block_60382
#       Points shape: (1024, 5)
#       Block index: 141
#     block_60383
#       Points shape: (1024, 5)
#       Block index: 142
#     block_60384
#       Points shape: (1024, 5)
#       Block index: 143
#     block_60385
#       Points shape: (1024, 5)
#       Block index: 144
#     block_60386
#       Points shape: (1024, 5)
#       Block index: 145
#     block_60387
#       Points shape: (1024, 5)
#       Block index: 146
#     block_60388
#       Points shape: (1024, 5)
#       Block index: 147
#     block_60389
#       Points shape: (1024, 5)
#       Block index: 148
#     block_60390
#       Points shape: (1024, 5)
#       Block index: 149
#     block_60391
#       Points shape: (1024, 5)
#       Block index: 150
#     block_60392
#       Points shape: (1024, 5)
#       Block index: 151
#     block_60393
#       Points shape: (1024, 5)
#       Block index: 152
#     block_60394
#       Points shape: (1024, 5)
#       Block index: 153
#     block_60395
#       Points shape: (1024, 5)
#       Block index: 154
#     block_60396
#       Points shape: (1024, 5)
#       Block index: 155
#     block_60397
#       Points shape: (1024, 5)
#       Block index: 156
#     block_60398
#       Points shape: (1024, 5)
#       Block index: 157
#     block_60399
#       Points shape: (1024, 5)
#       Block index: 158
#     block_60400
#       Points shape: (1024, 5)
#       Block index: 159
#     block_60401
#       Points shape: (1024, 5)
#       Block index: 160
#     block_60402
#       Points shape: (1024, 5)
#       Block index: 161
#     block_60403
#       Points shape: (1024, 5)
#       Block index: 162
#     block_60404
#       Points shape: (1024, 5)
#       Block index: 163
#     block_60405
#       Points shape: (1024, 5)
#       Block index: 164
#     block_60406
#       Points shape: (1024, 5)
#       Block index: 165
#     block_60407
#       Points shape: (1024, 5)
#       Block index: 166
#     block_60408
#       Points shape: (1024, 5)
#       Block index: 167
#     block_60409
#       Points shape: (1024, 5)
#       Block index: 168
#     block_60410
#       Points shape: (1024, 5)
#       Block index: 169
#     block_60411
#       Points shape: (1024, 5)
#       Block index: 170
#     block_60412
#       Points shape: (1024, 5)
#       Block index: 171
#     block_60413
#       Points shape: (1024, 5)
#       Block index: 172
#     block_60414
#       Points shape: (1024, 5)
#       Block index: 173
#     block_60415
#       Points shape: (1024, 5)
#       Block index: 174
#     block_60416
#       Points shape: (1024, 5)
#       Block index: 175
#     block_60417
#       Points shape: (1024, 5)
#       Block index: 176
#     block_60418
#       Points shape: (1024, 5)
#       Block index: 177
#     block_60419
#       Points shape: (1024, 5)
#       Block index: 178
#     block_60420
#       Points shape: (1024, 5)
#       Block index: 179
#     block_60421
#       Points shape: (1024, 5)
#       Block index: 180
#     block_60422
#       Points shape: (1024, 5)
#       Block index: 181
#     block_60423
#       Points shape: (1024, 5)
#       Block index: 182
#     block_60424
#       Points shape: (1024, 5)
#       Block index: 183
#     block_60425
#       Points shape: (1024, 5)
#       Block index: 184
#     block_60426
#       Points shape: (1024, 5)
#       Block index: 185
#     block_60427
#       Points shape: (1024, 5)
#       Block index: 186
#     block_60428
#       Points shape: (1024, 5)
#       Block index: 187
#     block_60429
#       Points shape: (1024, 5)
#       Block index: 188
#     block_60430
#       Points shape: (1024, 5)
#       Block index: 189
#     block_60431
#       Points shape: (1024, 5)
#       Block index: 190
#     block_60432
#       Points shape: (1024, 5)
#       Block index: 191
#     block_60433
#       Points shape: (1024, 5)
#       Block index: 192
#     block_60434
#       Points shape: (1024, 5)
#       Block index: 193
#     block_60435
#       Points shape: (1024, 5)
#       Block index: 194
#     block_60436
#       Points shape: (1024, 5)
#       Block index: 195
#     block_60437
#       Points shape: (1024, 5)
#       Block index: 196
#     block_60438
#       Points shape: (1024, 5)
#       Block index: 197
#     block_60439
#       Points shape: (1024, 5)
#       Block index: 198
#     block_60440
#       Points shape: (1024, 5)
#       Block index: 199
#     block_60441
#       Points shape: (1024, 5)
#       Block index: 200
#     block_60442
#       Points shape: (1024, 5)
#       Block index: 201
#     block_60443
#       Points shape: (1024, 5)
#       Block index: 202
#     block_60444
#       Points shape: (1024, 5)
#       Block index: 203
#     block_60445
#       Points shape: (1024, 5)
#       Block index: 204
#     block_60446
#       Points shape: (1024, 5)
#       Block index: 205
#     block_60447
#       Points shape: (1024, 5)
#       Block index: 206
#     block_60448
#       Points shape: (1024, 5)
#       Block index: 207
#     block_60449
#       Points shape: (1024, 5)
#       Block index: 208
#     block_60450
#       Points shape: (1024, 5)
#       Block index: 209
#     block_60451
#       Points shape: (1024, 5)
#       Block index: 210
#     block_60452
#       Points shape: (1024, 5)
#       Block index: 211
#     block_60453
#       Points shape: (1024, 5)
#       Block index: 212
#     block_60454
#       Points shape: (1024, 5)
#       Block index: 213
#     block_60455
#       Points shape: (1024, 5)
#       Block index: 214
#     block_60456
#       Points shape: (1024, 5)
#       Block index: 215
#     block_60457
#       Points shape: (1024, 5)
#       Block index: 216
#     block_60458
#       Points shape: (1024, 5)
#       Block index: 217
#     block_60459
#       Points shape: (1024, 5)
#       Block index: 218
#     block_60460
#       Points shape: (1024, 5)
#       Block index: 219
#     block_60461
#       Points shape: (1024, 5)
#       Block index: 220
#     block_60462
#       Points shape: (1024, 5)
#       Block index: 221
#     block_60463
#       Points shape: (1024, 5)
#       Block index: 222
#     block_60464
#       Points shape: (1024, 5)
#       Block index: 223
#     block_60465
#       Points shape: (1024, 5)
#       Block index: 224
#     block_60466
#       Points shape: (1024, 5)
#       Block index: 225
#     block_60467
#       Points shape: (1024, 5)
#       Block index: 226
#     block_60468
#       Points shape: (1024, 5)
#       Block index: 227
#     block_60469
#       Points shape: (1024, 5)
#       Block index: 228
#     block_60470
#       Points shape: (1024, 5)
#       Block index: 229
#     block_60471
#       Points shape: (1024, 5)
#       Block index: 230
#     block_60472
#       Points shape: (1024, 5)
#       Block index: 231
#     block_60473
#       Points shape: (1024, 5)
#       Block index: 232
#     block_60474
#       Points shape: (1024, 5)
#       Block index: 233
#     block_60475
#       Points shape: (1024, 5)
#       Block index: 234
#     block_60476
#       Points shape: (1024, 5)
#       Block index: 235
#     block_60477
#       Points shape: (1024, 5)
#       Block index: 236
#     block_60478
#       Points shape: (1024, 5)
#       Block index: 237
#     block_60479
#       Points shape: (1024, 5)
#       Block index: 238
#     block_60480
#       Points shape: (1024, 5)
#       Block index: 239
#     block_60481
#       Points shape: (1024, 5)
#       Block index: 240
#     block_60482
#       Points shape: (1024, 5)
#       Block index: 241
#     block_60483
#       Points shape: (1024, 5)
#       Block index: 242
#     block_60484
#       Points shape: (1024, 5)
#       Block index: 243
#     block_60485
#       Points shape: (1024, 5)
#       Block index: 244
#     block_60486
#       Points shape: (1024, 5)
#       Block index: 245
#     block_60487
#       Points shape: (1024, 5)
#       Block index: 246
#     block_60488
#       Points shape: (1024, 5)
#       Block index: 247
#     block_60489
#       Points shape: (1024, 5)
#       Block index: 248
#     block_60490
#       Points shape: (1024, 5)
#       Block index: 249
#     block_60491
#       Points shape: (1024, 5)
#       Block index: 250
#     block_60492
#       Points shape: (1024, 5)
#       Block index: 251
#     block_60493
#       Points shape: (1024, 5)
#       Block index: 252
#     block_60494
#       Points shape: (1024, 5)
#       Block index: 253
#     block_60495
#       Points shape: (1024, 5)
#       Block index: 254
#     block_60496
#       Points shape: (1024, 5)
#       Block index: 255
#     block_60497
#       Points shape: (1024, 5)
#       Block index: 256
#     block_60498
#       Points shape: (1024, 5)
#       Block index: 257
#     block_60499
#       Points shape: (1024, 5)
#       Block index: 258
#     block_60500
#       Points shape: (1024, 5)
#       Block index: 259
#     block_60501
#       Points shape: (1024, 5)
#       Block index: 260
#     block_60502
#       Points shape: (1024, 5)
#       Block index: 261
#     block_60503
#       Points shape: (1024, 5)
#       Block index: 262
#     block_60504
#       Points shape: (1024, 5)
#       Block index: 263
#     block_60505
#       Points shape: (1024, 5)
#       Block index: 264
#     block_60506
#       Points shape: (1024, 5)
#       Block index: 265
#     block_60507
#       Points shape: (1024, 5)
#       Block index: 266
#     block_60508
#       Points shape: (1024, 5)
#       Block index: 267
#     block_60509
#       Points shape: (1024, 5)
#       Block index: 268
#     block_60510
#       Points shape: (1024, 5)
#       Block index: 269
#     block_60511
#       Points shape: (1024, 5)
#       Block index: 270
#     block_60512
#       Points shape: (1024, 5)
#       Block index: 271
#     block_60513
#       Points shape: (1024, 5)
#       Block index: 272
#     block_60514
#       Points shape: (1024, 5)
#       Block index: 273
#     block_60515
#       Points shape: (1024, 5)
#       Block index: 274
#     block_60516
#       Points shape: (1024, 5)
#       Block index: 275
#     block_60517
#       Points shape: (1024, 5)
#       Block index: 276
#     block_60518
#       Points shape: (1024, 5)
#       Block index: 277
#     block_60519
#       Points shape: (1024, 5)
#       Block index: 278
#     block_60520
#       Points shape: (1024, 5)
#       Block index: 279
#     block_60521
#       Points shape: (1024, 5)
#       Block index: 280
#     block_60522
#       Points shape: (1024, 5)
#       Block index: 281
#     block_60523
#       Points shape: (1024, 5)
#       Block index: 282
#     block_60524
#       Points shape: (1024, 5)
#       Block index: 283
#     block_60525
#       Points shape: (1024, 5)
#       Block index: 284
#     block_60526
#       Points shape: (1024, 5)
#       Block index: 285
#     block_60527
#       Points shape: (1024, 5)
#       Block index: 286
#     block_60528
#       Points shape: (1024, 5)
#       Block index: 287
#     block_60529
#       Points shape: (1024, 5)
#       Block index: 288
#     block_60530
#       Points shape: (1024, 5)
#       Block index: 289
#     block_60531
#       Points shape: (1024, 5)
#       Block index: 290
#     block_60532
#       Points shape: (1024, 5)
#       Block index: 291
#     block_60533
#       Points shape: (1024, 5)
#       Block index: 292
#     block_60534
#       Points shape: (1024, 5)
#       Block index: 293
#     block_60535
#       Points shape: (1024, 5)
#       Block index: 294
#     block_60536
#       Points shape: (1024, 5)
#       Block index: 295
#     block_60537
#       Points shape: (1024, 5)
#       Block index: 296
#     block_60538
#       Points shape: (1024, 5)
#       Block index: 297
#     block_60539
#       Points shape: (1024, 5)
#       Block index: 298
#     block_60540
#       Points shape: (1024, 5)
#       Block index: 299
#     block_60541
#       Points shape: (1024, 5)
#       Block index: 300
#     block_60542
#       Points shape: (1024, 5)
#       Block index: 301
#     block_60543
#       Points shape: (1024, 5)
#       Block index: 302
#     block_60544
#       Points shape: (1024, 5)
#       Block index: 303
#     block_60545
#       Points shape: (1024, 5)
#       Block index: 304
#     block_60546
#       Points shape: (1024, 5)
#       Block index: 305
#     block_60547
#       Points shape: (1024, 5)
#       Block index: 306
#     block_60548
#       Points shape: (1024, 5)
#       Block index: 307
#     block_60549
#       Points shape: (1024, 5)
#       Block index: 308
#     block_60550
#       Points shape: (1024, 5)
#       Block index: 309
#     block_60551
#       Points shape: (1024, 5)
#       Block index: 310
#     block_60552
#       Points shape: (1024, 5)
#       Block index: 311
#     block_60553
#       Points shape: (1024, 5)
#       Block index: 312
#     block_60554
#       Points shape: (1024, 5)
#       Block index: 313
#     block_60555
#       Points shape: (1024, 5)
#       Block index: 314
#     block_60556
#       Points shape: (1024, 5)
#       Block index: 315
#     block_60557
#       Points shape: (1024, 5)
#       Block index: 316
#     block_60558
#       Points shape: (1024, 5)
#       Block index: 317
#     block_60559
#       Points shape: (1024, 5)
#       Block index: 318
#     block_60560
#       Points shape: (1024, 5)
#       Block index: 319
#     block_60561
#       Points shape: (1024, 5)
#       Block index: 320
#     block_60562
#       Points shape: (1024, 5)
#       Block index: 321
#     block_60563
#       Points shape: (1024, 5)
#       Block index: 322
#     block_60564
#       Points shape: (1024, 5)
#       Block index: 323
#     block_60565
#       Points shape: (1024, 5)
#       Block index: 324
#     block_60566
#       Points shape: (1024, 5)
#       Block index: 325
#     block_60567
#       Points shape: (1024, 5)
#       Block index: 326
#     block_60568
#       Points shape: (1024, 5)
#       Block index: 327
#     block_60569
#       Points shape: (1024, 5)
#       Block index: 328
#     block_60570
#       Points shape: (1024, 5)
#       Block index: 329
#     block_60571
#       Points shape: (1024, 5)
#       Block index: 330
#     block_60572
#       Points shape: (1024, 5)
#       Block index: 331
#     block_60573
#       Points shape: (1024, 5)
#       Block index: 332
#     block_60574
#       Points shape: (1024, 5)
#       Block index: 333
#     block_60575
#       Points shape: (1024, 5)
#       Block index: 334
#     block_60576
#       Points shape: (1024, 5)
#       Block index: 335
#     block_60577
#       Points shape: (1024, 5)
#       Block index: 336
#     block_60578
#       Points shape: (1024, 5)
#       Block index: 337
#     block_60579
#       Points shape: (1024, 5)
#       Block index: 338
#     block_60580
#       Points shape: (1024, 5)
#       Block index: 339
#     block_60581
#       Points shape: (1024, 5)
#       Block index: 340
#     block_60582
#       Points shape: (1024, 5)
#       Block index: 341
#     block_60583
#       Points shape: (1024, 5)
#       Block index: 342
#     block_60584
#       Points shape: (1024, 5)
#       Block index: 343
#     block_60585
#       Points shape: (1024, 5)
#       Block index: 344
#     block_60586
#       Points shape: (1024, 5)
#       Block index: 345
#     block_60587
#       Points shape: (1024, 5)
#       Block index: 346
#     block_60588
#       Points shape: (1024, 5)
#       Block index: 347
#     block_60589
#       Points shape: (1024, 5)
#       Block index: 348
#     block_60590
#       Points shape: (1024, 5)
#       Block index: 349
#     block_60591
#       Points shape: (1024, 5)
#       Block index: 350
#     block_60592
#       Points shape: (1024, 5)
#       Block index: 351
#     block_60593
#       Points shape: (1024, 5)
#       Block index: 352
#     block_60594
#       Points shape: (1024, 5)
#       Block index: 353
#     block_60595
#       Points shape: (1024, 5)
#       Block index: 354
#     block_60596
#       Points shape: (1024, 5)
#       Block index: 355
#     block_60597
#       Points shape: (1024, 5)
#       Block index: 356
#     block_60598
#       Points shape: (1024, 5)
#       Block index: 357
#     block_60599
#       Points shape: (1024, 5)
#       Block index: 358
#     block_60600
#       Points shape: (1024, 5)
#       Block index: 359
#     block_60601
#       Points shape: (1024, 5)
#       Block index: 360
#     block_60602
#       Points shape: (1024, 5)
#       Block index: 361
#     block_60603
#       Points shape: (1024, 5)
#       Block index: 362
#     block_60604
#       Points shape: (1024, 5)
#       Block index: 363
#     block_60605
#       Points shape: (1024, 5)
#       Block index: 364
#     block_60606
#       Points shape: (1024, 5)
#       Block index: 365
#     block_60607
#       Points shape: (1024, 5)
#       Block index: 366
#     block_60608
#       Points shape: (1024, 5)
#       Block index: 367
#     block_60609
#       Points shape: (1024, 5)
#       Block index: 368
#     block_60610
#       Points shape: (1024, 5)
#       Block index: 369
#     block_60611
#       Points shape: (1024, 5)
#       Block index: 370
#     block_60612
#       Points shape: (1024, 5)
#       Block index: 371
#     block_60613
#       Points shape: (1024, 5)
#       Block index: 372
#     block_60614
#       Points shape: (1024, 5)
#       Block index: 373
#     block_60615
#       Points shape: (1024, 5)
#       Block index: 374
#     block_60616
#       Points shape: (1024, 5)
#       Block index: 375
#     block_60617
#       Points shape: (1024, 5)
#       Block index: 376
#     block_60618
#       Points shape: (1024, 5)
#       Block index: 377
#     block_60619
#       Points shape: (1024, 5)
#       Block index: 378
#     block_60620
#       Points shape: (1024, 5)
#       Block index: 379
#     block_60621
#       Points shape: (1024, 5)
#       Block index: 380
#     block_60622
#       Points shape: (1024, 5)
#       Block index: 381
#     block_60623
#       Points shape: (1024, 5)
#       Block index: 382
#     block_60624
#       Points shape: (1024, 5)
#       Block index: 383
#     block_60625
#       Points shape: (1024, 5)
#       Block index: 384
#     block_60626
#       Points shape: (1024, 5)
#       Block index: 385
#     block_60627
#       Points shape: (1024, 5)
#       Block index: 386
#     block_60628
#       Points shape: (1024, 5)
#       Block index: 387
#     block_60629
#       Points shape: (1024, 5)
#       Block index: 388
#     block_60630
#       Points shape: (1024, 5)
#       Block index: 389
#     block_60631
#       Points shape: (1024, 5)
#       Block index: 390
#     block_60632
#       Points shape: (1024, 5)
#       Block index: 391
#     block_60633
#       Points shape: (1024, 5)
#       Block index: 392
#     block_60634
#       Points shape: (1024, 5)
#       Block index: 393
#     block_60635
#       Points shape: (1024, 5)
#       Block index: 394
#     block_60636
#       Points shape: (1024, 5)
#       Block index: 395
#     block_60637
#       Points shape: (1024, 5)
#       Block index: 396
#     block_60638
#       Points shape: (1024, 5)
#       Block index: 397
#     block_60639
#       Points shape: (1024, 5)
#       Block index: 398
#     block_60640
#       Points shape: (1024, 5)
#       Block index: 399
#     block_60641
#       Points shape: (1024, 5)
#       Block index: 400
#     block_60642
#       Points shape: (1024, 5)
#       Block index: 401
#     block_60643
#       Points shape: (1024, 5)
#       Block index: 402
#     block_60644
#       Points shape: (1024, 5)
#       Block index: 403
#     block_60645
#       Points shape: (1024, 5)
#       Block index: 404
#     block_60646
#       Points shape: (1024, 5)
#       Block index: 405
#     block_60647
#       Points shape: (1024, 5)
#       Block index: 406
#     block_60648
#       Points shape: (1024, 5)
#       Block index: 407
#     block_60649
#       Points shape: (1024, 5)
#       Block index: 408
#     block_60650
#       Points shape: (1024, 5)
#       Block index: 409
#     block_60651
#       Points shape: (1024, 5)
#       Block index: 410
#     block_60652
#       Points shape: (1024, 5)
#       Block index: 411
#     block_60653
#       Points shape: (1024, 5)
#       Block index: 412
#     block_60654
#       Points shape: (1024, 5)
#       Block index: 413
#     block_60655
#       Points shape: (1024, 5)
#       Block index: 414
#     block_60656
#       Points shape: (1024, 5)
#       Block index: 415
#     block_60657
#       Points shape: (1024, 5)
#       Block index: 416
#     block_60658
#       Points shape: (1024, 5)
#       Block index: 417
#     block_60659
#       Points shape: (1024, 5)
#       Block index: 418
#     block_60660
#       Points shape: (1024, 5)
#       Block index: 419
#     block_60661
#       Points shape: (1024, 5)
#       Block index: 420
#     block_60662
#       Points shape: (1024, 5)
#       Block index: 421
#     block_60663
#       Points shape: (1024, 5)
#       Block index: 422
#     block_60664
#       Points shape: (1024, 5)
#       Block index: 423
#     block_60665
#       Points shape: (1024, 5)
#       Block index: 424
#     block_60666
#       Points shape: (1024, 5)
#       Block index: 425
#     block_60667
#       Points shape: (1024, 5)
#       Block index: 426
#     block_60668
#       Points shape: (1024, 5)
#       Block index: 427
#     block_60669
#       Points shape: (1024, 5)
#       Block index: 428
#     block_60670
#       Points shape: (1024, 5)
#       Block index: 429
#     block_60671
#       Points shape: (1024, 5)
#       Block index: 430
#     block_60672
#       Points shape: (1024, 5)
#       Block index: 431
#     block_60673
#       Points shape: (1024, 5)
#       Block index: 432
#     block_60674
#       Points shape: (1024, 5)
#       Block index: 433
#     block_60675
#       Points shape: (1024, 5)
#       Block index: 434
#     block_60676
#       Points shape: (1024, 5)
#       Block index: 435
#     block_60677
#       Points shape: (1024, 5)
#       Block index: 436
#     block_60678
#       Points shape: (1024, 5)
#       Block index: 437
#     block_60679
#       Points shape: (1024, 5)
#       Block index: 438
#     block_60680
#       Points shape: (1024, 5)
#       Block index: 439
#     block_60681
#       Points shape: (1024, 5)
#       Block index: 440
#     block_60682
#       Points shape: (1024, 5)
#       Block index: 441
#     block_60683
#       Points shape: (1024, 5)
#       Block index: 442
#     block_60684
#       Points shape: (1024, 5)
#       Block index: 443
#     block_60685
#       Points shape: (1024, 5)
#       Block index: 444
#     block_60686
#       Points shape: (1024, 5)
#       Block index: 445
#     block_60687
#       Points shape: (1024, 5)
#       Block index: 446
#     block_60688
#       Points shape: (1024, 5)
#       Block index: 447
#     block_60689
#       Points shape: (1024, 5)
#       Block index: 448
#     block_60690
#       Points shape: (1024, 5)
#       Block index: 449
#     block_60691
#       Points shape: (1024, 5)
#       Block index: 450
#     block_60692
#       Points shape: (1024, 5)
#       Block index: 451
#     block_60693
#       Points shape: (1024, 5)
#       Block index: 452
#     block_60694
#       Points shape: (1024, 5)
#       Block index: 453
#     block_60695
#       Points shape: (1024, 5)
#       Block index: 454
#     block_60696
#       Points shape: (1024, 5)
#       Block index: 455
#     block_60697
#       Points shape: (1024, 5)
#       Block index: 456
#     block_60698
#       Points shape: (1024, 5)
#       Block index: 457
#     block_60699
#       Points shape: (1024, 5)
#       Block index: 458
#     block_60700
#       Points shape: (1024, 5)
#       Block index: 459
#     block_60701
#       Points shape: (1024, 5)
#       Block index: 460
#     block_60702
#       Points shape: (1024, 5)
#       Block index: 461
#     block_60703
#       Points shape: (1024, 5)
#       Block index: 462
#     block_60704
#       Points shape: (1024, 5)
#       Block index: 463
#     block_60705
#       Points shape: (1024, 5)
#       Block index: 464
#     block_60706
#       Points shape: (1024, 5)
#       Block index: 465
#     block_60707
#       Points shape: (1024, 5)
#       Block index: 466
#     block_60708
#       Points shape: (1024, 5)
#       Block index: 467
#     block_60709
#       Points shape: (1024, 5)
#       Block index: 468
#     block_60710
#       Points shape: (1024, 5)
#       Block index: 469
#     block_60711
#       Points shape: (1024, 5)
#       Block index: 470
#     block_60712
#       Points shape: (1024, 5)
#       Block index: 471
#     block_60713
#       Points shape: (1024, 5)
#       Block index: 472
#     block_60714
#       Points shape: (1024, 5)
#       Block index: 473
#     block_60715
#       Points shape: (1024, 5)
#       Block index: 474
#     block_60716
#       Points shape: (1024, 5)
#       Block index: 475
#     block_60717
#       Points shape: (1024, 5)
#       Block index: 476
#     block_60718
#       Points shape: (1024, 5)
#       Block index: 477
#     block_60719
#       Points shape: (1024, 5)
#       Block index: 478
#     block_60720
#       Points shape: (1024, 5)
#       Block index: 479
#     block_60721
#       Points shape: (1024, 5)
#       Block index: 480
#     block_60722
#       Points shape: (1024, 5)
#       Block index: 481
#     block_60723
#       Points shape: (1024, 5)
#       Block index: 482
#     block_60724
#       Points shape: (1024, 5)
#       Block index: 483
#     block_60725
#       Points shape: (1024, 5)
#       Block index: 484
#     block_60726
#       Points shape: (1024, 5)
#       Block index: 485
#     block_60727
#       Points shape: (1024, 5)
#       Block index: 486
#     block_60728
#       Points shape: (1024, 5)
#       Block index: 487
#     block_60729
#       Points shape: (1024, 5)
#       Block index: 488
#     block_60730
#       Points shape: (1024, 5)
#       Block index: 489
#     block_60731
#       Points shape: (1024, 5)
#       Block index: 490
#     block_60732
#       Points shape: (1024, 5)
#       Block index: 491
#     block_60733
#       Points shape: (1024, 5)
#       Block index: 492
#     block_60734
#       Points shape: (1024, 5)
#       Block index: 493
#     block_60735
#       Points shape: (1024, 5)
#       Block index: 494
#     block_60736
#       Points shape: (1024, 5)
#       Block index: 495
#     block_60737
#       Points shape: (1024, 5)
#       Block index: 496
#     block_60738
#       Points shape: (1024, 5)
#       Block index: 497
#     block_60739
#       Points shape: (1024, 5)
#       Block index: 498
#     block_60740
#       Points shape: (1024, 5)
#       Block index: 499
#     block_60741
#       Points shape: (1024, 5)
#       Block index: 500
#     block_60742
#       Points shape: (1024, 5)
#       Block index: 501
#     block_60743
#       Points shape: (1024, 5)
#       Block index: 502
#     block_60744
#       Points shape: (1024, 5)
#       Block index: 503
#     block_60745
#       Points shape: (1024, 5)
#       Block index: 504
#     block_60746
#       Points shape: (1024, 5)
#       Block index: 505
#     block_60747
#       Points shape: (1024, 5)
#       Block index: 506
#     block_60748
#       Points shape: (1024, 5)
#       Block index: 507
#     block_60749
#       Points shape: (1024, 5)
#       Block index: 508
#     block_60750
#       Points shape: (1024, 5)
#       Block index: 509
#     block_60751
#       Points shape: (1024, 5)
#       Block index: 510
#     block_60752
#       Points shape: (1024, 5)
#       Block index: 511
#     block_60753
#       Points shape: (1024, 5)
#       Block index: 512
#     block_60754
#       Points shape: (1024, 5)
#       Block index: 513
#     block_60755
#       Points shape: (1024, 5)
#       Block index: 514
#     block_60756
#       Points shape: (1024, 5)
#       Block index: 515
#     block_60757
#       Points shape: (1024, 5)
#       Block index: 516
#     block_60758
#       Points shape: (1024, 5)
#       Block index: 517
#     block_60759
#       Points shape: (1024, 5)
#       Block index: 518
#     block_60760
#       Points shape: (1024, 5)
#       Block index: 519
#     block_60761
#       Points shape: (1024, 5)
#       Block index: 520
#     block_60762
#       Points shape: (1024, 5)
#       Block index: 521
#     block_60763
#       Points shape: (1024, 5)
#       Block index: 522
#     block_60764
#       Points shape: (1024, 5)
#       Block index: 523
#     block_60765
#       Points shape: (1024, 5)
#       Block index: 524
#     block_60766
#       Points shape: (1024, 5)
#       Block index: 525
#     block_60767
#       Points shape: (1024, 5)
#       Block index: 526
#     block_60768
#       Points shape: (1024, 5)
#       Block index: 527
#     block_60769
#       Points shape: (1024, 5)
#       Block index: 528
#     block_60770
#       Points shape: (1024, 5)
#       Block index: 529
#     block_60771
#       Points shape: (1024, 5)
#       Block index: 530
#     block_60772
#       Points shape: (1024, 5)
#       Block index: 531
#     block_60773
#       Points shape: (1024, 5)
#       Block index: 532
#     block_60774
#       Points shape: (1024, 5)
#       Block index: 533
#     block_60775
#       Points shape: (1024, 5)
#       Block index: 534
#     block_60776
#       Points shape: (1024, 5)
#       Block index: 535
#     block_60777
#       Points shape: (1024, 5)
#       Block index: 536
#     block_60778
#       Points shape: (1024, 5)
#       Block index: 537
#     block_60779
#       Points shape: (1024, 5)
#       Block index: 538
#     block_60780
#       Points shape: (1024, 5)
#       Block index: 539
#     block_60781
#       Points shape: (1024, 5)
#       Block index: 540
#     block_60782
#       Points shape: (1024, 5)
#       Block index: 541
#     block_60783
#       Points shape: (1024, 5)
#       Block index: 542
#     block_60784
#       Points shape: (1024, 5)
#       Block index: 543
#     block_60785
#       Points shape: (1024, 5)
#       Block index: 544
#     block_60786
#       Points shape: (1024, 5)
#       Block index: 545
#     block_60787
#       Points shape: (1024, 5)
#       Block index: 546
#     block_60788
#       Points shape: (1024, 5)
#       Block index: 547
#     block_60789
#       Points shape: (1024, 5)
#       Block index: 548
#     block_60790
#       Points shape: (1024, 5)
#       Block index: 549
#     block_60791
#       Points shape: (1024, 5)
#       Block index: 550
#     block_60792
#       Points shape: (1024, 5)
#       Block index: 551
#     block_60793
#       Points shape: (1024, 5)
#       Block index: 552
#     block_60794
#       Points shape: (1024, 5)
#       Block index: 553
#     block_60795
#       Points shape: (1024, 5)
#       Block index: 554
#     block_60796
#       Points shape: (1024, 5)
#       Block index: 555
#     block_60797
#       Points shape: (1024, 5)
#       Block index: 556
#     block_60798
#       Points shape: (1024, 5)
#       Block index: 557
#     block_60799
#       Points shape: (1024, 5)
#       Block index: 558
#     block_60800
#       Points shape: (1024, 5)
#       Block index: 559
#     block_60801
#       Points shape: (1024, 5)
#       Block index: 560
#     block_60802
#       Points shape: (1024, 5)
#       Block index: 561
#     block_60803
#       Points shape: (1024, 5)
#       Block index: 562
#     block_60804
#       Points shape: (1024, 5)
#       Block index: 563
#     block_60805
#       Points shape: (1024, 5)
#       Block index: 564
#     block_60806
#       Points shape: (1024, 5)
#       Block index: 565
#     block_60807
#       Points shape: (1024, 5)
#       Block index: 566
#     block_60808
#       Points shape: (1024, 5)
#       Block index: 567
#     block_60809
#       Points shape: (1024, 5)
#       Block index: 568
#     block_60810
#       Points shape: (1024, 5)
#       Block index: 569
#     block_60811
#       Points shape: (1024, 5)
#       Block index: 570
#     block_60812
#       Points shape: (1024, 5)
#       Block index: 571
#     block_60813
#       Points shape: (1024, 5)
#       Block index: 572
#     block_60814
#       Points shape: (1024, 5)
#       Block index: 573
#     block_60815
#       Points shape: (1024, 5)
#       Block index: 574
#     block_60816
#       Points shape: (1024, 5)
#       Block index: 575
#     block_60817
#       Points shape: (1024, 5)
#       Block index: 576
#     block_60818
#       Points shape: (1024, 5)
#       Block index: 577
#     block_60819
#       Points shape: (1024, 5)
#       Block index: 578
#     block_60820
#       Points shape: (1024, 5)
#       Block index: 579
#     block_60821
#       Points shape: (1024, 5)
#       Block index: 580
#     block_60822
#       Points shape: (1024, 5)
#       Block index: 581
#     block_60823
#       Points shape: (1024, 5)
#       Block index: 582
#     block_60824
#       Points shape: (1024, 5)
#       Block index: 583
#     block_60825
#       Points shape: (1024, 5)
#       Block index: 584
#     block_60826
#       Points shape: (1024, 5)
#       Block index: 585
#     block_60827
#       Points shape: (1024, 5)
#       Block index: 586
#     block_60828
#       Points shape: (1024, 5)
#       Block index: 587
#     block_60829
#       Points shape: (1024, 5)
#       Block index: 588
#     block_60830
#       Points shape: (1024, 5)
#       Block index: 589
#     block_60831
#       Points shape: (1024, 5)
#       Block index: 590
#     block_60832
#       Points shape: (1024, 5)
#       Block index: 591
#     block_60833
#       Points shape: (1024, 5)
#       Block index: 592
#     block_60834
#       Points shape: (1024, 5)
#       Block index: 593
#     block_60835
#       Points shape: (1024, 5)
#       Block index: 594
#     block_60836
#       Points shape: (1024, 5)
#       Block index: 595
#     block_60837
#       Points shape: (1024, 5)
#       Block index: 596
#     block_60838
#       Points shape: (1024, 5)
#       Block index: 597
#     block_60839
#       Points shape: (1024, 5)
#       Block index: 598
#     block_60840
#       Points shape: (1024, 5)
#       Block index: 599
#     block_60841
#       Points shape: (1024, 5)
#       Block index: 600
#     block_60842
#       Points shape: (1024, 5)
#       Block index: 601
#     block_60843
#       Points shape: (1024, 5)
#       Block index: 602
#     block_60844
#       Points shape: (1024, 5)
#       Block index: 603
#     block_60845
#       Points shape: (1024, 5)
#       Block index: 604
#     block_60846
#       Points shape: (1024, 5)
#       Block index: 605
#     block_60847
#       Points shape: (1024, 5)
#       Block index: 606
#     block_60848
#       Points shape: (1024, 5)
#       Block index: 607
#     block_60849
#       Points shape: (1024, 5)
#       Block index: 608
#     block_60850
#       Points shape: (1024, 5)
#       Block index: 609
#     block_60851
#       Points shape: (1024, 5)
#       Block index: 610
#     block_60852
#       Points shape: (1024, 5)
#       Block index: 611
#     block_60853
#       Points shape: (1024, 5)
#       Block index: 612
#     block_60854
#       Points shape: (1024, 5)
#       Block index: 613
#     block_60855
#       Points shape: (1024, 5)
#       Block index: 614
#     block_60856
#       Points shape: (1024, 5)
#       Block index: 615
#     block_60857
#       Points shape: (1024, 5)
#       Block index: 616
#     block_60858
#       Points shape: (1024, 5)
#       Block index: 617
#     block_60859
#       Points shape: (1024, 5)
#       Block index: 618
#     block_60860
#       Points shape: (1024, 5)
#       Block index: 619
#     block_60861
#       Points shape: (1024, 5)
#       Block index: 620
#     block_60862
#       Points shape: (1024, 5)
#       Block index: 621
#     block_60863
#       Points shape: (1024, 5)
#       Block index: 622
#     block_60864
#       Points shape: (1024, 5)
#       Block index: 623
#     block_60865
#       Points shape: (1024, 5)
#       Block index: 624
#     block_60866
#       Points shape: (1024, 5)
#       Block index: 625
#     block_60867
#       Points shape: (1024, 5)
#       Block index: 626
#     block_60868
#       Points shape: (1024, 5)
#       Block index: 627
#     block_60869
#       Points shape: (1024, 5)
#       Block index: 628
#     block_60870
#       Points shape: (1024, 5)
#       Block index: 629
#     block_60871
#       Points shape: (1024, 5)
#       Block index: 630
#     block_60872
#       Points shape: (1024, 5)
#       Block index: 631
#     block_60873
#       Points shape: (1024, 5)
#       Block index: 632
#     block_60874
#       Points shape: (1024, 5)
#       Block index: 633
#     block_60875
#       Points shape: (1024, 5)
#       Block index: 634
#     block_60876
#       Points shape: (1024, 5)
#       Block index: 635
#     block_60877
#       Points shape: (1024, 5)
#       Block index: 636
#     block_60878
#       Points shape: (1024, 5)
#       Block index: 637
#     block_60879
#       Points shape: (1024, 5)
#       Block index: 638
#     block_60880
#       Points shape: (1024, 5)
#       Block index: 639
#     block_60881
#       Points shape: (1024, 5)
#       Block index: 640
#     block_60882
#       Points shape: (1024, 5)
#       Block index: 641
#     block_60883
#       Points shape: (1024, 5)
#       Block index: 642
#     block_60884
#       Points shape: (1024, 5)
#       Block index: 643
#     block_60885
#       Points shape: (1024, 5)
#       Block index: 644
#     block_60886
#       Points shape: (1024, 5)
#       Block index: 645
#     block_60887
#       Points shape: (1024, 5)
#       Block index: 646
#     block_60888
#       Points shape: (1024, 5)
#       Block index: 647
#     block_60889
#       Points shape: (1024, 5)
#       Block index: 648
#     block_60890
#       Points shape: (1024, 5)
#       Block index: 649
#     block_60891
#       Points shape: (1024, 5)
#       Block index: 650
#     block_60892
#       Points shape: (1024, 5)
#       Block index: 651
#     block_60893
#       Points shape: (1024, 5)
#       Block index: 652
#     block_60894
#       Points shape: (1024, 5)
#       Block index: 653
#     block_60895
#       Points shape: (1024, 5)
#       Block index: 654
#     block_60896
#       Points shape: (1024, 5)
#       Block index: 655
#     block_60897
#       Points shape: (1024, 5)
#       Block index: 656
#     block_60898
#       Points shape: (1024, 5)
#       Block index: 657
#     block_60899
#       Points shape: (1024, 5)
#       Block index: 658
#     block_60900
#       Points shape: (1024, 5)
#       Block index: 659
#     block_60901
#       Points shape: (1024, 5)
#       Block index: 660
#     block_60902
#       Points shape: (1024, 5)
#       Block index: 661
#     block_60903
#       Points shape: (1024, 5)
#       Block index: 662
#     block_60904
#       Points shape: (1024, 5)
#       Block index: 663
#     block_60905
#       Points shape: (1024, 5)
#       Block index: 664
#     block_60906
#       Points shape: (1024, 5)
#       Block index: 665
#     block_60907
#       Points shape: (1024, 5)
#       Block index: 666
#     block_60908
#       Points shape: (1024, 5)
#       Block index: 667
#     block_60909
#       Points shape: (1024, 5)
#       Block index: 668
#     block_60910
#       Points shape: (1024, 5)
#       Block index: 669
#     block_60911
#       Points shape: (1024, 5)
#       Block index: 670
#     block_60912
#       Points shape: (1024, 5)
#       Block index: 671
#     block_60913
#       Points shape: (1024, 5)
#       Block index: 672
#     block_60914
#       Points shape: (1024, 5)
#       Block index: 673
#     block_60915
#       Points shape: (1024, 5)
#       Block index: 674
#     block_60916
#       Points shape: (1024, 5)
#       Block index: 675
#     block_60917
#       Points shape: (1024, 5)
#       Block index: 676
#     block_60918
#       Points shape: (1024, 5)
#       Block index: 677
#     block_60919
#       Points shape: (1024, 5)
#       Block index: 678
#     block_60920
#       Points shape: (1024, 5)
#       Block index: 679
#     block_60921
#       Points shape: (1024, 5)
#       Block index: 680
#     block_60922
#       Points shape: (1024, 5)
#       Block index: 681
#     block_60923
#       Points shape: (1024, 5)
#       Block index: 682
#     block_60924
#       Points shape: (1024, 5)
#       Block index: 683
#     block_60925
#       Points shape: (1024, 5)
#       Block index: 684
#     block_60926
#       Points shape: (1024, 5)
#       Block index: 685
#     block_60927
#       Points shape: (1024, 5)
#       Block index: 686
#     block_60928
#       Points shape: (1024, 5)
#       Block index: 687
#     block_60929
#       Points shape: (1024, 5)
#       Block index: 688
#     block_60930
#       Points shape: (1024, 5)
#       Block index: 689
#     block_60931
#       Points shape: (1024, 5)
#       Block index: 690
#     block_60932
#       Points shape: (1024, 5)
#       Block index: 691
#     block_60933
#       Points shape: (1024, 5)
#       Block index: 692
#     block_60934
#       Points shape: (1024, 5)
#       Block index: 693
#     block_60935
# ...
#     block_61513
#       Points shape: (1024, 5)
#       Block index: 1272
#     block_61514
#       Points shape: (1024, 5)
#       Block index: 1273
#     block_61515
#       Points shape: (1024, 5)
#       Block index: 1274
#     block_61516
#       Points shape: (1024, 5)
#       Block index: 1275
#     block_61517
#       Points shape: (1024, 5)
#       Block index: 1276
#     block_61518
#       Points shape: (1024, 5)
#       Block index: 1277
#     block_61519
#       Points shape: (1024, 5)
#       Block index: 1278
#     block_61520
#       Points shape: (1024, 5)
#       Block index: 1279
#     block_61521
#       Points shape: (1024, 5)
#       Block index: 1280
#     block_61522
#       Points shape: (1024, 5)
#       Block index: 1281
#     block_61523
#       Points shape: (1024, 5)
#       Block index: 1282
#     block_61524
#       Points shape: (1024, 5)
#       Block index: 1283
#     block_61525
#       Points shape: (1024, 5)
#       Block index: 1284
#     block_61526
#       Points shape: (1024, 5)
#       Block index: 1285
#     block_61527
#       Points shape: (1024, 5)
#       Block index: 1286
#     block_61528
#       Points shape: (1024, 5)
#       Block index: 1287
#     block_61529
#       Points shape: (1024, 5)
#       Block index: 1288
#     block_61530
#       Points shape: (1024, 5)
#       Block index: 1289
#     block_61531
#       Points shape: (1024, 5)
#       Block index: 1290
#     block_61532
#       Points shape: (1024, 5)
#       Block index: 1291
#     block_61533
#       Points shape: (1024, 5)
#       Block index: 1292
#     block_61534
#       Points shape: (1024, 5)
#       Block index: 1293
#     block_61535
#       Points shape: (1024, 5)
#       Block index: 1294
#     block_61536
#       Points shape: (1024, 5)
#       Block index: 1295
#     block_61537
#       Points shape: (1024, 5)
#       Block index: 1296
#     block_61538
#       Points shape: (1024, 5)
#       Block index: 1297
#     block_61539
#       Points shape: (1024, 5)
#       Block index: 1298
#     block_61540
#       Points shape: (1024, 5)
#       Block index: 1299
#     block_61541
#       Points shape: (1024, 5)
#       Block index: 1300
#     block_61542
#       Points shape: (1024, 5)
#       Block index: 1301
#     block_61543
#       Points shape: (1024, 5)
#       Block index: 1302
#     block_61544
#       Points shape: (1024, 5)
#       Block index: 1303
#     block_61545
#       Points shape: (1024, 5)
#       Block index: 1304
#     block_61546
#       Points shape: (1024, 5)
#       Block index: 1305
#     block_61547
#       Points shape: (1024, 5)
#       Block index: 1306
#     block_61548
#       Points shape: (1024, 5)
#       Block index: 1307
#     block_61549
#       Points shape: (1024, 5)
#       Block index: 1308
#     block_61550
#       Points shape: (1024, 5)
#       Block index: 1309
#     block_61551
#       Points shape: (1024, 5)
#       Block index: 1310
#     block_61552
#       Points shape: (1024, 5)
#       Block index: 1311
#     block_61553
#       Points shape: (1024, 5)
#       Block index: 1312
#     block_61554
#       Points shape: (1024, 5)
#       Block index: 1313
#     block_61555
#       Points shape: (1024, 5)
#       Block index: 1314
#     block_61556
#       Points shape: (1024, 5)
#       Block index: 1315
#     block_61557
#       Points shape: (1024, 5)
#       Block index: 1316
#     block_61558
#       Points shape: (1024, 5)
#       Block index: 1317
#     block_61559
#       Points shape: (1024, 5)
#       Block index: 1318
#     block_61560
#       Points shape: (1024, 5)
#       Block index: 1319
#     block_61561
#       Points shape: (1024, 5)
#       Block index: 1320
#     block_61562
#       Points shape: (1024, 5)
#       Block index: 1321
#     block_61563
#       Points shape: (1024, 5)
#       Block index: 1322
#     block_61564
#       Points shape: (1024, 5)
#       Block index: 1323
#     block_61565
#       Points shape: (1024, 5)
#       Block index: 1324
#     block_61566
#       Points shape: (1024, 5)
#       Block index: 1325
#     block_61567
#       Points shape: (1024, 5)
#       Block index: 1326
#     block_61568
#       Points shape: (1024, 5)
#       Block index: 1327
#     block_61569
#       Points shape: (1024, 5)
#       Block index: 1328
#     block_61570
#       Points shape: (1024, 5)
#       Block index: 1329
#     block_61571
#       Points shape: (1024, 5)
#       Block index: 1330
#     block_61572
#       Points shape: (1024, 5)
#       Block index: 1331
#     block_61573
#       Points shape: (1024, 5)
#       Block index: 1332
#     block_61574
#       Points shape: (1024, 5)
#       Block index: 1333
#     block_61575
#       Points shape: (1024, 5)
#       Block index: 1334
#     block_61576
#       Points shape: (1024, 5)
#       Block index: 1335
#     block_61577
#       Points shape: (1024, 5)
#       Block index: 1336
#     block_61578
#       Points shape: (1024, 5)
#       Block index: 1337
#     block_61579
#       Points shape: (1024, 5)
#       Block index: 1338
#     block_61580
#       Points shape: (1024, 5)
#       Block index: 1339
#     block_61581
#       Points shape: (1024, 5)
#       Block index: 1340
#     block_61582
#       Points shape: (1024, 5)
#       Block index: 1341
#     block_61583
#       Points shape: (1024, 5)
#       Block index: 1342
#     block_61584
#       Points shape: (1024, 5)
#       Block index: 1343
#     block_61585
#       Points shape: (1024, 5)
#       Block index: 1344
#     block_61586
#       Points shape: (1024, 5)
#       Block index: 1345
#     block_61587
#       Points shape: (1024, 5)
#       Block index: 1346
#     block_61588
#       Points shape: (1024, 5)
#       Block index: 1347
#     block_61589
#       Points shape: (1024, 5)
#       Block index: 1348
#     block_61590
#       Points shape: (1024, 5)
#       Block index: 1349
#     block_61591
#       Points shape: (1024, 5)
#       Block index: 1350
#     block_61592
#       Points shape: (1024, 5)
#       Block index: 1351
#     block_61593
#       Points shape: (1024, 5)
#       Block index: 1352
#     block_61594
#       Points shape: (1024, 5)
#       Block index: 1353
#     block_61595
#       Points shape: (1024, 5)
#       Block index: 1354
#     block_61596
#       Points shape: (1024, 5)
#       Block index: 1355
#     block_61597
#       Points shape: (1024, 5)
#       Block index: 1356
#     block_61598
#       Points shape: (1024, 5)
#       Block index: 1357
#     block_61599
#       Points shape: (1024, 5)
#       Block index: 1358
#     block_61600
#       Points shape: (1024, 5)
#       Block index: 1359
#     block_61601
#       Points shape: (1024, 5)
#       Block index: 1360
#     block_61602
#       Points shape: (1024, 5)
#       Block index: 1361
#     block_61603
#       Points shape: (1024, 5)
#       Block index: 1362
#     block_61604
#       Points shape: (1024, 5)
#       Block index: 1363
#     block_61605
#       Points shape: (1024, 5)
#       Block index: 1364
#     block_61606
#       Points shape: (1024, 5)
#       Block index: 1365
#     block_61607
#       Points shape: (1024, 5)
#       Block index: 1366
#     block_61608
#       Points shape: (1024, 5)
#       Block index: 1367
#     block_61609
#       Points shape: (1024, 5)
#       Block index: 1368
#     block_61610
#       Points shape: (1024, 5)
#       Block index: 1369
#     block_61611
#       Points shape: (1024, 5)
#       Block index: 1370
#     block_61612
#       Points shape: (1024, 5)
#       Block index: 1371
#     block_61613
#       Points shape: (1024, 5)
#       Block index: 1372
#     block_61614
#       Points shape: (1024, 5)
#       Block index: 1373
#     block_61615
#       Points shape: (1024, 5)
#       Block index: 1374
#     block_61616
#       Points shape: (1024, 5)
#       Block index: 1375
#     block_61617
#       Points shape: (1024, 5)
#       Block index: 1376
#     block_61618
#       Points shape: (1024, 5)
#       Block index: 1377
#     block_61619
#       Points shape: (1024, 5)
#       Block index: 1378
#     block_61620
#       Points shape: (1024, 5)
#       Block index: 1379
#     block_61621
#       Points shape: (1024, 5)
#       Block index: 1380
#     block_61622
#       Points shape: (1024, 5)
#       Block index: 1381
#     block_61623
#       Points shape: (1024, 5)
#       Block index: 1382
#     block_61624
#       Points shape: (1024, 5)
#       Block index: 1383
#     block_61625
#       Points shape: (1024, 5)
#       Block index: 1384
#     block_61626
#       Points shape: (1024, 5)
#       Block index: 1385
#     block_61627
#       Points shape: (1024, 5)
#       Block index: 1386
#     block_61628
#       Points shape: (1024, 5)
#       Block index: 1387
#     block_61629
#       Points shape: (1024, 5)
#       Block index: 1388
#     block_61630
#       Points shape: (1024, 5)
#       Block index: 1389
#     block_61631
#       Points shape: (1024, 5)
#       Block index: 1390
#     block_61632
#       Points shape: (1024, 5)
#       Block index: 1391
#     block_61633
#       Points shape: (1024, 5)
#       Block index: 1392
#     block_61634
#       Points shape: (1024, 5)
#       Block index: 1393
#     block_61635
#       Points shape: (1024, 5)
#       Block index: 1394
#     block_61636
#       Points shape: (1024, 5)
#       Block index: 1395
#     block_61637
#       Points shape: (1024, 5)
#       Block index: 1396
#     block_61638
#       Points shape: (1024, 5)
#       Block index: 1397
#     block_61639
#       Points shape: (1024, 5)
#       Block index: 1398
#     block_61640
#       Points shape: (1024, 5)
#       Block index: 1399
#     block_61641
#       Points shape: (1024, 5)
#       Block index: 1400
#     block_61642
#       Points shape: (1024, 5)
#       Block index: 1401
#     block_61643
#       Points shape: (1024, 5)
#       Block index: 1402
#     block_61644
#       Points shape: (1024, 5)
#       Block index: 1403
#     block_61645
#       Points shape: (1024, 5)
#       Block index: 1404
#     block_61646
#       Points shape: (1024, 5)
#       Block index: 1405
#     block_61647
#       Points shape: (1024, 5)
#       Block index: 1406
#     block_61648
#       Points shape: (1024, 5)
#       Block index: 1407
#     block_61649
#       Points shape: (1024, 5)
#       Block index: 1408
#     block_61650
#       Points shape: (1024, 5)
#       Block index: 1409
#     block_61651
#       Points shape: (1024, 5)
#       Block index: 1410
#     block_61652
#       Points shape: (1024, 5)
#       Block index: 1411
#     block_61653
#       Points shape: (1024, 5)
#       Block index: 1412
#     block_61654
#       Points shape: (1024, 5)
#       Block index: 1413
#     block_61655
#       Points shape: (1024, 5)
#       Block index: 1414
#     block_61656
#       Points shape: (1024, 5)
#       Block index: 1415
#     block_61657
#       Points shape: (1024, 5)
#       Block index: 1416
#     block_61658
#       Points shape: (1024, 5)
#       Block index: 1417
#     block_61659
#       Points shape: (1024, 5)
#       Block index: 1418
#     block_61660
#       Points shape: (1024, 5)
#       Block index: 1419
#     block_61661
#       Points shape: (1024, 5)
#       Block index: 1420
#     block_61662
#       Points shape: (1024, 5)
#       Block index: 1421
#     block_61663
#       Points shape: (1024, 5)
#       Block index: 1422
#     block_61664
#       Points shape: (1024, 5)
#       Block index: 1423
#     block_61665
#       Points shape: (1024, 5)
#       Block index: 1424
#     block_61666
#       Points shape: (1024, 5)
#       Block index: 1425
#     block_61667
#       Points shape: (1024, 5)
#       Block index: 1426
#     block_61668
#       Points shape: (1024, 5)
#       Block index: 1427
#     block_61669
#       Points shape: (1024, 5)
#       Block index: 1428
#     block_61670
#       Points shape: (1024, 5)
#       Block index: 1429
#     block_61671
#       Points shape: (1024, 5)
#       Block index: 1430
#     block_61672
#       Points shape: (1024, 5)
#       Block index: 1431
#     block_61673
#       Points shape: (1024, 5)
#       Block index: 1432
#     block_61674
#       Points shape: (1024, 5)
#       Block index: 1433
#     block_61675
#       Points shape: (1024, 5)
#       Block index: 1434
#     block_61676
#       Points shape: (1024, 5)
#       Block index: 1435
#     block_61677
#       Points shape: (1024, 5)
#       Block index: 1436
#     block_61678
#       Points shape: (1024, 5)
#       Block index: 1437
#     block_61679
#       Points shape: (1024, 5)
#       Block index: 1438
#     block_61680
#       Points shape: (1024, 5)
#       Block index: 1439
#     block_61681
#       Points shape: (1024, 5)
#       Block index: 1440
#     block_61682
#       Points shape: (1024, 5)
#       Block index: 1441
#     block_61683
#       Points shape: (1024, 5)
#       Block index: 1442
#     block_61684
#       Points shape: (1024, 5)
#       Block index: 1443
#     block_61685
#       Points shape: (1024, 5)
#       Block index: 1444
#     block_61686
#       Points shape: (1024, 5)
#       Block index: 1445
#     block_61687
#       Points shape: (1024, 5)
#       Block index: 1446
#     block_61688
#       Points shape: (1024, 5)
#       Block index: 1447
#     block_61689
#       Points shape: (1024, 5)
#       Block index: 1448
#     block_61690
#       Points shape: (1024, 5)
#       Block index: 1449
#     block_61691
#       Points shape: (1024, 5)
#       Block index: 1450
#     block_61692
#       Points shape: (1024, 5)
#       Block index: 1451
#     block_61693
#       Points shape: (1024, 5)
#       Block index: 1452
#     block_61694
#       Points shape: (1024, 5)
#       Block index: 1453
#     block_61695
#       Points shape: (1024, 5)
#       Block index: 1454
#     block_61696
#       Points shape: (1024, 5)
#       Block index: 1455
#     block_61697
#       Points shape: (1024, 5)
#       Block index: 1456
#     block_61698
#       Points shape: (1024, 5)
#       Block index: 1457
#     block_61699
#       Points shape: (1024, 5)
#       Block index: 1458
#     block_61700
#       Points shape: (1024, 5)
#       Block index: 1459
#     block_61701
#       Points shape: (1024, 5)
#       Block index: 1460
#     block_61702
#       Points shape: (1024, 5)
#       Block index: 1461
#     block_61703
#       Points shape: (1024, 5)
#       Block index: 1462
#     block_61704
#       Points shape: (1024, 5)
#       Block index: 1463
#     block_61705
#       Points shape: (1024, 5)
#       Block index: 1464
#     block_61706
#       Points shape: (1024, 5)
#       Block index: 1465
#     block_61707
#       Points shape: (1024, 5)
#       Block index: 1466
#     block_61708
#       Points shape: (1024, 5)
#       Block index: 1467
#     block_61709
#       Points shape: (1024, 5)
#       Block index: 1468
#     block_61710
#       Points shape: (1024, 5)
#       Block index: 1469
#     block_61711
#       Points shape: (1024, 5)
#       Block index: 1470
#     block_61712
#       Points shape: (1024, 5)
#       Block index: 1471
#     block_61713
#       Points shape: (1024, 5)
#       Block index: 1472
#     block_61714
#       Points shape: (1024, 5)
#       Block index: 1473
#     block_61715
#       Points shape: (1024, 5)
#       Block index: 1474
#     block_61716
#       Points shape: (1024, 5)
#       Block index: 1475
#     block_61717
#       Points shape: (1024, 5)
#       Block index: 1476
#     block_61718
#       Points shape: (1024, 5)
#       Block index: 1477
#     block_61719
#       Points shape: (1024, 5)
#       Block index: 1478
#     block_61720
#       Points shape: (1024, 5)
#       Block index: 1479
#     block_61721
#       Points shape: (1024, 5)
#       Block index: 1480
#     block_61722
#       Points shape: (1024, 5)
#       Block index: 1481
#     block_61723
#       Points shape: (1024, 5)
#       Block index: 1482
#     block_61724
#       Points shape: (1024, 5)
#       Block index: 1483
#     block_61725
#       Points shape: (1024, 5)
#       Block index: 1484
#     block_61726
#       Points shape: (1024, 5)
#       Block index: 1485
#     block_61727
#       Points shape: (1024, 5)
#       Block index: 1486
#     block_61728
#       Points shape: (1024, 5)
#       Block index: 1487
#     block_61729
#       Points shape: (1024, 5)
#       Block index: 1488
#     block_61730
#       Points shape: (1024, 5)
#       Block index: 1489
#     block_61731
#       Points shape: (1024, 5)
#       Block index: 1490
#
# Voxel: voxel_-0.9315010070800795_-11.186700057983398_-3.79
#   Points shape: (5872, 5)
#   Voxel key: [ -0.93150101 -11.18670006  -3.79      ]
#   Blocks in this voxel:
#     block_58396
#       Points shape: (1024, 5)
#       Block index: 0
#     block_58397
#       Points shape: (1024, 5)
#       Block index: 1
#     block_58398
#       Points shape: (1024, 5)
#       Block index: 2
#     block_58399
#       Points shape: (1024, 5)
#       Block index: 3
#     block_58400
#       Points shape: (1024, 5)
#       Block index: 4
#
# Voxel: voxel_-0.9315010070800795_-12.986700057983398_-3.79
#   Points shape: (1355, 5)
#   Voxel key: [ -0.93150101 -12.98670006  -3.79      ]
#   Blocks in this voxel:

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import h5py
import numpy as np
import os
import matplotlib.pyplot as plt

# Step 1: Create a Custom Dataset
class PointCloudDataset(Dataset):
    def __init__(self, data_paths):
        super().__init__()
        self.data_paths = data_paths
        self.max_label = 0
        self.block_indices = []

        # Collect metadata without loading all data into memory
        for data_path in self.data_paths:
            with h5py.File(data_path, 'r') as h5f:
                blocks_grp = h5f['blocks']
                for block_name in blocks_grp:
                    self.block_indices.append((data_path, block_name))
                    block_grp = blocks_grp[block_name]
                    points = block_grp['points'][:]
                    label = points[0, -1]
                    if label > self.max_label:
                        self.max_label = label

    def __len__(self):
        return len(self.block_indices)

    def __getitem__(self, idx):
        data_path, block_name = self.block_indices[idx]
        with h5py.File(data_path, 'r') as h5f:
            block_grp = h5f['blocks'][block_name]
            point_block = block_grp['points'][:]  # Shape: (1024, 4) - (x, y, z, intensity)
        points = point_block[:, :4]  # XYZ + intensity
        label = int(point_block[0, -1])  # Assuming all points in the block have the same class label

        # Ensure label is within the valid range
        if label < 0 or label >= num_classes:
            raise ValueError(f"Label {label} is out of bounds for num_classes {num_classes}")

        return points, label

# Step 2: Define the PointNet++ Model (using a basic architecture for simplicity)
class PointNetPlusPlus(nn.Module):
    def __init__(self, num_classes):
        super(PointNetPlusPlus, self).__init__()
        # Simplified PointNet++ layers for feature learning
        self.sa1 = nn.Sequential(
            nn.Conv1d(4, 64, 1),
            nn.ReLU(),
            nn.Conv1d(64, 128, 1),
            nn.ReLU(),
            nn.Conv1d(128, 256, 1),
            nn.ReLU(),
        )
        self.fc1 = nn.Linear(256, 128)
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        x = x.transpose(2, 1)  # Input shape: (batch_size, num_points, num_features) -> (batch_size, num_features, num_points)
        x = self.sa1(x)
        x, _ = torch.max(x, 2)  # Global feature (max pooling)
        x = x.view(-1, 256)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Step 3: Training Loop
if __name__ == "__main__":
    # Dataset and DataLoader
    data_paths = [
        r"C:\Users\lukas\Desktop\pointcloud_blocks.h5",
        # Add more paths as needed
    ]
    dataset = PointCloudDataset(data_paths)
    num_classes = int(dataset.max_label) + 1  # Set num_classes based on the maximum label value in the dataset

    # Hyperparameters
    batch_size = 16
    num_epochs = 50
    learning_rate = 0.001

    # Dataset and DataLoader
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

    # Model, Loss, and Optimizer
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = PointNetPlusPlus(num_classes).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Training Loop
    loss_history = []
    accuracy_history = []
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        for i, (points, labels) in enumerate(dataloader):
            points, labels = points.to(device).float(), labels.to(device).long()
            optimizer.zero_grad()

            # Forward pass
            outputs = model(points)
            loss = criterion(outputs, labels)

            # Backward pass and optimization
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            # Calculate accuracy
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        epoch_loss = running_loss / len(dataloader)
        epoch_accuracy = 100 * correct / total
        loss_history.append(epoch_loss)
        accuracy_history.append(epoch_accuracy)
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%")

    # Plot the loss function and accuracy
    plt.figure()
    plt.subplot(2, 1, 1)
    plt.plot(range(1, num_epochs + 1), loss_history, marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training Loss over Epochs')
    plt.grid()

    plt.subplot(2, 1, 2)
    plt.plot(range(1, num_epochs + 1), accuracy_history, marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.title('Training Accuracy over Epochs')
    plt.grid()

    plt.tight_layout()
    plt.show()

    print("Training Finished!")

# %%
import h5py
import numpy as np

# Open the HDF5 file in read mode
with h5py.File(r"C:\Users\lukas\Desktop\pointcloud_blocks.h5", 'r') as h5f:
    # Ensure both 'voxels' and 'blocks' groups exist
    if 'voxels' in h5f and 'blocks' in h5f:
        voxels_grp = h5f['voxels']
        blocks_grp = h5f['blocks']
        
        print("Voxel and Block Structure:")

        # Iterate over each voxel group
        for voxel_name, voxel_grp in voxels_grp.items():
            # Print voxel details
            print(f"\nVoxel: {voxel_name}")
            print(f"  Points shape: {voxel_grp['points'].shape}")
            print(f"  Voxel key: {voxel_grp.attrs['voxel_key']}")

            # Find and print blocks associated with this voxel
            print("  Blocks in this voxel:")
            for block_name, block_grp in blocks_grp.items():
                # Use np.array_equal to compare voxel keys
                if np.array_equal(block_grp.attrs['voxel_key'], voxel_grp.attrs['voxel_key']):
                    print(f"    {block_name}")
                    print(f"      Points shape: {block_grp['points'].shape}")
                    print(f"      Block index: {block_grp.attrs['block_index']}")
                    
                    # Access the details of the first block and display them
                    if block_name == 'block_0':  # Adjust this based on the actual name of the first block
                        print("\nDetails of the first block:")
                        coordinates = block_grp['points'][:, :3]  # Assuming the first three columns are XYZ coordinates
                        rgb = block_grp['points'][:, 3:6]  # Assuming the next three columns are RGB
                        intensity = block_grp['points'][:, 6]  # Assuming the 7th column is intensity
                        classes = block_grp['points'][:, 7]  # Assuming the 8th column is class
                        
                        print("Coordinates:", coordinates)
                        print("RGB:", rgb)
                        print("Intensity:", intensity)
                        print("Class:", classes)
                        
                        break  # Stop after the first block for demonstration purposes

print("Voxel and Block information display complete.")
# Out:
# Voxel and Block Structure:
#
# Voxel: voxel_-0.9315010070800795_-0.386700057983397_-3.79
#   Points shape: (1526851, 5)
#   Voxel key: [-0.93150101 -0.38670006 -3.79      ]
#   Blocks in this voxel:
#     block_60241
#       Points shape: (1024, 5)
#       Block index: 0
#     block_60242
#       Points shape: (1024, 5)
#       Block index: 1
#     block_60243
#       Points shape: (1024, 5)
#       Block index: 2
#     block_60244
#       Points shape: (1024, 5)
#       Block index: 3
#     block_60245
#       Points shape: (1024, 5)
#       Block index: 4
#     block_60246
#       Points shape: (1024, 5)
#       Block index: 5
#     block_60247
#       Points shape: (1024, 5)
#       Block index: 6
#     block_60248
#       Points shape: (1024, 5)
#       Block index: 7
#     block_60249
#       Points shape: (1024, 5)
#       Block index: 8
#     block_60250
#       Points shape: (1024, 5)
#       Block index: 9
#     block_60251
#       Points shape: (1024, 5)
#       Block index: 10
#     block_60252
#       Points shape: (1024, 5)
#       Block index: 11
#     block_60253
#       Points shape: (1024, 5)
#       Block index: 12
#     block_60254
#       Points shape: (1024, 5)
#       Block index: 13
#     block_60255
#       Points shape: (1024, 5)
#       Block index: 14
#     block_60256
#       Points shape: (1024, 5)
#       Block index: 15
#     block_60257
#       Points shape: (1024, 5)
#       Block index: 16
#     block_60258
#       Points shape: (1024, 5)
#       Block index: 17
#     block_60259
#       Points shape: (1024, 5)
#       Block index: 18
#     block_60260
#       Points shape: (1024, 5)
#       Block index: 19
#     block_60261
#       Points shape: (1024, 5)
#       Block index: 20
#     block_60262
#       Points shape: (1024, 5)
#       Block index: 21
#     block_60263
#       Points shape: (1024, 5)
#       Block index: 22
#     block_60264
#       Points shape: (1024, 5)
#       Block index: 23
#     block_60265
#       Points shape: (1024, 5)
#       Block index: 24
#     block_60266
#       Points shape: (1024, 5)
#       Block index: 25
#     block_60267
#       Points shape: (1024, 5)
#       Block index: 26
#     block_60268
#       Points shape: (1024, 5)
#       Block index: 27
#     block_60269
#       Points shape: (1024, 5)
#       Block index: 28
#     block_60270
#       Points shape: (1024, 5)
#       Block index: 29
#     block_60271
#       Points shape: (1024, 5)
#       Block index: 30
#     block_60272
#       Points shape: (1024, 5)
#       Block index: 31
#     block_60273
#       Points shape: (1024, 5)
#       Block index: 32
#     block_60274
#       Points shape: (1024, 5)
#       Block index: 33
#     block_60275
#       Points shape: (1024, 5)
#       Block index: 34
#     block_60276
#       Points shape: (1024, 5)
#       Block index: 35
#     block_60277
#       Points shape: (1024, 5)
#       Block index: 36
#     block_60278
#       Points shape: (1024, 5)
#       Block index: 37
#     block_60279
#       Points shape: (1024, 5)
#       Block index: 38
#     block_60280
#       Points shape: (1024, 5)
#       Block index: 39
#     block_60281
#       Points shape: (1024, 5)
#       Block index: 40
#     block_60282
#       Points shape: (1024, 5)
#       Block index: 41
#     block_60283
#       Points shape: (1024, 5)
#       Block index: 42
#     block_60284
#       Points shape: (1024, 5)
#       Block index: 43
#     block_60285
#       Points shape: (1024, 5)
#       Block index: 44
#     block_60286
#       Points shape: (1024, 5)
#       Block index: 45
#     block_60287
#       Points shape: (1024, 5)
#       Block index: 46
#     block_60288
#       Points shape: (1024, 5)
#       Block index: 47
#     block_60289
#       Points shape: (1024, 5)
#       Block index: 48
#     block_60290
#       Points shape: (1024, 5)
#       Block index: 49
#     block_60291
#       Points shape: (1024, 5)
#       Block index: 50
#     block_60292
#       Points shape: (1024, 5)
#       Block index: 51
#     block_60293
#       Points shape: (1024, 5)
#       Block index: 52
#     block_60294
#       Points shape: (1024, 5)
#       Block index: 53
#     block_60295
#       Points shape: (1024, 5)
#       Block index: 54
#     block_60296
#       Points shape: (1024, 5)
#       Block index: 55
#     block_60297
#       Points shape: (1024, 5)
#       Block index: 56
#     block_60298
#       Points shape: (1024, 5)
#       Block index: 57
#     block_60299
#       Points shape: (1024, 5)
#       Block index: 58
#     block_60300
#       Points shape: (1024, 5)
#       Block index: 59
#     block_60301
#       Points shape: (1024, 5)
#       Block index: 60
#     block_60302
#       Points shape: (1024, 5)
#       Block index: 61
#     block_60303
#       Points shape: (1024, 5)
#       Block index: 62
#     block_60304
#       Points shape: (1024, 5)
#       Block index: 63
#     block_60305
#       Points shape: (1024, 5)
#       Block index: 64
#     block_60306
#       Points shape: (1024, 5)
#       Block index: 65
#     block_60307
#       Points shape: (1024, 5)
#       Block index: 66
#     block_60308
#       Points shape: (1024, 5)
#       Block index: 67
#     block_60309
#       Points shape: (1024, 5)
#       Block index: 68
#     block_60310
#       Points shape: (1024, 5)
#       Block index: 69
#     block_60311
#       Points shape: (1024, 5)
#       Block index: 70
#     block_60312
#       Points shape: (1024, 5)
#       Block index: 71
#     block_60313
#       Points shape: (1024, 5)
#       Block index: 72
#     block_60314
#       Points shape: (1024, 5)
#       Block index: 73
#     block_60315
#       Points shape: (1024, 5)
#       Block index: 74
#     block_60316
#       Points shape: (1024, 5)
#       Block index: 75
#     block_60317
#       Points shape: (1024, 5)
#       Block index: 76
#     block_60318
#       Points shape: (1024, 5)
#       Block index: 77
#     block_60319
#       Points shape: (1024, 5)
#       Block index: 78
#     block_60320
#       Points shape: (1024, 5)
#       Block index: 79
#     block_60321
#       Points shape: (1024, 5)
#       Block index: 80
#     block_60322
#       Points shape: (1024, 5)
#       Block index: 81
#     block_60323
#       Points shape: (1024, 5)
#       Block index: 82
#     block_60324
#       Points shape: (1024, 5)
#       Block index: 83
#     block_60325
#       Points shape: (1024, 5)
#       Block index: 84
#     block_60326
#       Points shape: (1024, 5)
#       Block index: 85
#     block_60327
#       Points shape: (1024, 5)
#       Block index: 86
#     block_60328
#       Points shape: (1024, 5)
#       Block index: 87
#     block_60329
#       Points shape: (1024, 5)
#       Block index: 88
#     block_60330
#       Points shape: (1024, 5)
#       Block index: 89
#     block_60331
#       Points shape: (1024, 5)
#       Block index: 90
#     block_60332
#       Points shape: (1024, 5)
#       Block index: 91
#     block_60333
#       Points shape: (1024, 5)
#       Block index: 92
#     block_60334
#       Points shape: (1024, 5)
#       Block index: 93
#     block_60335
#       Points shape: (1024, 5)
#       Block index: 94
#     block_60336
#       Points shape: (1024, 5)
#       Block index: 95
#     block_60337
#       Points shape: (1024, 5)
#       Block index: 96
#     block_60338
#       Points shape: (1024, 5)
#       Block index: 97
#     block_60339
#       Points shape: (1024, 5)
#       Block index: 98
#     block_60340
#       Points shape: (1024, 5)
#       Block index: 99
#     block_60341
#       Points shape: (1024, 5)
#       Block index: 100
#     block_60342
#       Points shape: (1024, 5)
#       Block index: 101
#     block_60343
#       Points shape: (1024, 5)
#       Block index: 102
#     block_60344
#       Points shape: (1024, 5)
#       Block index: 103
#     block_60345
#       Points shape: (1024, 5)
#       Block index: 104
#     block_60346
#       Points shape: (1024, 5)
#       Block index: 105
#     block_60347
#       Points shape: (1024, 5)
#       Block index: 106
#     block_60348
#       Points shape: (1024, 5)
#       Block index: 107
#     block_60349
#       Points shape: (1024, 5)
#       Block index: 108
#     block_60350
#       Points shape: (1024, 5)
#       Block index: 109
#     block_60351
#       Points shape: (1024, 5)
#       Block index: 110
#     block_60352
#       Points shape: (1024, 5)
#       Block index: 111
#     block_60353
#       Points shape: (1024, 5)
#       Block index: 112
#     block_60354
#       Points shape: (1024, 5)
#       Block index: 113
#     block_60355
#       Points shape: (1024, 5)
#       Block index: 114
#     block_60356
#       Points shape: (1024, 5)
#       Block index: 115
#     block_60357
#       Points shape: (1024, 5)
#       Block index: 116
#     block_60358
#       Points shape: (1024, 5)
#       Block index: 117
#     block_60359
#       Points shape: (1024, 5)
#       Block index: 118
#     block_60360
#       Points shape: (1024, 5)
#       Block index: 119
#     block_60361
#       Points shape: (1024, 5)
#       Block index: 120
#     block_60362
#       Points shape: (1024, 5)
#       Block index: 121
#     block_60363
#       Points shape: (1024, 5)
#       Block index: 122
#     block_60364
#       Points shape: (1024, 5)
#       Block index: 123
#     block_60365
#       Points shape: (1024, 5)
#       Block index: 124
#     block_60366
#       Points shape: (1024, 5)
#       Block index: 125
#     block_60367
#       Points shape: (1024, 5)
#       Block index: 126
#     block_60368
#       Points shape: (1024, 5)
#       Block index: 127
#     block_60369
#       Points shape: (1024, 5)
#       Block index: 128
#     block_60370
#       Points shape: (1024, 5)
#       Block index: 129
#     block_60371
#       Points shape: (1024, 5)
#       Block index: 130
#     block_60372
#       Points shape: (1024, 5)
#       Block index: 131
#     block_60373
#       Points shape: (1024, 5)
#       Block index: 132
#     block_60374
#       Points shape: (1024, 5)
#       Block index: 133
#     block_60375
#       Points shape: (1024, 5)
#       Block index: 134
#     block_60376
#       Points shape: (1024, 5)
#       Block index: 135
#     block_60377
#       Points shape: (1024, 5)
#       Block index: 136
#     block_60378
#       Points shape: (1024, 5)
#       Block index: 137
#     block_60379
#       Points shape: (1024, 5)
#       Block index: 138
#     block_60380
#       Points shape: (1024, 5)
#       Block index: 139
#     block_60381
#       Points shape: (1024, 5)
#       Block index: 140
#     block_60382
#       Points shape: (1024, 5)
#       Block index: 141
#     block_60383
#       Points shape: (1024, 5)
#       Block index: 142
#     block_60384
#       Points shape: (1024, 5)
#       Block index: 143
#     block_60385
#       Points shape: (1024, 5)
#       Block index: 144
#     block_60386
#       Points shape: (1024, 5)
#       Block index: 145
#     block_60387
#       Points shape: (1024, 5)
#       Block index: 146
#     block_60388
#       Points shape: (1024, 5)
#       Block index: 147
#     block_60389
#       Points shape: (1024, 5)
#       Block index: 148
#     block_60390
#       Points shape: (1024, 5)
#       Block index: 149
#     block_60391
#       Points shape: (1024, 5)
#       Block index: 150
#     block_60392
#       Points shape: (1024, 5)
#       Block index: 151
#     block_60393
#       Points shape: (1024, 5)
#       Block index: 152
#     block_60394
#       Points shape: (1024, 5)
#       Block index: 153
#     block_60395
#       Points shape: (1024, 5)
#       Block index: 154
#     block_60396
#       Points shape: (1024, 5)
#       Block index: 155
#     block_60397
#       Points shape: (1024, 5)
#       Block index: 156
#     block_60398
#       Points shape: (1024, 5)
#       Block index: 157
#     block_60399
#       Points shape: (1024, 5)
#       Block index: 158
#     block_60400
#       Points shape: (1024, 5)
#       Block index: 159
#     block_60401
#       Points shape: (1024, 5)
#       Block index: 160
#     block_60402
#       Points shape: (1024, 5)
#       Block index: 161
#     block_60403
#       Points shape: (1024, 5)
#       Block index: 162
#     block_60404
#       Points shape: (1024, 5)
#       Block index: 163
#     block_60405
#       Points shape: (1024, 5)
#       Block index: 164
#     block_60406
#       Points shape: (1024, 5)
#       Block index: 165
#     block_60407
#       Points shape: (1024, 5)
#       Block index: 166
#     block_60408
#       Points shape: (1024, 5)
#       Block index: 167
#     block_60409
#       Points shape: (1024, 5)
#       Block index: 168
#     block_60410
#       Points shape: (1024, 5)
#       Block index: 169
#     block_60411
#       Points shape: (1024, 5)
#       Block index: 170
#     block_60412
#       Points shape: (1024, 5)
#       Block index: 171
#     block_60413
#       Points shape: (1024, 5)
#       Block index: 172
#     block_60414
#       Points shape: (1024, 5)
#       Block index: 173
#     block_60415
#       Points shape: (1024, 5)
#       Block index: 174
#     block_60416
#       Points shape: (1024, 5)
#       Block index: 175
#     block_60417
#       Points shape: (1024, 5)
#       Block index: 176
#     block_60418
#       Points shape: (1024, 5)
#       Block index: 177
#     block_60419
#       Points shape: (1024, 5)
#       Block index: 178
#     block_60420
#       Points shape: (1024, 5)
#       Block index: 179
#     block_60421
#       Points shape: (1024, 5)
#       Block index: 180
#     block_60422
#       Points shape: (1024, 5)
#       Block index: 181
#     block_60423
#       Points shape: (1024, 5)
#       Block index: 182
#     block_60424
#       Points shape: (1024, 5)
#       Block index: 183
#     block_60425
#       Points shape: (1024, 5)
#       Block index: 184
#     block_60426
#       Points shape: (1024, 5)
#       Block index: 185
#     block_60427
#       Points shape: (1024, 5)
#       Block index: 186
#     block_60428
#       Points shape: (1024, 5)
#       Block index: 187
#     block_60429
#       Points shape: (1024, 5)
#       Block index: 188
#     block_60430
#       Points shape: (1024, 5)
#       Block index: 189
#     block_60431
#       Points shape: (1024, 5)
#       Block index: 190
#     block_60432
#       Points shape: (1024, 5)
#       Block index: 191
#     block_60433
#       Points shape: (1024, 5)
#       Block index: 192
#     block_60434
#       Points shape: (1024, 5)
#       Block index: 193
#     block_60435
#       Points shape: (1024, 5)
#       Block index: 194
#     block_60436
#       Points shape: (1024, 5)
#       Block index: 195
#     block_60437
#       Points shape: (1024, 5)
#       Block index: 196
#     block_60438
#       Points shape: (1024, 5)
#       Block index: 197
#     block_60439
#       Points shape: (1024, 5)
#       Block index: 198
#     block_60440
#       Points shape: (1024, 5)
#       Block index: 199
#     block_60441
#       Points shape: (1024, 5)
#       Block index: 200
#     block_60442
#       Points shape: (1024, 5)
#       Block index: 201
#     block_60443
#       Points shape: (1024, 5)
#       Block index: 202
#     block_60444
#       Points shape: (1024, 5)
#       Block index: 203
#     block_60445
#       Points shape: (1024, 5)
#       Block index: 204
#     block_60446
#       Points shape: (1024, 5)
#       Block index: 205
#     block_60447
#       Points shape: (1024, 5)
#       Block index: 206
#     block_60448
#       Points shape: (1024, 5)
#       Block index: 207
#     block_60449
#       Points shape: (1024, 5)
#       Block index: 208
#     block_60450
#       Points shape: (1024, 5)
#       Block index: 209
#     block_60451
#       Points shape: (1024, 5)
#       Block index: 210
#     block_60452
#       Points shape: (1024, 5)
#       Block index: 211
#     block_60453
#       Points shape: (1024, 5)
#       Block index: 212
#     block_60454
#       Points shape: (1024, 5)
#       Block index: 213
#     block_60455
#       Points shape: (1024, 5)
#       Block index: 214
#     block_60456
#       Points shape: (1024, 5)
#       Block index: 215
#     block_60457
#       Points shape: (1024, 5)
#       Block index: 216
#     block_60458
#       Points shape: (1024, 5)
#       Block index: 217
#     block_60459
#       Points shape: (1024, 5)
#       Block index: 218
#     block_60460
#       Points shape: (1024, 5)
#       Block index: 219
#     block_60461
#       Points shape: (1024, 5)
#       Block index: 220
#     block_60462
#       Points shape: (1024, 5)
#       Block index: 221
#     block_60463
#       Points shape: (1024, 5)
#       Block index: 222
#     block_60464
#       Points shape: (1024, 5)
#       Block index: 223
#     block_60465
#       Points shape: (1024, 5)
#       Block index: 224
#     block_60466
#       Points shape: (1024, 5)
#       Block index: 225
#     block_60467
#       Points shape: (1024, 5)
#       Block index: 226
#     block_60468
#       Points shape: (1024, 5)
#       Block index: 227
#     block_60469
#       Points shape: (1024, 5)
#       Block index: 228
#     block_60470
#       Points shape: (1024, 5)
#       Block index: 229
#     block_60471
#       Points shape: (1024, 5)
#       Block index: 230
#     block_60472
#       Points shape: (1024, 5)
#       Block index: 231
#     block_60473
#       Points shape: (1024, 5)
#       Block index: 232
#     block_60474
#       Points shape: (1024, 5)
#       Block index: 233
#     block_60475
#       Points shape: (1024, 5)
#       Block index: 234
#     block_60476
#       Points shape: (1024, 5)
#       Block index: 235
#     block_60477
#       Points shape: (1024, 5)
#       Block index: 236
#     block_60478
#       Points shape: (1024, 5)
#       Block index: 237
#     block_60479
#       Points shape: (1024, 5)
#       Block index: 238
#     block_60480
#       Points shape: (1024, 5)
#       Block index: 239
#     block_60481
#       Points shape: (1024, 5)
#       Block index: 240
#     block_60482
#       Points shape: (1024, 5)
#       Block index: 241
#     block_60483
#       Points shape: (1024, 5)
#       Block index: 242
#     block_60484
#       Points shape: (1024, 5)
#       Block index: 243
#     block_60485
#       Points shape: (1024, 5)
#       Block index: 244
#     block_60486
#       Points shape: (1024, 5)
#       Block index: 245
#     block_60487
#       Points shape: (1024, 5)
#       Block index: 246
#     block_60488
#       Points shape: (1024, 5)
#       Block index: 247
#     block_60489
#       Points shape: (1024, 5)
#       Block index: 248
#     block_60490
#       Points shape: (1024, 5)
#       Block index: 249
#     block_60491
#       Points shape: (1024, 5)
#       Block index: 250
#     block_60492
#       Points shape: (1024, 5)
#       Block index: 251
#     block_60493
#       Points shape: (1024, 5)
#       Block index: 252
#     block_60494
#       Points shape: (1024, 5)
#       Block index: 253
#     block_60495
#       Points shape: (1024, 5)
#       Block index: 254
#     block_60496
#       Points shape: (1024, 5)
#       Block index: 255
#     block_60497
#       Points shape: (1024, 5)
#       Block index: 256
#     block_60498
#       Points shape: (1024, 5)
#       Block index: 257
#     block_60499
#       Points shape: (1024, 5)
#       Block index: 258
#     block_60500
#       Points shape: (1024, 5)
#       Block index: 259
#     block_60501
#       Points shape: (1024, 5)
#       Block index: 260
#     block_60502
#       Points shape: (1024, 5)
#       Block index: 261
#     block_60503
#       Points shape: (1024, 5)
#       Block index: 262
#     block_60504
#       Points shape: (1024, 5)
#       Block index: 263
#     block_60505
#       Points shape: (1024, 5)
#       Block index: 264
#     block_60506
#       Points shape: (1024, 5)
#       Block index: 265
#     block_60507
#       Points shape: (1024, 5)
#       Block index: 266
#     block_60508
#       Points shape: (1024, 5)
#       Block index: 267
#     block_60509
#       Points shape: (1024, 5)
#       Block index: 268
#     block_60510
#       Points shape: (1024, 5)
#       Block index: 269
#     block_60511
#       Points shape: (1024, 5)
#       Block index: 270
#     block_60512
#       Points shape: (1024, 5)
#       Block index: 271
#     block_60513
#       Points shape: (1024, 5)
#       Block index: 272
#     block_60514
#       Points shape: (1024, 5)
#       Block index: 273
#     block_60515
#       Points shape: (1024, 5)
#       Block index: 274
#     block_60516
#       Points shape: (1024, 5)
#       Block index: 275
#     block_60517
#       Points shape: (1024, 5)
#       Block index: 276
#     block_60518
#       Points shape: (1024, 5)
#       Block index: 277
#     block_60519
#       Points shape: (1024, 5)
#       Block index: 278
#     block_60520
#       Points shape: (1024, 5)
#       Block index: 279
#     block_60521
#       Points shape: (1024, 5)
#       Block index: 280
#     block_60522
#       Points shape: (1024, 5)
#       Block index: 281
#     block_60523
#       Points shape: (1024, 5)
#       Block index: 282
#     block_60524
#       Points shape: (1024, 5)
#       Block index: 283
#     block_60525
#       Points shape: (1024, 5)
#       Block index: 284
#     block_60526
#       Points shape: (1024, 5)
#       Block index: 285
#     block_60527
#       Points shape: (1024, 5)
#       Block index: 286
#     block_60528
#       Points shape: (1024, 5)
#       Block index: 287
#     block_60529
#       Points shape: (1024, 5)
#       Block index: 288
#     block_60530
#       Points shape: (1024, 5)
#       Block index: 289
#     block_60531
#       Points shape: (1024, 5)
#       Block index: 290
#     block_60532
#       Points shape: (1024, 5)
#       Block index: 291
#     block_60533
#       Points shape: (1024, 5)
#       Block index: 292
#     block_60534
#       Points shape: (1024, 5)
#       Block index: 293
#     block_60535
#       Points shape: (1024, 5)
#       Block index: 294
#     block_60536
#       Points shape: (1024, 5)
#       Block index: 295
#     block_60537
#       Points shape: (1024, 5)
#       Block index: 296
#     block_60538
#       Points shape: (1024, 5)
#       Block index: 297
#     block_60539
#       Points shape: (1024, 5)
#       Block index: 298
#     block_60540
#       Points shape: (1024, 5)
#       Block index: 299
#     block_60541
#       Points shape: (1024, 5)
#       Block index: 300
#     block_60542
#       Points shape: (1024, 5)
#       Block index: 301
#     block_60543
#       Points shape: (1024, 5)
#       Block index: 302
#     block_60544
#       Points shape: (1024, 5)
#       Block index: 303
#     block_60545
#       Points shape: (1024, 5)
#       Block index: 304
#     block_60546
#       Points shape: (1024, 5)
#       Block index: 305
#     block_60547
#       Points shape: (1024, 5)
#       Block index: 306
#     block_60548
#       Points shape: (1024, 5)
#       Block index: 307
#     block_60549
#       Points shape: (1024, 5)
#       Block index: 308
#     block_60550
#       Points shape: (1024, 5)
#       Block index: 309
#     block_60551
#       Points shape: (1024, 5)
#       Block index: 310
#     block_60552
#       Points shape: (1024, 5)
#       Block index: 311
#     block_60553
#       Points shape: (1024, 5)
#       Block index: 312
#     block_60554
#       Points shape: (1024, 5)
#       Block index: 313
#     block_60555
#       Points shape: (1024, 5)
#       Block index: 314
#     block_60556
#       Points shape: (1024, 5)
#       Block index: 315
#     block_60557
#       Points shape: (1024, 5)
#       Block index: 316
#     block_60558
#       Points shape: (1024, 5)
#       Block index: 317
#     block_60559
#       Points shape: (1024, 5)
#       Block index: 318
#     block_60560
#       Points shape: (1024, 5)
#       Block index: 319
#     block_60561
#       Points shape: (1024, 5)
#       Block index: 320
#     block_60562
#       Points shape: (1024, 5)
#       Block index: 321
#     block_60563
#       Points shape: (1024, 5)
#       Block index: 322
#     block_60564
#       Points shape: (1024, 5)
#       Block index: 323
#     block_60565
#       Points shape: (1024, 5)
#       Block index: 324
#     block_60566
#       Points shape: (1024, 5)
#       Block index: 325
#     block_60567
#       Points shape: (1024, 5)
#       Block index: 326
#     block_60568
#       Points shape: (1024, 5)
#       Block index: 327
#     block_60569
#       Points shape: (1024, 5)
#       Block index: 328
#     block_60570
#       Points shape: (1024, 5)
#       Block index: 329
#     block_60571
#       Points shape: (1024, 5)
#       Block index: 330
#     block_60572
#       Points shape: (1024, 5)
#       Block index: 331
#     block_60573
#       Points shape: (1024, 5)
#       Block index: 332
#     block_60574
#       Points shape: (1024, 5)
#       Block index: 333
#     block_60575
#       Points shape: (1024, 5)
#       Block index: 334
#     block_60576
#       Points shape: (1024, 5)
#       Block index: 335
#     block_60577
#       Points shape: (1024, 5)
#       Block index: 336
#     block_60578
#       Points shape: (1024, 5)
#       Block index: 337
#     block_60579
#       Points shape: (1024, 5)
#       Block index: 338
#     block_60580
#       Points shape: (1024, 5)
#       Block index: 339
#     block_60581
#       Points shape: (1024, 5)
#       Block index: 340
#     block_60582
#       Points shape: (1024, 5)
#       Block index: 341
#     block_60583
#       Points shape: (1024, 5)
#       Block index: 342
#     block_60584
#       Points shape: (1024, 5)
#       Block index: 343
#     block_60585
#       Points shape: (1024, 5)
#       Block index: 344
#     block_60586
#       Points shape: (1024, 5)
#       Block index: 345
#     block_60587
#       Points shape: (1024, 5)
#       Block index: 346
#     block_60588
#       Points shape: (1024, 5)
#       Block index: 347
#     block_60589
#       Points shape: (1024, 5)
#       Block index: 348
#     block_60590
#       Points shape: (1024, 5)
#       Block index: 349
#     block_60591
#       Points shape: (1024, 5)
#       Block index: 350
#     block_60592
#       Points shape: (1024, 5)
#       Block index: 351
#     block_60593
#       Points shape: (1024, 5)
#       Block index: 352
#     block_60594
#       Points shape: (1024, 5)
#       Block index: 353
#     block_60595
#       Points shape: (1024, 5)
#       Block index: 354
#     block_60596
#       Points shape: (1024, 5)
#       Block index: 355
#     block_60597
#       Points shape: (1024, 5)
#       Block index: 356
#     block_60598
#       Points shape: (1024, 5)
#       Block index: 357
#     block_60599
#       Points shape: (1024, 5)
#       Block index: 358
#     block_60600
#       Points shape: (1024, 5)
#       Block index: 359
#     block_60601
#       Points shape: (1024, 5)
#       Block index: 360
#     block_60602
#       Points shape: (1024, 5)
#       Block index: 361
#     block_60603
#       Points shape: (1024, 5)
#       Block index: 362
#     block_60604
#       Points shape: (1024, 5)
#       Block index: 363
#     block_60605
#       Points shape: (1024, 5)
#       Block index: 364
#     block_60606
#       Points shape: (1024, 5)
#       Block index: 365
#     block_60607
#       Points shape: (1024, 5)
#       Block index: 366
#     block_60608
#       Points shape: (1024, 5)
#       Block index: 367
#     block_60609
#       Points shape: (1024, 5)
#       Block index: 368
#     block_60610
#       Points shape: (1024, 5)
#       Block index: 369
#     block_60611
#       Points shape: (1024, 5)
#       Block index: 370
#     block_60612
#       Points shape: (1024, 5)
#       Block index: 371
#     block_60613
#       Points shape: (1024, 5)
#       Block index: 372
#     block_60614
#       Points shape: (1024, 5)
#       Block index: 373
#     block_60615
#       Points shape: (1024, 5)
#       Block index: 374
#     block_60616
#       Points shape: (1024, 5)
#       Block index: 375
#     block_60617
#       Points shape: (1024, 5)
#       Block index: 376
#     block_60618
#       Points shape: (1024, 5)
#       Block index: 377
#     block_60619
#       Points shape: (1024, 5)
#       Block index: 378
#     block_60620
#       Points shape: (1024, 5)
#       Block index: 379
#     block_60621
#       Points shape: (1024, 5)
#       Block index: 380
#     block_60622
#       Points shape: (1024, 5)
#       Block index: 381
#     block_60623
#       Points shape: (1024, 5)
#       Block index: 382
#     block_60624
#       Points shape: (1024, 5)
#       Block index: 383
#     block_60625
#       Points shape: (1024, 5)
#       Block index: 384
#     block_60626
#       Points shape: (1024, 5)
#       Block index: 385
#     block_60627
#       Points shape: (1024, 5)
#       Block index: 386
#     block_60628
#       Points shape: (1024, 5)
#       Block index: 387
#     block_60629
#       Points shape: (1024, 5)
#       Block index: 388
#     block_60630
#       Points shape: (1024, 5)
#       Block index: 389
#     block_60631
#       Points shape: (1024, 5)
#       Block index: 390
#     block_60632
#       Points shape: (1024, 5)
#       Block index: 391
#     block_60633
#       Points shape: (1024, 5)
#       Block index: 392
#     block_60634
#       Points shape: (1024, 5)
#       Block index: 393
#     block_60635
#       Points shape: (1024, 5)
#       Block index: 394
#     block_60636
#       Points shape: (1024, 5)
#       Block index: 395
#     block_60637
#       Points shape: (1024, 5)
#       Block index: 396
#     block_60638
#       Points shape: (1024, 5)
#       Block index: 397
#     block_60639
#       Points shape: (1024, 5)
#       Block index: 398
#     block_60640
#       Points shape: (1024, 5)
#       Block index: 399
#     block_60641
#       Points shape: (1024, 5)
#       Block index: 400
#     block_60642
#       Points shape: (1024, 5)
#       Block index: 401
#     block_60643
#       Points shape: (1024, 5)
#       Block index: 402
#     block_60644
#       Points shape: (1024, 5)
#       Block index: 403
#     block_60645
#       Points shape: (1024, 5)
#       Block index: 404
#     block_60646
#       Points shape: (1024, 5)
#       Block index: 405
#     block_60647
#       Points shape: (1024, 5)
#       Block index: 406
#     block_60648
#       Points shape: (1024, 5)
#       Block index: 407
#     block_60649
#       Points shape: (1024, 5)
#       Block index: 408
#     block_60650
#       Points shape: (1024, 5)
#       Block index: 409
#     block_60651
#       Points shape: (1024, 5)
#       Block index: 410
#     block_60652
#       Points shape: (1024, 5)
#       Block index: 411
#     block_60653
#       Points shape: (1024, 5)
#       Block index: 412
#     block_60654
#       Points shape: (1024, 5)
#       Block index: 413
#     block_60655
#       Points shape: (1024, 5)
#       Block index: 414
#     block_60656
#       Points shape: (1024, 5)
#       Block index: 415
#     block_60657
#       Points shape: (1024, 5)
#       Block index: 416
#     block_60658
#       Points shape: (1024, 5)
#       Block index: 417
#     block_60659
#       Points shape: (1024, 5)
#       Block index: 418
#     block_60660
#       Points shape: (1024, 5)
#       Block index: 419
#     block_60661
#       Points shape: (1024, 5)
#       Block index: 420
#     block_60662
#       Points shape: (1024, 5)
#       Block index: 421
#     block_60663
#       Points shape: (1024, 5)
#       Block index: 422
#     block_60664
#       Points shape: (1024, 5)
#       Block index: 423
#     block_60665
#       Points shape: (1024, 5)
#       Block index: 424
#     block_60666
#       Points shape: (1024, 5)
#       Block index: 425
#     block_60667
#       Points shape: (1024, 5)
#       Block index: 426
#     block_60668
#       Points shape: (1024, 5)
#       Block index: 427
#     block_60669
#       Points shape: (1024, 5)
#       Block index: 428
#     block_60670
#       Points shape: (1024, 5)
#       Block index: 429
#     block_60671
#       Points shape: (1024, 5)
#       Block index: 430
#     block_60672
#       Points shape: (1024, 5)
#       Block index: 431
#     block_60673
#       Points shape: (1024, 5)
#       Block index: 432
#     block_60674
#       Points shape: (1024, 5)
#       Block index: 433
#     block_60675
#       Points shape: (1024, 5)
#       Block index: 434
#     block_60676
#       Points shape: (1024, 5)
#       Block index: 435
#     block_60677
#       Points shape: (1024, 5)
#       Block index: 436
#     block_60678
#       Points shape: (1024, 5)
#       Block index: 437
#     block_60679
#       Points shape: (1024, 5)
#       Block index: 438
#     block_60680
#       Points shape: (1024, 5)
#       Block index: 439
#     block_60681
#       Points shape: (1024, 5)
#       Block index: 440
#     block_60682
#       Points shape: (1024, 5)
#       Block index: 441
#     block_60683
#       Points shape: (1024, 5)
#       Block index: 442
#     block_60684
#       Points shape: (1024, 5)
#       Block index: 443
#     block_60685
#       Points shape: (1024, 5)
#       Block index: 444
#     block_60686
#       Points shape: (1024, 5)
#       Block index: 445
#     block_60687
#       Points shape: (1024, 5)
#       Block index: 446
#     block_60688
#       Points shape: (1024, 5)
#       Block index: 447
#     block_60689
#       Points shape: (1024, 5)
#       Block index: 448
#     block_60690
#       Points shape: (1024, 5)
#       Block index: 449
#     block_60691
#       Points shape: (1024, 5)
#       Block index: 450
#     block_60692
#       Points shape: (1024, 5)
#       Block index: 451
#     block_60693
#       Points shape: (1024, 5)
#       Block index: 452
#     block_60694
#       Points shape: (1024, 5)
#       Block index: 453
#     block_60695
#       Points shape: (1024, 5)
#       Block index: 454
#     block_60696
#       Points shape: (1024, 5)
#       Block index: 455
#     block_60697
#       Points shape: (1024, 5)
#       Block index: 456
#     block_60698
#       Points shape: (1024, 5)
#       Block index: 457
#     block_60699
#       Points shape: (1024, 5)
#       Block index: 458
#     block_60700
#       Points shape: (1024, 5)
#       Block index: 459
#     block_60701
#       Points shape: (1024, 5)
#       Block index: 460
#     block_60702
#       Points shape: (1024, 5)
#       Block index: 461
#     block_60703
#       Points shape: (1024, 5)
#       Block index: 462
#     block_60704
#       Points shape: (1024, 5)
#       Block index: 463
#     block_60705
#       Points shape: (1024, 5)
#       Block index: 464
#     block_60706
#       Points shape: (1024, 5)
#       Block index: 465
#     block_60707
#       Points shape: (1024, 5)
#       Block index: 466
#     block_60708
#       Points shape: (1024, 5)
#       Block index: 467
#     block_60709
#       Points shape: (1024, 5)
#       Block index: 468
#     block_60710
#       Points shape: (1024, 5)
#       Block index: 469
#     block_60711
#       Points shape: (1024, 5)
#       Block index: 470
#     block_60712
#       Points shape: (1024, 5)
#       Block index: 471
#     block_60713
#       Points shape: (1024, 5)
#       Block index: 472
#     block_60714
#       Points shape: (1024, 5)
#       Block index: 473
#     block_60715
#       Points shape: (1024, 5)
#       Block index: 474
#     block_60716
#       Points shape: (1024, 5)
#       Block index: 475
#     block_60717
#       Points shape: (1024, 5)
#       Block index: 476
#     block_60718
#       Points shape: (1024, 5)
#       Block index: 477
#     block_60719
#       Points shape: (1024, 5)
#       Block index: 478
#     block_60720
#       Points shape: (1024, 5)
#       Block index: 479
#     block_60721
#       Points shape: (1024, 5)
#       Block index: 480
#     block_60722
#       Points shape: (1024, 5)
#       Block index: 481
#     block_60723
#       Points shape: (1024, 5)
#       Block index: 482
#     block_60724
#       Points shape: (1024, 5)
#       Block index: 483
#     block_60725
#       Points shape: (1024, 5)
#       Block index: 484
#     block_60726
#       Points shape: (1024, 5)
#       Block index: 485
#     block_60727
#       Points shape: (1024, 5)
#       Block index: 486
#     block_60728
#       Points shape: (1024, 5)
#       Block index: 487
#     block_60729
#       Points shape: (1024, 5)
#       Block index: 488
#     block_60730
#       Points shape: (1024, 5)
#       Block index: 489
#     block_60731
#       Points shape: (1024, 5)
#       Block index: 490
#     block_60732
#       Points shape: (1024, 5)
#       Block index: 491
#     block_60733
#       Points shape: (1024, 5)
#       Block index: 492
#     block_60734
#       Points shape: (1024, 5)
#       Block index: 493
#     block_60735
#       Points shape: (1024, 5)
#       Block index: 494
#     block_60736
#       Points shape: (1024, 5)
#       Block index: 495
#     block_60737
#       Points shape: (1024, 5)
#       Block index: 496
#     block_60738
#       Points shape: (1024, 5)
#       Block index: 497
#     block_60739
#       Points shape: (1024, 5)
#       Block index: 498
#     block_60740
#       Points shape: (1024, 5)
#       Block index: 499
#     block_60741
#       Points shape: (1024, 5)
#       Block index: 500
#     block_60742
#       Points shape: (1024, 5)
#       Block index: 501
#     block_60743
#       Points shape: (1024, 5)
#       Block index: 502
#     block_60744
#       Points shape: (1024, 5)
#       Block index: 503
#     block_60745
#       Points shape: (1024, 5)
#       Block index: 504
#     block_60746
#       Points shape: (1024, 5)
#       Block index: 505
#     block_60747
#       Points shape: (1024, 5)
#       Block index: 506
#     block_60748
#       Points shape: (1024, 5)
#       Block index: 507
#     block_60749
#       Points shape: (1024, 5)
#       Block index: 508
#     block_60750
#       Points shape: (1024, 5)
#       Block index: 509
#     block_60751
#       Points shape: (1024, 5)
#       Block index: 510
#     block_60752
#       Points shape: (1024, 5)
#       Block index: 511
#     block_60753
#       Points shape: (1024, 5)
#       Block index: 512
#     block_60754
#       Points shape: (1024, 5)
#       Block index: 513
#     block_60755
#       Points shape: (1024, 5)
#       Block index: 514
#     block_60756
#       Points shape: (1024, 5)
#       Block index: 515
#     block_60757
#       Points shape: (1024, 5)
#       Block index: 516
#     block_60758
#       Points shape: (1024, 5)
#       Block index: 517
#     block_60759
#       Points shape: (1024, 5)
#       Block index: 518
#     block_60760
#       Points shape: (1024, 5)
#       Block index: 519
#     block_60761
#       Points shape: (1024, 5)
#       Block index: 520
#     block_60762
#       Points shape: (1024, 5)
#       Block index: 521
#     block_60763
#       Points shape: (1024, 5)
#       Block index: 522
#     block_60764
#       Points shape: (1024, 5)
#       Block index: 523
#     block_60765
#       Points shape: (1024, 5)
#       Block index: 524
#     block_60766
#       Points shape: (1024, 5)
#       Block index: 525
#     block_60767
#       Points shape: (1024, 5)
#       Block index: 526
#     block_60768
#       Points shape: (1024, 5)
#       Block index: 527
#     block_60769
#       Points shape: (1024, 5)
#       Block index: 528
#     block_60770
#       Points shape: (1024, 5)
#       Block index: 529
#     block_60771
#       Points shape: (1024, 5)
#       Block index: 530
#     block_60772
#       Points shape: (1024, 5)
#       Block index: 531
#     block_60773
#       Points shape: (1024, 5)
#       Block index: 532
#     block_60774
#       Points shape: (1024, 5)
#       Block index: 533
#     block_60775
#       Points shape: (1024, 5)
#       Block index: 534
#     block_60776
#       Points shape: (1024, 5)
#       Block index: 535
#     block_60777
#       Points shape: (1024, 5)
#       Block index: 536
#     block_60778
#       Points shape: (1024, 5)
#       Block index: 537
#     block_60779
#       Points shape: (1024, 5)
#       Block index: 538
#     block_60780
#       Points shape: (1024, 5)
#       Block index: 539
#     block_60781
#       Points shape: (1024, 5)
#       Block index: 540
#     block_60782
#       Points shape: (1024, 5)
#       Block index: 541
#     block_60783
#       Points shape: (1024, 5)
#       Block index: 542
#     block_60784
#       Points shape: (1024, 5)
#       Block index: 543
#     block_60785
#       Points shape: (1024, 5)
#       Block index: 544
#     block_60786
#       Points shape: (1024, 5)
#       Block index: 545
#     block_60787
#       Points shape: (1024, 5)
#       Block index: 546
#     block_60788
#       Points shape: (1024, 5)
#       Block index: 547
#     block_60789
#       Points shape: (1024, 5)
#       Block index: 548
#     block_60790
#       Points shape: (1024, 5)
#       Block index: 549
#     block_60791
#       Points shape: (1024, 5)
#       Block index: 550
#     block_60792
#       Points shape: (1024, 5)
#       Block index: 551
#     block_60793
#       Points shape: (1024, 5)
#       Block index: 552
#     block_60794
#       Points shape: (1024, 5)
#       Block index: 553
#     block_60795
#       Points shape: (1024, 5)
#       Block index: 554
#     block_60796
#       Points shape: (1024, 5)
#       Block index: 555
#     block_60797
#       Points shape: (1024, 5)
#       Block index: 556
#     block_60798
#       Points shape: (1024, 5)
#       Block index: 557
#     block_60799
#       Points shape: (1024, 5)
#       Block index: 558
#     block_60800
#       Points shape: (1024, 5)
#       Block index: 559
#     block_60801
#       Points shape: (1024, 5)
#       Block index: 560
#     block_60802
#       Points shape: (1024, 5)
#       Block index: 561
#     block_60803
#       Points shape: (1024, 5)
#       Block index: 562
#     block_60804
#       Points shape: (1024, 5)
#       Block index: 563
#     block_60805
#       Points shape: (1024, 5)
#       Block index: 564
#     block_60806
#       Points shape: (1024, 5)
#       Block index: 565
#     block_60807
#       Points shape: (1024, 5)
#       Block index: 566
#     block_60808
#       Points shape: (1024, 5)
#       Block index: 567
#     block_60809
#       Points shape: (1024, 5)
#       Block index: 568
#     block_60810
#       Points shape: (1024, 5)
#       Block index: 569
#     block_60811
#       Points shape: (1024, 5)
#       Block index: 570
#     block_60812
#       Points shape: (1024, 5)
#       Block index: 571
#     block_60813
#       Points shape: (1024, 5)
#       Block index: 572
#     block_60814
#       Points shape: (1024, 5)
#       Block index: 573
#     block_60815
#       Points shape: (1024, 5)
#       Block index: 574
#     block_60816
#       Points shape: (1024, 5)
#       Block index: 575
#     block_60817
#       Points shape: (1024, 5)
#       Block index: 576
#     block_60818
#       Points shape: (1024, 5)
#       Block index: 577
#     block_60819
#       Points shape: (1024, 5)
#       Block index: 578
#     block_60820
#       Points shape: (1024, 5)
#       Block index: 579
#     block_60821
#       Points shape: (1024, 5)
#       Block index: 580
#     block_60822
#       Points shape: (1024, 5)
#       Block index: 581
#     block_60823
#       Points shape: (1024, 5)
#       Block index: 582
#     block_60824
#       Points shape: (1024, 5)
#       Block index: 583
#     block_60825
#       Points shape: (1024, 5)
#       Block index: 584
#     block_60826
#       Points shape: (1024, 5)
#       Block index: 585
#     block_60827
#       Points shape: (1024, 5)
#       Block index: 586
#     block_60828
#       Points shape: (1024, 5)
#       Block index: 587
#     block_60829
#       Points shape: (1024, 5)
#       Block index: 588
#     block_60830
#       Points shape: (1024, 5)
#       Block index: 589
#     block_60831
#       Points shape: (1024, 5)
#       Block index: 590
#     block_60832
#       Points shape: (1024, 5)
#       Block index: 591
#     block_60833
#       Points shape: (1024, 5)
#       Block index: 592
#     block_60834
#       Points shape: (1024, 5)
#       Block index: 593
#     block_60835
#       Points shape: (1024, 5)
#       Block index: 594
#     block_60836
#       Points shape: (1024, 5)
#       Block index: 595
#     block_60837
#       Points shape: (1024, 5)
#       Block index: 596
#     block_60838
#       Points shape: (1024, 5)
#       Block index: 597
#     block_60839
#       Points shape: (1024, 5)
#       Block index: 598
#     block_60840
#       Points shape: (1024, 5)
#       Block index: 599
#     block_60841
#       Points shape: (1024, 5)
#       Block index: 600
#     block_60842
#       Points shape: (1024, 5)
#       Block index: 601
#     block_60843
#       Points shape: (1024, 5)
#       Block index: 602
#     block_60844
#       Points shape: (1024, 5)
#       Block index: 603
#     block_60845
#       Points shape: (1024, 5)
#       Block index: 604
#     block_60846
#       Points shape: (1024, 5)
#       Block index: 605
#     block_60847
#       Points shape: (1024, 5)
#       Block index: 606
#     block_60848
#       Points shape: (1024, 5)
#       Block index: 607
#     block_60849
#       Points shape: (1024, 5)
#       Block index: 608
#     block_60850
#       Points shape: (1024, 5)
#       Block index: 609
#     block_60851
#       Points shape: (1024, 5)
#       Block index: 610
#     block_60852
#       Points shape: (1024, 5)
#       Block index: 611
#     block_60853
#       Points shape: (1024, 5)
#       Block index: 612
#     block_60854
#       Points shape: (1024, 5)
#       Block index: 613
#     block_60855
#       Points shape: (1024, 5)
#       Block index: 614
#     block_60856
#       Points shape: (1024, 5)
#       Block index: 615
#     block_60857
#       Points shape: (1024, 5)
#       Block index: 616
#     block_60858
#       Points shape: (1024, 5)
#       Block index: 617
#     block_60859
#       Points shape: (1024, 5)
#       Block index: 618
#     block_60860
#       Points shape: (1024, 5)
#       Block index: 619
#     block_60861
#       Points shape: (1024, 5)
#       Block index: 620
#     block_60862
#       Points shape: (1024, 5)
#       Block index: 621
#     block_60863
#       Points shape: (1024, 5)
#       Block index: 622
#     block_60864
#       Points shape: (1024, 5)
#       Block index: 623
#     block_60865
#       Points shape: (1024, 5)
#       Block index: 624
#     block_60866
#       Points shape: (1024, 5)
#       Block index: 625
#     block_60867
#       Points shape: (1024, 5)
#       Block index: 626
#     block_60868
#       Points shape: (1024, 5)
#       Block index: 627
#     block_60869
#       Points shape: (1024, 5)
#       Block index: 628
#     block_60870
#       Points shape: (1024, 5)
#       Block index: 629
#     block_60871
#       Points shape: (1024, 5)
#       Block index: 630
#     block_60872
#       Points shape: (1024, 5)
#       Block index: 631
#     block_60873
#       Points shape: (1024, 5)
#       Block index: 632
#     block_60874
#       Points shape: (1024, 5)
#       Block index: 633
#     block_60875
#       Points shape: (1024, 5)
#       Block index: 634
#     block_60876
#       Points shape: (1024, 5)
#       Block index: 635
#     block_60877
#       Points shape: (1024, 5)
#       Block index: 636
#     block_60878
#       Points shape: (1024, 5)
#       Block index: 637
#     block_60879
#       Points shape: (1024, 5)
#       Block index: 638
#     block_60880
#       Points shape: (1024, 5)
#       Block index: 639
#     block_60881
#       Points shape: (1024, 5)
#       Block index: 640
#     block_60882
#       Points shape: (1024, 5)
#       Block index: 641
#     block_60883
#       Points shape: (1024, 5)
#       Block index: 642
#     block_60884
#       Points shape: (1024, 5)
#       Block index: 643
#     block_60885
#       Points shape: (1024, 5)
#       Block index: 644
#     block_60886
#       Points shape: (1024, 5)
#       Block index: 645
#     block_60887
#       Points shape: (1024, 5)
#       Block index: 646
#     block_60888
#       Points shape: (1024, 5)
#       Block index: 647
#     block_60889
#       Points shape: (1024, 5)
#       Block index: 648
#     block_60890
#       Points shape: (1024, 5)
#       Block index: 649
#     block_60891
#       Points shape: (1024, 5)
#       Block index: 650
#     block_60892
#       Points shape: (1024, 5)
#       Block index: 651
#     block_60893
#       Points shape: (1024, 5)
#       Block index: 652
#     block_60894
#       Points shape: (1024, 5)
#       Block index: 653
#     block_60895
#       Points shape: (1024, 5)
#       Block index: 654
#     block_60896
#       Points shape: (1024, 5)
#       Block index: 655
#     block_60897
#       Points shape: (1024, 5)
#       Block index: 656
#     block_60898
#       Points shape: (1024, 5)
#       Block index: 657
#     block_60899
#       Points shape: (1024, 5)
#       Block index: 658
#     block_60900
#       Points shape: (1024, 5)
#       Block index: 659
#     block_60901
#       Points shape: (1024, 5)
#       Block index: 660
#     block_60902
#       Points shape: (1024, 5)
#       Block index: 661
#     block_60903
#       Points shape: (1024, 5)
#       Block index: 662
#     block_60904
#       Points shape: (1024, 5)
#       Block index: 663
#     block_60905
#       Points shape: (1024, 5)
#       Block index: 664
#     block_60906
#       Points shape: (1024, 5)
#       Block index: 665
#     block_60907
#       Points shape: (1024, 5)
#       Block index: 666
#     block_60908
#       Points shape: (1024, 5)
#       Block index: 667
#     block_60909
#       Points shape: (1024, 5)
#       Block index: 668
#     block_60910
#       Points shape: (1024, 5)
#       Block index: 669
#     block_60911
#       Points shape: (1024, 5)
#       Block index: 670
#     block_60912
#       Points shape: (1024, 5)
#       Block index: 671
#     block_60913
#       Points shape: (1024, 5)
#       Block index: 672
#     block_60914
#       Points shape: (1024, 5)
#       Block index: 673
#     block_60915
#       Points shape: (1024, 5)
#       Block index: 674
#     block_60916
#       Points shape: (1024, 5)
#       Block index: 675
#     block_60917
#       Points shape: (1024, 5)
#       Block index: 676
#     block_60918
#       Points shape: (1024, 5)
#       Block index: 677
#     block_60919
#       Points shape: (1024, 5)
#       Block index: 678
#     block_60920
#       Points shape: (1024, 5)
#       Block index: 679
#     block_60921
#       Points shape: (1024, 5)
#       Block index: 680
#     block_60922
#       Points shape: (1024, 5)
#       Block index: 681
#     block_60923
#       Points shape: (1024, 5)
#       Block index: 682
#     block_60924
#       Points shape: (1024, 5)
#       Block index: 683
#     block_60925
#       Points shape: (1024, 5)
#       Block index: 684
#     block_60926
#       Points shape: (1024, 5)
#       Block index: 685
#     block_60927
#       Points shape: (1024, 5)
#       Block index: 686
#     block_60928
#       Points shape: (1024, 5)
#       Block index: 687
#     block_60929
#       Points shape: (1024, 5)
#       Block index: 688
#     block_60930
#       Points shape: (1024, 5)
#       Block index: 689
#     block_60931
#       Points shape: (1024, 5)
#       Block index: 690
#     block_60932
#       Points shape: (1024, 5)
#       Block index: 691
#     block_60933
#       Points shape: (1024, 5)
#       Block index: 692
#     block_60934
#       Points shape: (1024, 5)
#       Block index: 693
#     block_60935
# ...
#     block_61528
#       Points shape: (1024, 5)
#       Block index: 1287
#     block_61529
#       Points shape: (1024, 5)
#       Block index: 1288
#     block_61530
#       Points shape: (1024, 5)
#       Block index: 1289
#     block_61531
#       Points shape: (1024, 5)
#       Block index: 1290
#     block_61532
#       Points shape: (1024, 5)
#       Block index: 1291
#     block_61533
#       Points shape: (1024, 5)
#       Block index: 1292
#     block_61534
#       Points shape: (1024, 5)
#       Block index: 1293
#     block_61535
#       Points shape: (1024, 5)
#       Block index: 1294
#     block_61536
#       Points shape: (1024, 5)
#       Block index: 1295
#     block_61537
#       Points shape: (1024, 5)
#       Block index: 1296
#     block_61538
#       Points shape: (1024, 5)
#       Block index: 1297
#     block_61539
#       Points shape: (1024, 5)
#       Block index: 1298
#     block_61540
#       Points shape: (1024, 5)
#       Block index: 1299
#     block_61541
#       Points shape: (1024, 5)
#       Block index: 1300
#     block_61542
#       Points shape: (1024, 5)
#       Block index: 1301
#     block_61543
#       Points shape: (1024, 5)
#       Block index: 1302
#     block_61544
#       Points shape: (1024, 5)
#       Block index: 1303
#     block_61545
#       Points shape: (1024, 5)
#       Block index: 1304
#     block_61546
#       Points shape: (1024, 5)
#       Block index: 1305
#     block_61547
#       Points shape: (1024, 5)
#       Block index: 1306
#     block_61548
#       Points shape: (1024, 5)
#       Block index: 1307
#     block_61549
#       Points shape: (1024, 5)
#       Block index: 1308
#     block_61550
#       Points shape: (1024, 5)
#       Block index: 1309
#     block_61551
#       Points shape: (1024, 5)
#       Block index: 1310
#     block_61552
#       Points shape: (1024, 5)
#       Block index: 1311
#     block_61553
#       Points shape: (1024, 5)
#       Block index: 1312
#     block_61554
#       Points shape: (1024, 5)
#       Block index: 1313
#     block_61555
#       Points shape: (1024, 5)
#       Block index: 1314
#     block_61556
#       Points shape: (1024, 5)
#       Block index: 1315
#     block_61557
#       Points shape: (1024, 5)
#       Block index: 1316
#     block_61558
#       Points shape: (1024, 5)
#       Block index: 1317
#     block_61559
#       Points shape: (1024, 5)
#       Block index: 1318
#     block_61560
#       Points shape: (1024, 5)
#       Block index: 1319
#     block_61561
#       Points shape: (1024, 5)
#       Block index: 1320
#     block_61562
#       Points shape: (1024, 5)
#       Block index: 1321
#     block_61563
#       Points shape: (1024, 5)
#       Block index: 1322
#     block_61564
#       Points shape: (1024, 5)
#       Block index: 1323
#     block_61565
#       Points shape: (1024, 5)
#       Block index: 1324
#     block_61566
#       Points shape: (1024, 5)
#       Block index: 1325
#     block_61567
#       Points shape: (1024, 5)
#       Block index: 1326
#     block_61568
#       Points shape: (1024, 5)
#       Block index: 1327
#     block_61569
#       Points shape: (1024, 5)
#       Block index: 1328
#     block_61570
#       Points shape: (1024, 5)
#       Block index: 1329
#     block_61571
#       Points shape: (1024, 5)
#       Block index: 1330
#     block_61572
#       Points shape: (1024, 5)
#       Block index: 1331
#     block_61573
#       Points shape: (1024, 5)
#       Block index: 1332
#     block_61574
#       Points shape: (1024, 5)
#       Block index: 1333
#     block_61575
#       Points shape: (1024, 5)
#       Block index: 1334
#     block_61576
#       Points shape: (1024, 5)
#       Block index: 1335
#     block_61577
#       Points shape: (1024, 5)
#       Block index: 1336
#     block_61578
#       Points shape: (1024, 5)
#       Block index: 1337
#     block_61579
#       Points shape: (1024, 5)
#       Block index: 1338
#     block_61580
#       Points shape: (1024, 5)
#       Block index: 1339
#     block_61581
#       Points shape: (1024, 5)
#       Block index: 1340
#     block_61582
#       Points shape: (1024, 5)
#       Block index: 1341
#     block_61583
#       Points shape: (1024, 5)
#       Block index: 1342
#     block_61584
#       Points shape: (1024, 5)
#       Block index: 1343
#     block_61585
#       Points shape: (1024, 5)
#       Block index: 1344
#     block_61586
#       Points shape: (1024, 5)
#       Block index: 1345
#     block_61587
#       Points shape: (1024, 5)
#       Block index: 1346
#     block_61588
#       Points shape: (1024, 5)
#       Block index: 1347
#     block_61589
#       Points shape: (1024, 5)
#       Block index: 1348
#     block_61590
#       Points shape: (1024, 5)
#       Block index: 1349
#     block_61591
#       Points shape: (1024, 5)
#       Block index: 1350
#     block_61592
#       Points shape: (1024, 5)
#       Block index: 1351
#     block_61593
#       Points shape: (1024, 5)
#       Block index: 1352
#     block_61594
#       Points shape: (1024, 5)
#       Block index: 1353
#     block_61595
#       Points shape: (1024, 5)
#       Block index: 1354
#     block_61596
#       Points shape: (1024, 5)
#       Block index: 1355
#     block_61597
#       Points shape: (1024, 5)
#       Block index: 1356
#     block_61598
#       Points shape: (1024, 5)
#       Block index: 1357
#     block_61599
#       Points shape: (1024, 5)
#       Block index: 1358
#     block_61600
#       Points shape: (1024, 5)
#       Block index: 1359
#     block_61601
#       Points shape: (1024, 5)
#       Block index: 1360
#     block_61602
#       Points shape: (1024, 5)
#       Block index: 1361
#     block_61603
#       Points shape: (1024, 5)
#       Block index: 1362
#     block_61604
#       Points shape: (1024, 5)
#       Block index: 1363
#     block_61605
#       Points shape: (1024, 5)
#       Block index: 1364
#     block_61606
#       Points shape: (1024, 5)
#       Block index: 1365
#     block_61607
#       Points shape: (1024, 5)
#       Block index: 1366
#     block_61608
#       Points shape: (1024, 5)
#       Block index: 1367
#     block_61609
#       Points shape: (1024, 5)
#       Block index: 1368
#     block_61610
#       Points shape: (1024, 5)
#       Block index: 1369
#     block_61611
#       Points shape: (1024, 5)
#       Block index: 1370
#     block_61612
#       Points shape: (1024, 5)
#       Block index: 1371
#     block_61613
#       Points shape: (1024, 5)
#       Block index: 1372
#     block_61614
#       Points shape: (1024, 5)
#       Block index: 1373
#     block_61615
#       Points shape: (1024, 5)
#       Block index: 1374
#     block_61616
#       Points shape: (1024, 5)
#       Block index: 1375
#     block_61617
#       Points shape: (1024, 5)
#       Block index: 1376
#     block_61618
#       Points shape: (1024, 5)
#       Block index: 1377
#     block_61619
#       Points shape: (1024, 5)
#       Block index: 1378
#     block_61620
#       Points shape: (1024, 5)
#       Block index: 1379
#     block_61621
#       Points shape: (1024, 5)
#       Block index: 1380
#     block_61622
#       Points shape: (1024, 5)
#       Block index: 1381
#     block_61623
#       Points shape: (1024, 5)
#       Block index: 1382
#     block_61624
#       Points shape: (1024, 5)
#       Block index: 1383
#     block_61625
#       Points shape: (1024, 5)
#       Block index: 1384
#     block_61626
#       Points shape: (1024, 5)
#       Block index: 1385
#     block_61627
#       Points shape: (1024, 5)
#       Block index: 1386
#     block_61628
#       Points shape: (1024, 5)
#       Block index: 1387
#     block_61629
#       Points shape: (1024, 5)
#       Block index: 1388
#     block_61630
#       Points shape: (1024, 5)
#       Block index: 1389
#     block_61631
#       Points shape: (1024, 5)
#       Block index: 1390
#     block_61632
#       Points shape: (1024, 5)
#       Block index: 1391
#     block_61633
#       Points shape: (1024, 5)
#       Block index: 1392
#     block_61634
#       Points shape: (1024, 5)
#       Block index: 1393
#     block_61635
#       Points shape: (1024, 5)
#       Block index: 1394
#     block_61636
#       Points shape: (1024, 5)
#       Block index: 1395
#     block_61637
#       Points shape: (1024, 5)
#       Block index: 1396
#     block_61638
#       Points shape: (1024, 5)
#       Block index: 1397
#     block_61639
#       Points shape: (1024, 5)
#       Block index: 1398
#     block_61640
#       Points shape: (1024, 5)
#       Block index: 1399
#     block_61641
#       Points shape: (1024, 5)
#       Block index: 1400
#     block_61642
#       Points shape: (1024, 5)
#       Block index: 1401
#     block_61643
#       Points shape: (1024, 5)
#       Block index: 1402
#     block_61644
#       Points shape: (1024, 5)
#       Block index: 1403
#     block_61645
#       Points shape: (1024, 5)
#       Block index: 1404
#     block_61646
#       Points shape: (1024, 5)
#       Block index: 1405
#     block_61647
#       Points shape: (1024, 5)
#       Block index: 1406
#     block_61648
#       Points shape: (1024, 5)
#       Block index: 1407
#     block_61649
#       Points shape: (1024, 5)
#       Block index: 1408
#     block_61650
#       Points shape: (1024, 5)
#       Block index: 1409
#     block_61651
#       Points shape: (1024, 5)
#       Block index: 1410
#     block_61652
#       Points shape: (1024, 5)
#       Block index: 1411
#     block_61653
#       Points shape: (1024, 5)
#       Block index: 1412
#     block_61654
#       Points shape: (1024, 5)
#       Block index: 1413
#     block_61655
#       Points shape: (1024, 5)
#       Block index: 1414
#     block_61656
#       Points shape: (1024, 5)
#       Block index: 1415
#     block_61657
#       Points shape: (1024, 5)
#       Block index: 1416
#     block_61658
#       Points shape: (1024, 5)
#       Block index: 1417
#     block_61659
#       Points shape: (1024, 5)
#       Block index: 1418
#     block_61660
#       Points shape: (1024, 5)
#       Block index: 1419
#     block_61661
#       Points shape: (1024, 5)
#       Block index: 1420
#     block_61662
#       Points shape: (1024, 5)
#       Block index: 1421
#     block_61663
#       Points shape: (1024, 5)
#       Block index: 1422
#     block_61664
#       Points shape: (1024, 5)
#       Block index: 1423
#     block_61665
#       Points shape: (1024, 5)
#       Block index: 1424
#     block_61666
#       Points shape: (1024, 5)
#       Block index: 1425
#     block_61667
#       Points shape: (1024, 5)
#       Block index: 1426
#     block_61668
#       Points shape: (1024, 5)
#       Block index: 1427
#     block_61669
#       Points shape: (1024, 5)
#       Block index: 1428
#     block_61670
#       Points shape: (1024, 5)
#       Block index: 1429
#     block_61671
#       Points shape: (1024, 5)
#       Block index: 1430
#     block_61672
#       Points shape: (1024, 5)
#       Block index: 1431
#     block_61673
#       Points shape: (1024, 5)
#       Block index: 1432
#     block_61674
#       Points shape: (1024, 5)
#       Block index: 1433
#     block_61675
#       Points shape: (1024, 5)
#       Block index: 1434
#     block_61676
#       Points shape: (1024, 5)
#       Block index: 1435
#     block_61677
#       Points shape: (1024, 5)
#       Block index: 1436
#     block_61678
#       Points shape: (1024, 5)
#       Block index: 1437
#     block_61679
#       Points shape: (1024, 5)
#       Block index: 1438
#     block_61680
#       Points shape: (1024, 5)
#       Block index: 1439
#     block_61681
#       Points shape: (1024, 5)
#       Block index: 1440
#     block_61682
#       Points shape: (1024, 5)
#       Block index: 1441
#     block_61683
#       Points shape: (1024, 5)
#       Block index: 1442
#     block_61684
#       Points shape: (1024, 5)
#       Block index: 1443
#     block_61685
#       Points shape: (1024, 5)
#       Block index: 1444
#     block_61686
#       Points shape: (1024, 5)
#       Block index: 1445
#     block_61687
#       Points shape: (1024, 5)
#       Block index: 1446
#     block_61688
#       Points shape: (1024, 5)
#       Block index: 1447
#     block_61689
#       Points shape: (1024, 5)
#       Block index: 1448
#     block_61690
#       Points shape: (1024, 5)
#       Block index: 1449
#     block_61691
#       Points shape: (1024, 5)
#       Block index: 1450
#     block_61692
#       Points shape: (1024, 5)
#       Block index: 1451
#     block_61693
#       Points shape: (1024, 5)
#       Block index: 1452
#     block_61694
#       Points shape: (1024, 5)
#       Block index: 1453
#     block_61695
#       Points shape: (1024, 5)
#       Block index: 1454
#     block_61696
#       Points shape: (1024, 5)
#       Block index: 1455
#     block_61697
#       Points shape: (1024, 5)
#       Block index: 1456
#     block_61698
#       Points shape: (1024, 5)
#       Block index: 1457
#     block_61699
#       Points shape: (1024, 5)
#       Block index: 1458
#     block_61700
#       Points shape: (1024, 5)
#       Block index: 1459
#     block_61701
#       Points shape: (1024, 5)
#       Block index: 1460
#     block_61702
#       Points shape: (1024, 5)
#       Block index: 1461
#     block_61703
#       Points shape: (1024, 5)
#       Block index: 1462
#     block_61704
#       Points shape: (1024, 5)
#       Block index: 1463
#     block_61705
#       Points shape: (1024, 5)
#       Block index: 1464
#     block_61706
#       Points shape: (1024, 5)
#       Block index: 1465
#     block_61707
#       Points shape: (1024, 5)
#       Block index: 1466
#     block_61708
#       Points shape: (1024, 5)
#       Block index: 1467
#     block_61709
#       Points shape: (1024, 5)
#       Block index: 1468
#     block_61710
#       Points shape: (1024, 5)
#       Block index: 1469
#     block_61711
#       Points shape: (1024, 5)
#       Block index: 1470
#     block_61712
#       Points shape: (1024, 5)
#       Block index: 1471
#     block_61713
#       Points shape: (1024, 5)
#       Block index: 1472
#     block_61714
#       Points shape: (1024, 5)
#       Block index: 1473
#     block_61715
#       Points shape: (1024, 5)
#       Block index: 1474
#     block_61716
#       Points shape: (1024, 5)
#       Block index: 1475
#     block_61717
#       Points shape: (1024, 5)
#       Block index: 1476
#     block_61718
#       Points shape: (1024, 5)
#       Block index: 1477
#     block_61719
#       Points shape: (1024, 5)
#       Block index: 1478
#     block_61720
#       Points shape: (1024, 5)
#       Block index: 1479
#     block_61721
#       Points shape: (1024, 5)
#       Block index: 1480
#     block_61722
#       Points shape: (1024, 5)
#       Block index: 1481
#     block_61723
#       Points shape: (1024, 5)
#       Block index: 1482
#     block_61724
#       Points shape: (1024, 5)
#       Block index: 1483
#     block_61725
#       Points shape: (1024, 5)
#       Block index: 1484
#     block_61726
#       Points shape: (1024, 5)
#       Block index: 1485
#     block_61727
#       Points shape: (1024, 5)
#       Block index: 1486
#     block_61728
#       Points shape: (1024, 5)
#       Block index: 1487
#     block_61729
#       Points shape: (1024, 5)
#       Block index: 1488
#     block_61730
#       Points shape: (1024, 5)
#       Block index: 1489
#     block_61731
#       Points shape: (1024, 5)
#       Block index: 1490
#
# Voxel: voxel_-0.9315010070800795_-11.186700057983398_-3.79
#   Points shape: (5872, 5)
#   Voxel key: [ -0.93150101 -11.18670006  -3.79      ]
#   Blocks in this voxel:
#     block_58396
#       Points shape: (1024, 5)
#       Block index: 0
#     block_58397
#       Points shape: (1024, 5)
#       Block index: 1
#     block_58398
#       Points shape: (1024, 5)
#       Block index: 2
#     block_58399
#       Points shape: (1024, 5)
#       Block index: 3
#     block_58400
#       Points shape: (1024, 5)
#       Block index: 4
#
# Voxel: voxel_-0.9315010070800795_-12.986700057983398_-3.79
#   Points shape: (1355, 5)
#   Voxel key: [ -0.93150101 -12.98670006  -3.79      ]
#   Blocks in this voxel:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 24
#      21 print("  Blocks in this voxel:")
#      22 for block_name, block_grp in blocks_grp.items():
#      23     # Use np.array_equal to compare voxel keys
# ---> 24     if np.array_equal(block_grp.attrs['voxel_key'], voxel_grp.attrs['voxel_key']):
#      25         print(f"    {block_name}")
#      26         print(f"      Points shape: {block_grp['points'].shape}")
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\h5py\_hl\attrs.py:63, in AttributeManager.__getitem__(self, name)
#      60 if shape is None:
#      61     return Empty(attr.dtype)
# ---> 63 dtype = attr.dtype
#      65 # Do this first, as we'll be fiddling with the dtype for top-level
#      66 # array types
#      67 htype = h5t.py_create(dtype)
#
# KeyboardInterrupt:

# %%
import h5py
import pandas as pd

# Replace with the correct path to your HDF5 file
file_path = r"C:\Users\lukas\Desktop\pointcloud_blocks2.h5"

# Dictionary to store the first 5 points' details for each block
blocks_first_5_points = {}

# Open the HDF5 file and retrieve the first 5 points in every block
with h5py.File(file_path, 'r') as file:
    if 'blocks' in file:
        blocks_grp = file['blocks']
        
        # Iterate through each block and retrieve the first 5 points' details
        for block_name, block_grp in blocks_grp.items():
            points = block_grp['points'][:5]  # Get the first 5 points
            blocks_first_5_points[block_name] = {
                "coordinates": points[:, :3],  # XYZ coordinates
                "RGB": points[:, 3:6],         # RGB values
                "intensity": points[:, 6],     # Intensity
                "class": points[:, 7]          # Class
            }

# Convert dictionary to a DataFrame for easier visualization
df_list = []
for block_name, data in blocks_first_5_points.items():
    for i in range(5):  # For each of the first 5 points in the block
        df_list.append({
            "block_name": block_name,
            "point_index": i,
            "x": data["coordinates"][i][0],
            "y": data["coordinates"][i][1],
            "z": data["coordinates"][i][2],
            "r": data["RGB"][i][0],
            "g": data["RGB"][i][1],
            "b": data["RGB"][i][2],
            "intensity": data["intensity"][i],
            "class": data["class"][i]
        })

# Create a DataFrame from the list
df_first_5_points = pd.DataFrame(df_list)

# Display the DataFrame for inspection
import ace_tools as tools; tools.display_dataframe_to_user(name="First 5 Points in Each Block", dataframe=df_first_5_points)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 21
#      16         for block_name, block_grp in blocks_grp.items():
#      17             points = block_grp['points'][:5]  # Get the first 5 points
#      18             blocks_first_5_points[block_name] = {
#      19                 "coordinates": points[:, :3],  # XYZ coordinates
#      20                 "RGB": points[:, 3:6],         # RGB values
# ---> 21                 "intensity": points[:, 6],     # Intensity
#      22                 "class": points[:, 7]          # Class
#      23             }
#      25 # Convert dictionary to a DataFrame for easier visualization
#      26 df_list = []
#
# IndexError: index 6 is out of bounds for axis 1 with size 5

# %%
import h5py

file_path = r"C:\Users\lukas\Desktop\pointcloud_blocks.h5"

# Load the HDF5 file and display its structure
with h5py.File(file_path, 'r') as h5f:
    def print_structure(name, obj):
        if isinstance(obj, h5py.Dataset):
            print(f"Dataset: {name}, shape: {obj.shape}, dtype: {obj.dtype}")
        elif isinstance(obj, h5py.Group):
            print(f"Group: {name}")

    # Print the structure of the HDF5 file
    print("HDF5 File Structure:")
    h5f.visititems(print_structure)

    # Load and display points, RGB, intensity, and class for each block (if applicable)
    if 'blocks' in h5f:
        blocks_grp = h5f['blocks']
        for block_name, block_grp in blocks_grp.items():
            points = block_grp['points'][:]
            print(f"\nBlock: {block_name}")
            print(f"Points shape: {points.shape}")

            # Assuming points can contain different numbers of columns
            num_columns = points.shape[1]
            
            # Assign attributes dynamically based on number of columns
            if num_columns >= 3:
                x, y, z = points[:, 0], points[:, 1], points[:, 2]
            else:
                print("The points dataset does not contain XYZ coordinates.")
                continue

            intensity = points[:, 3] if num_columns > 3 else None
            r, g, b = (points[:, 4], points[:, 5], points[:, 6]) if num_columns > 6 else (None, None, None)
            classification = points[:, 7] if num_columns > 7 else None

            # Print some example points
            for i in range(min(5, len(points))):  # Print the first 5 points or fewer if less are available
                print(f"Point {i + 1}: (x: {x[i]}, y: {y[i]}, z: {z[i]}, "
                      f"intensity: {intensity[i] if intensity is not None else 'N/A'}, "
                      f"r: {r[i] if r is not None else 'N/A'}, "
                      f"g: {g[i] if g is not None else 'N/A'}, "
                      f"b: {b[i] if b is not None else 'N/A'}, "
                      f"class: {classification[i] if classification is not None else 'N/A'})")

print("HDF5 file reading and inspection completed.")

# %%
import h5py

file_path = r"C:\Users\lukas\Desktop\pointcloud_blocks.h5"

# Load the HDF5 file and display its structure and content
with h5py.File(file_path, 'r') as h5f:
    def print_structure(name, obj):
        if isinstance(obj, h5py.Dataset):
            print(f"Dataset: {name}, shape: {obj.shape}, dtype: {obj.dtype}")
        elif isinstance(obj, h5py.Group):
            print(f"Group: {name}")

    # Print the structure of the HDF5 file
    print("HDF5 File Structure:")
    h5f.visititems(print_structure)

    # Load and display points, RGB, intensity, and class for each block (if applicable)
    if 'blocks' in h5f:
        blocks_grp = h5f['blocks']
        for block_name, block_grp in blocks_grp.items():
            points = block_grp['points'][:]
            print(f"\nBlock: {block_name}")
            print(f"Points shape: {points.shape}")

            # Print the first 5 rows of the points dataset to understand the data structure
            print("First 5 points in the block:")
            for i in range(min(5, len(points))):
                print(f"Point {i + 1}: {points[i]}")

            # Assuming the structure after investigation
            num_columns = points.shape[1]
            if num_columns >= 3:
                x, y, z = points[:, 0], points[:, 1], points[:, 2]
            else:
                print("The points dataset does not contain XYZ coordinates.")
                continue

            # Attempt to identify additional attributes
            intensity = points[:, 3] if num_columns > 3 else None
            if num_columns > 4:
                if num_columns == 5:
                    # If there are only 5 columns, assume the 5th is classification
                    classification = points[:, 4]
                    r, g, b = (None, None, None)
                elif num_columns >= 7:
                    # If there are more columns, assume columns 4, 5, 6 are RGB
                    r, g, b = points[:, 4], points[:, 5], points[:, 6]
                    classification = points[:, 7] if num_columns > 7 else None
                else:
                    r, g, b = (None, None, None)
                    classification = None
            else:
                r, g, b, classification = (None, None, None, None)

            # Print some example points
            for i in range(min(5, len(points))):  # Print the first 5 points or fewer if less are available
                print(f"Point {i + 1}: (x: {x[i]}, y: {y[i]}, z: {z[i]}, "
                      f"intensity: {intensity[i] if intensity is not None else 'N/A'}, "
                      f"r: {r[i] if r is not None else 'N/A'}, "
                      f"g: {g[i] if g is not None else 'N/A'}, "
                      f"b: {b[i] if b is not None else 'N/A'}, "
                      f"class: {classification[i] if classification is not None else 'N/A'})")

print("HDF5 file reading and inspection completed.")

# %%
import laspy
import numpy as np
import h5py

# Load the LAS file efficiently and display loading progress
print("Loading LAS file...")
with laspy.open(r"C:\Users\lukas\Desktop\pointcloud.las") as las_file:
    las = las_file.read()
    points = np.vstack((las.x, las.y, las.z)).T

    # Adding additional attributes if they exist
    if hasattr(las, 'intensity'):
        intensity = las.intensity[:, np.newaxis]
        points = np.hstack((points, intensity))

    if hasattr(las, 'red') and hasattr(las, 'green') and hasattr(las, 'blue'):
        rgb = np.vstack((las.red, las.green, las.blue)).T / 65535.0  # Normalize to [0, 1]
        points = np.hstack((points, rgb))

    if hasattr(las, 'classification_trees'):
        classification = las.classification_trees[:, np.newaxis]
        points = np.hstack((points, classification))

print("LAS file loaded successfully.")

# Voxelization parameters
voxel_size_x = float(input("Enter voxel size for x-axis: "))
voxel_size_y = float(input("Enter voxel size for y-axis: "))
voxel_size_z = np.max(points[:, 2]) - np.min(points[:, 2]) + 1
voxel_overlap_ratio = float(input("Enter voxel overlap ratio (0 to 1): "))

# Voxel bounds with overlap
x_min, y_min, z_min = np.min(points[:, :3], axis=0)
x_max, y_max, z_max = np.max(points[:, :3], axis=0)
adjusted_voxel_size_x = voxel_size_x * (1 - voxel_overlap_ratio)
adjusted_voxel_size_y = voxel_size_y * (1 - voxel_overlap_ratio)
adjusted_voxel_size_z = voxel_size_z * (1 - voxel_overlap_ratio)

# Prepare voxel grid
x_indices = np.arange(x_min, x_max, adjusted_voxel_size_x)
y_indices = np.arange(y_min, y_max, adjusted_voxel_size_y)
z_indices = np.arange(z_min, z_max, adjusted_voxel_size_z)

# Block size for PointNet++
block_size = 1024

# Open HDF5 file for writing
with h5py.File(r"C:\Users\lukas\Desktop\pointcloud_blocks_optimizedx.h5", 'w') as h5f:
    blocks_grp = h5f.create_group('blocks')

    # Process voxels, create blocks, and save each block to HDF5 immediately
    total_voxels = len(x_indices) * len(y_indices) * len(z_indices)
    voxel_count = 0

    print("Processing voxels and saving to HDF5...")
    for x in x_indices:
        for y in y_indices:
            for z in z_indices:
                voxel_count += 1
                progress = (voxel_count / total_voxels) * 100
                print(f"Progress: {progress:.2f}% - Processing voxel at ({x}, {y}, {z})")

                # Mask to find points in the current voxel
                mask = (points[:, 0] >= x) & (points[:, 0] < x + voxel_size_x) & \
                       (points[:, 1] >= y) & (points[:, 1] < y + voxel_size_y) & \
                       (points[:, 2] >= z) & (points[:, 2] < z + voxel_size_z)
                voxel_points = points[mask]

                if len(voxel_points) >= block_size:
                    start_idx = 0
                    block_index = 0

                    # Create and save blocks from the current voxel
                    while start_idx + block_size <= len(voxel_points):
                        block = voxel_points[start_idx:start_idx + block_size]

                        # Save each block immediately
                        block_name = f"block_{voxel_count}_{block_index}"
                        block_grp = blocks_grp.create_group(block_name)
                        block_grp.create_dataset('points', data=block)
                        block_grp.attrs['voxel_key'] = (x, y, z)
                        block_grp.attrs['block_index'] = block_index

                        block_index += 1
                        start_idx += block_size

    print("Data processing and saving completed.")
# Out:
# Loading LAS file...
# LAS file loaded successfully.
# [-32.20409012 -30.20409012 -28.20409012 -26.20409012 -24.20409012]
# [-15.87524796 -13.87524796 -11.87524796  -9.87524796]
# [0.103857]
# Processing voxels and saving to HDF5...
# Progress: 5.00% - Processing voxel at (-32.2040901184082, -15.875247955322266, 0.10385699999999999)
# Progress: 10.00% - Processing voxel at (-32.2040901184082, -13.875247955322266, 0.10385699999999999)
# Progress: 15.00% - Processing voxel at (-32.2040901184082, -11.875247955322266, 0.10385699999999999)
# Progress: 20.00% - Processing voxel at (-32.2040901184082, -9.875247955322266, 0.10385699999999999)
# Progress: 25.00% - Processing voxel at (-30.204090118408203, -15.875247955322266, 0.10385699999999999)
# Progress: 30.00% - Processing voxel at (-30.204090118408203, -13.875247955322266, 0.10385699999999999)
# Progress: 35.00% - Processing voxel at (-30.204090118408203, -11.875247955322266, 0.10385699999999999)
# Progress: 40.00% - Processing voxel at (-30.204090118408203, -9.875247955322266, 0.10385699999999999)
# Progress: 45.00% - Processing voxel at (-28.204090118408203, -15.875247955322266, 0.10385699999999999)
# Progress: 50.00% - Processing voxel at (-28.204090118408203, -13.875247955322266, 0.10385699999999999)
# Progress: 55.00% - Processing voxel at (-28.204090118408203, -11.875247955322266, 0.10385699999999999)
# Progress: 60.00% - Processing voxel at (-28.204090118408203, -9.875247955322266, 0.10385699999999999)
# Progress: 65.00% - Processing voxel at (-26.204090118408203, -15.875247955322266, 0.10385699999999999)
# Progress: 70.00% - Processing voxel at (-26.204090118408203, -13.875247955322266, 0.10385699999999999)
# Progress: 75.00% - Processing voxel at (-26.204090118408203, -11.875247955322266, 0.10385699999999999)
# Progress: 80.00% - Processing voxel at (-26.204090118408203, -9.875247955322266, 0.10385699999999999)
# Progress: 85.00% - Processing voxel at (-24.204090118408203, -15.875247955322266, 0.10385699999999999)
# Progress: 90.00% - Processing voxel at (-24.204090118408203, -13.875247955322266, 0.10385699999999999)
# Progress: 95.00% - Processing voxel at (-24.204090118408203, -11.875247955322266, 0.10385699999999999)
# Progress: 100.00% - Processing voxel at (-24.204090118408203, -9.875247955322266, 0.10385699999999999)
# Data processing and saving completed.

# %%
import laspy
import numpy as np
import h5py
import pdal
import json

# Load the LAS file efficiently and display loading progress
print("Loading LAS file...")
with laspy.open(r"C:\Users\lukas\Desktop\pointcloud_velky.las") as las_file:
    las = las_file.read()
    points = np.vstack((las.x, las.y, las.z)).T

    # Adding additional attributes if they exist
    if hasattr(las, 'intensity'):
        intensity = las.intensity[:, np.newaxis]
        points = np.hstack((points, intensity))

    if hasattr(las, 'red') and hasattr(las, 'green') and hasattr(las, 'blue'):
        rgb = np.vstack((las.red, las.green, las.blue)).T / 65535.0  # Normalize to [0, 1]
        points = np.hstack((points, rgb))

    if hasattr(las, 'classification_trees'):
        classification = las.classification_trees[:, np.newaxis]
        points = np.hstack((points, classification))

print("LAS file loaded successfully.")

# Voxelization parameters
voxel_size_x = float(input("Enter voxel size for x-axis: "))
voxel_size_y = float(input("Enter voxel size for y-axis: "))
voxel_size_z = np.max(points[:, 2]) - np.min(points[:, 2]) + 1
voxel_overlap_ratio = float(input("Enter voxel overlap ratio (0 to 1): "))

# Voxel bounds with overlap
x_min, y_min, z_min = np.min(points[:, :3], axis=0)
x_max, y_max, z_max = np.max(points[:, :3], axis=0)
adjusted_voxel_size_x = voxel_size_x * (1 - voxel_overlap_ratio)
adjusted_voxel_size_y = voxel_size_y * (1 - voxel_overlap_ratio)
adjusted_voxel_size_z = voxel_size_z * (1 - voxel_overlap_ratio)

# Prepare voxel grid
x_indices = np.arange(x_min, x_max, adjusted_voxel_size_x)
y_indices = np.arange(y_min, y_max, adjusted_voxel_size_y)
z_indices = np.arange(z_min, z_max, adjusted_voxel_size_z)

# Block size for PointNet++
block_size = 1024

# Open HDF5 file for writing
with h5py.File(r"C:\Users\lukas\Desktop\pointcloud_blocks_optimized.h5", 'w') as h5f:
    blocks_grp = h5f.create_group('blocks')

    # Process voxels, create blocks, and save each block to HDF5 immediately
    total_voxels = len(x_indices) * len(y_indices) * len(z_indices)
    voxel_count = 0

    print("Processing voxels and saving to HDF5...")
    for x in x_indices:
        for y in y_indices:
            for z in z_indices:
                voxel_count += 1
                progress = (voxel_count / total_voxels) * 100
                print(f"Progress: {progress:.2f}% - Processing voxel at ({x}, {y}, {z})")

                # Mask to find points in the current voxel
                mask = (points[:, 0] >= x) & (points[:, 0] < x + voxel_size_x) & \
                       (points[:, 1] >= y) & (points[:, 1] < y + voxel_size_y) & \
                       (points[:, 2] >= z) & (points[:, 2] < z + voxel_size_z)
                voxel_points = points[mask]

                num_blocks = len(voxel_points) // block_size
                remaining_points = voxel_points.copy()

                for block_index in range(num_blocks):
                    # Use PDAL filter.fps to select points within the voxel
                    pipeline_json = {
                        "pipeline": [
                            {
                                "type": "filters.fps",
                                "count": block_size
                            }
                        ]
                    }
                    pipeline = pdal.Pipeline(json.dumps(pipeline_json), arrays=[remaining_points])
                    pipeline.execute()
                    fps_points = pipeline.arrays[0]

                    # Remove the selected points from the remaining points
                    mask_selected = np.isin(remaining_points[:, :3], fps_points[:, :3]).all(axis=1)
                    remaining_points = remaining_points[~mask_selected]

                    # Save the FPS block to the HDF5 file
                    block_name = f"block_{voxel_count}_{block_index}"
                    block_grp = blocks_grp.create_group(block_name)
                    block_grp.create_dataset('points', data=fps_points)
                    block_grp.attrs['voxel_key'] = (x, y, z)
                    block_grp.attrs['block_index'] = block_index

    print("Data processing and saving completed.")
